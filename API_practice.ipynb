# %%
# Import the dependencies.
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)

lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
   # print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
         # citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
pip freeze
# Out:
# alabaster @ file:///home/ktietz/src/ci/alabaster_1611921544520/work
# anaconda-client @ file:///C:/ci/anaconda-client_1635342725944/work
# anaconda-navigator==2.1.4
# anaconda-project @ file:///tmp/build/80754af9/anaconda-project_1626085644852/work
# anyio @ file:///C:/ci/anyio_1620153135622/work/dist
# appdirs==1.4.4
# argh==0.26.2
# argon2-cffi @ file:///C:/ci/argon2-cffi_1613037869401/work
# arrow @ file:///C:/ci/arrow_1617738834352/work
# asn1crypto @ file:///tmp/build/80754af9/asn1crypto_1596577642040/work
# astroid @ file:///C:/ci/astroid_1628063282661/work
# astropy @ file:///C:/ci/astropy_1629829318700/work
# async-generator @ file:///home/ktietz/src/ci/async_generator_1611927993394/work
# atomicwrites==1.4.0
# attrs @ file:///tmp/build/80754af9/attrs_1620827162558/work
# autopep8 @ file:///tmp/build/80754af9/autopep8_1620866417880/work
# Babel @ file:///tmp/build/80754af9/babel_1620871417480/work
# backcall @ file:///home/ktietz/src/ci/backcall_1611930011877/work
# backports.functools-lru-cache @ file:///tmp/build/80754af9/backports.functools_lru_cache_1618170165463/work
# backports.shutil-get-terminal-size @ file:///tmp/build/80754af9/backports.shutil_get_terminal_size_1608222128777/work
# backports.tempfile @ file:///home/linux1/recipes/ci/backports.tempfile_1610991236607/work
# backports.weakref==1.0.post1
# bcrypt @ file:///C:/ci/bcrypt_1607022693089/work
# beautifulsoup4 @ file:///tmp/build/80754af9/beautifulsoup4_1631874778482/work
# binaryornot @ file:///tmp/build/80754af9/binaryornot_1617751525010/work
# bitarray @ file:///C:/ci/bitarray_1629133068652/work
# bkcharts==0.2
# black==19.10b0
# bleach @ file:///tmp/build/80754af9/bleach_1628110601003/work
# bokeh @ file:///C:/ci/bokeh_1635306491714/work
# boto==2.49.0
# Bottleneck @ file:///C:/ci/bottleneck_1607557040328/work
# brotlipy==0.7.0
# cached-property @ file:///tmp/build/80754af9/cached-property_1600785575025/work
# certifi==2021.10.8
# cffi @ file:///C:/ci/cffi_1625831756778/work
# chardet @ file:///C:/ci/chardet_1607706937985/work
# charset-normalizer @ file:///tmp/build/80754af9/charset-normalizer_1630003229654/work
# citipy==0.0.5
# click==8.0.3
# cloudpickle @ file:///tmp/build/80754af9/cloudpickle_1632508026186/work
# clyent==1.2.2
# colorama @ file:///tmp/build/80754af9/colorama_1607707115595/work
# comtypes==1.1.10
# conda==4.12.0
# conda-build==3.21.6
# conda-content-trust @ file:///tmp/build/80754af9/conda-content-trust_1617045594566/work
# conda-pack @ file:///tmp/build/80754af9/conda-pack_1611163042455/work
# conda-package-handling @ file:///C:/ci/conda-package-handling_1618262410900/work
# conda-repo-cli @ file:///tmp/build/80754af9/conda-repo-cli_1620168426516/work
# conda-token @ file:///tmp/build/80754af9/conda-token_1620076980546/work
# conda-verify==3.4.2
# contextlib2 @ file:///Users/ktietz/demo/mc3/conda-bld/contextlib2_1630668244042/work
# cookiecutter @ file:///tmp/build/80754af9/cookiecutter_1617748928239/work
# cryptography @ file:///C:/ci/cryptography_1633520531101/work
# cycler==0.10.0
# Cython @ file:///C:/ci/cython_1636018292912/work
# cytoolz==0.11.0
# daal4py==2021.3.0
# dask==2021.10.0
# debugpy @ file:///C:/ci/debugpy_1629222819322/work
# decorator @ file:///tmp/build/80754af9/decorator_1632776554403/work
# defusedxml @ file:///tmp/build/80754af9/defusedxml_1615228127516/work
# diff-match-patch @ file:///Users/ktietz/demo/mc3/conda-bld/diff-match-patch_1630511840874/work
# distributed @ file:///C:/ci/distributed_1635968318313/work
# docutils @ file:///C:/ci/docutils_1620828264669/work
# entrypoints==0.3
# et-xmlfile==1.1.0
# fastcache @ file:///C:/ci/fastcache_1607571310570/work
# filelock @ file:///tmp/build/80754af9/filelock_1635402558181/work
# flake8 @ file:///tmp/build/80754af9/flake8_1620776156532/work
# Flask @ file:///home/ktietz/src/ci/flask_1611932660458/work
# fonttools==4.25.0
# fsspec @ file:///tmp/build/80754af9/fsspec_1636116461911/work
# future @ file:///C:/ci/future_1607568713721/work
# geojson==2.5.0
# gevent @ file:///C:/ci/gevent_1628273776273/work
# glob2 @ file:///home/linux1/recipes/ci/glob2_1610991677669/work
# gmaps==0.9.0
# greenlet @ file:///C:/ci/greenlet_1628888275363/work
# h5py @ file:///C:/ci/h5py_1622088609188/work
# HeapDict @ file:///Users/ktietz/demo/mc3/conda-bld/heapdict_1630598515714/work
# html5lib @ file:///Users/ktietz/demo/mc3/conda-bld/html5lib_1629144453894/work
# idna @ file:///tmp/build/80754af9/idna_1622654382723/work
# imagecodecs @ file:///C:/ci/imagecodecs_1635511087451/work
# imageio @ file:///tmp/build/80754af9/imageio_1617700267927/work
# imagesize @ file:///Users/ktietz/demo/mc3/conda-bld/imagesize_1628863108022/work
# importlib-metadata @ file:///C:/ci/importlib-metadata_1631916826748/work
# inflection==0.5.1
# iniconfig @ file:///home/linux1/recipes/ci/iniconfig_1610983019677/work
# intervaltree @ file:///Users/ktietz/demo/mc3/conda-bld/intervaltree_1630511889664/work
# ipykernel @ file:///C:/ci/ipykernel_1633545585502/work/dist/ipykernel-6.4.1-py3-none-any.whl
# ipython @ file:///C:/ci/ipython_1635944283918/work
# ipython-genutils @ file:///tmp/build/80754af9/ipython_genutils_1606773439826/work
# ipywidgets @ file:///tmp/build/80754af9/ipywidgets_1634143127070/work
# isort @ file:///tmp/build/80754af9/isort_1628603791788/work
# itsdangerous @ file:///tmp/build/80754af9/itsdangerous_1621432558163/work
# jdcal @ file:///Users/ktietz/demo/mc3/conda-bld/jdcal_1630584345063/work
# jedi @ file:///C:/ci/jedi_1611341083684/work
# Jinja2 @ file:///tmp/build/80754af9/jinja2_1612213139570/work
# jinja2-time @ file:///tmp/build/80754af9/jinja2-time_1617751524098/work
# joblib @ file:///tmp/build/80754af9/joblib_1635411271373/work
# json5 @ file:///tmp/build/80754af9/json5_1624432770122/work
# jsonschema @ file:///Users/ktietz/demo/mc3/conda-bld/jsonschema_1630511932244/work
# jupyter @ file:///C:/ci/jupyter_1607685287094/work
# jupyter-client @ file:///tmp/build/80754af9/jupyter_client_1616770841739/work
# jupyter-console @ file:///tmp/build/80754af9/jupyter_console_1616615302928/work
# jupyter-core @ file:///C:/ci/jupyter_core_1633420716440/work
# jupyter-server @ file:///C:/ci/jupyter_server_1616084298419/work
# jupyterlab @ file:///tmp/build/80754af9/jupyterlab_1635799997693/work
# jupyterlab-pygments @ file:///tmp/build/80754af9/jupyterlab_pygments_1601490720602/work
# jupyterlab-server @ file:///tmp/build/80754af9/jupyterlab_server_1633419203660/work
# jupyterlab-widgets @ file:///tmp/build/80754af9/jupyterlab_widgets_1609884341231/work
# kdtree==0.16
# keyring @ file:///C:/ci/keyring_1629321702436/work
# kiwisolver @ file:///C:/ci/kiwisolver_1612282555033/work
# lazy-object-proxy @ file:///C:/ci/lazy-object-proxy_1616529288960/work
# libarchive-c @ file:///tmp/build/80754af9/python-libarchive-c_1617780486945/work
# llvmlite==0.37.0
# locket==0.2.1
# lxml @ file:///C:/ci/lxml_1616443418777/work
# MarkupSafe @ file:///C:/ci/markupsafe_1607027406824/work
# matplotlib @ file:///C:/ci/matplotlib-suite_1634667159685/work
# matplotlib-inline @ file:///tmp/build/80754af9/matplotlib-inline_1628242447089/work
# mccabe==0.6.1
# menuinst @ file:///C:/ci/menuinst_1631733438520/work
# mistune @ file:///C:/ci/mistune_1607359457024/work
# mkl-fft==1.3.1
# mkl-random @ file:///C:/ci/mkl_random_1626186184308/work
# mkl-service==2.4.0
# mock @ file:///tmp/build/80754af9/mock_1607622725907/work
# more-itertools @ file:///tmp/build/80754af9/more-itertools_1635423142362/work
# mpmath==1.2.1
# msgpack @ file:///C:/ci/msgpack-python_1612287350784/work
# multipledispatch @ file:///C:/ci/multipledispatch_1607574329826/work
# munkres==1.1.4
# mypy-extensions==0.4.3
# mysql-connector-python==8.0.27
# navigator-updater==0.2.1
# nbclassic @ file:///tmp/build/80754af9/nbclassic_1616085367084/work
# nbclient @ file:///tmp/build/80754af9/nbclient_1614364831625/work
# nbconvert @ file:///C:/ci/nbconvert_1624479160025/work
# nbformat @ file:///tmp/build/80754af9/nbformat_1617383369282/work
# nest-asyncio @ file:///tmp/build/80754af9/nest-asyncio_1613680548246/work
# networkx @ file:///tmp/build/80754af9/networkx_1633639043937/work
# nltk==3.6.5
# nose @ file:///tmp/build/80754af9/nose_1606773131901/work
# notebook @ file:///C:/ci/notebook_1635393701545/work
# numba @ file:///C:/ci/numba_1635186062888/work
# numexpr @ file:///C:/ci/numexpr_1618856728739/work
# numpy @ file:///C:/ci/numpy_and_numpy_base_1626271900803/work
# numpydoc @ file:///tmp/build/80754af9/numpydoc_1605117425582/work
# olefile @ file:///Users/ktietz/demo/mc3/conda-bld/olefile_1629805411829/work
# openpyxl @ file:///tmp/build/80754af9/openpyxl_1632777717936/work
# packaging @ file:///tmp/build/80754af9/packaging_1625611678980/work
# pandas @ file:///C:/ci/pandas_1635506685681/work
# pandocfilters @ file:///C:/ci/pandocfilters_1605114832805/work
# paramiko @ file:///tmp/build/80754af9/paramiko_1598886428689/work
# parso @ file:///tmp/build/80754af9/parso_1617223946239/work
# partd @ file:///tmp/build/80754af9/partd_1618000087440/work
# path @ file:///C:/ci/path_1624287837534/work
# pathlib2 @ file:///C:/ci/pathlib2_1625585796814/work
# pathspec==0.7.0
# patsy==0.5.2
# pep8==1.7.1
# pexpect @ file:///tmp/build/80754af9/pexpect_1605563209008/work
# pickleshare @ file:///tmp/build/80754af9/pickleshare_1606932040724/work
# Pillow==8.4.0
# pkginfo==1.7.1
# pluggy @ file:///C:/ci/pluggy_1615976440052/work
# ply==3.11
# poyo @ file:///tmp/build/80754af9/poyo_1617751526755/work
# prometheus-client @ file:///tmp/build/80754af9/prometheus_client_1623189609245/work
# prompt-toolkit @ file:///tmp/build/80754af9/prompt-toolkit_1633440160888/work
# psutil @ file:///C:/ci/psutil_1612298199233/work
# ptyprocess @ file:///tmp/build/80754af9/ptyprocess_1609355006118/work/dist/ptyprocess-0.7.0-py2.py3-none-any.whl
# py @ file:///tmp/build/80754af9/py_1607971587848/work
# pycodestyle @ file:///tmp/build/80754af9/pycodestyle_1615748559966/work
# pycosat==0.6.3
# pycparser @ file:///tmp/build/80754af9/pycparser_1594388511720/work
# pycurl==7.44.1
# pydocstyle @ file:///tmp/build/80754af9/pydocstyle_1621600989141/work
# pyerfa @ file:///C:/ci/pyerfa_1621560974055/work
# pyflakes @ file:///tmp/build/80754af9/pyflakes_1617200973297/work
# Pygments @ file:///tmp/build/80754af9/pygments_1629234116488/work
# PyJWT @ file:///C:/ci/pyjwt_1619682721924/work
# pylint @ file:///C:/ci/pylint_1627536884966/work
# pyls-spyder==0.4.0
# PyNaCl @ file:///C:/ci/pynacl_1607612759007/work
# pyodbc===4.0.0-unsupported
# pyOpenSSL @ file:///tmp/build/80754af9/pyopenssl_1635333100036/work
# pyparsing @ file:///tmp/build/80754af9/pyparsing_1635766073266/work
# pyreadline==2.1
# pyrsistent @ file:///C:/ci/pyrsistent_1636093225342/work
# PySocks @ file:///C:/ci/pysocks_1605307512533/work
# pytest==6.2.4
# python-dateutil @ file:///tmp/build/80754af9/python-dateutil_1626374649649/work
# python-lsp-black @ file:///tmp/build/80754af9/python-lsp-black_1634232156041/work
# python-lsp-jsonrpc==1.0.0
# python-lsp-server==1.2.4
# python-slugify @ file:///tmp/build/80754af9/python-slugify_1620405669636/work
# pytz==2021.3
# PyWavelets @ file:///C:/ci/pywavelets_1607645631519/work
# pywin32==228
# pywin32-ctypes @ file:///C:/ci/pywin32-ctypes_1607553594546/work
# pywinpty @ file:///C:/ci/pywinpty_1607419945780/work
# PyYAML==6.0
# pyzmq @ file:///C:/ci/pyzmq_1628276105793/work
# QDarkStyle @ file:///tmp/build/80754af9/qdarkstyle_1617386714626/work
# qstylizer @ file:///tmp/build/80754af9/qstylizer_1617713584600/work/dist/qstylizer-0.1.10-py2.py3-none-any.whl
# QtAwesome @ file:///tmp/build/80754af9/qtawesome_1615991616277/work
# qtconsole @ file:///tmp/build/80754af9/qtconsole_1632739723211/work
# QtPy @ file:///tmp/build/80754af9/qtpy_1629397026935/work
# regex @ file:///C:/ci/regex_1628063427816/work
# requests @ file:///tmp/build/80754af9/requests_1629994808627/work
# rope @ file:///tmp/build/80754af9/rope_1623703006312/work
# Rtree @ file:///C:/ci/rtree_1618421015405/work
# ruamel-yaml-conda @ file:///C:/ci/ruamel_yaml_1616016898638/work
# scikit-image==0.18.3
# scikit-learn @ file:///C:/ci/scikit-learn_1622739499047/work
# scikit-learn-intelex==2021.20210714.120553
# scipy @ file:///C:/ci/scipy_1630606917240/work
# seaborn @ file:///tmp/build/80754af9/seaborn_1629307859561/work
# Send2Trash @ file:///tmp/build/80754af9/send2trash_1632406701022/work
# simplegeneric==0.8.1
# singledispatch @ file:///tmp/build/80754af9/singledispatch_1629321204894/work
# sip==4.19.13
# six @ file:///tmp/build/80754af9/six_1623709665295/work
# sniffio @ file:///C:/ci/sniffio_1614030527509/work
# snowballstemmer @ file:///tmp/build/80754af9/snowballstemmer_1611258885636/work
# sortedcollections @ file:///tmp/build/80754af9/sortedcollections_1611172717284/work
# sortedcontainers @ file:///tmp/build/80754af9/sortedcontainers_1623949099177/work
# soupsieve @ file:///tmp/build/80754af9/soupsieve_1616183228191/work
# Sphinx==4.2.0
# sphinxcontrib-applehelp @ file:///home/ktietz/src/ci/sphinxcontrib-applehelp_1611920841464/work
# sphinxcontrib-devhelp @ file:///home/ktietz/src/ci/sphinxcontrib-devhelp_1611920923094/work
# sphinxcontrib-htmlhelp @ file:///tmp/build/80754af9/sphinxcontrib-htmlhelp_1623945626792/work
# sphinxcontrib-jsmath @ file:///home/ktietz/src/ci/sphinxcontrib-jsmath_1611920942228/work
# sphinxcontrib-qthelp @ file:///home/ktietz/src/ci/sphinxcontrib-qthelp_1611921055322/work
# sphinxcontrib-serializinghtml @ file:///tmp/build/80754af9/sphinxcontrib-serializinghtml_1624451540180/work
# sphinxcontrib-websupport @ file:///tmp/build/80754af9/sphinxcontrib-websupport_1597081412696/work
# spyder @ file:///C:/ci/spyder_1636480369575/work
# spyder-kernels @ file:///C:/ci/spyder-kernels_1634237096710/work
# SQLAlchemy @ file:///C:/ci/sqlalchemy_1626948551162/work
# statsmodels==0.12.2
# sympy @ file:///C:/ci/sympy_1635219088507/work
# tables==3.6.1
# TBB==0.2
# tblib @ file:///Users/ktietz/demo/mc3/conda-bld/tblib_1629402031467/work
# terminado==0.9.4
# testpath @ file:///tmp/build/80754af9/testpath_1624638946665/work
# text-unidecode @ file:///Users/ktietz/demo/mc3/conda-bld/text-unidecode_1629401354553/work
# textdistance @ file:///tmp/build/80754af9/textdistance_1612461398012/work
# threadpoolctl @ file:///Users/ktietz/demo/mc3/conda-bld/threadpoolctl_1629802263681/work
# three-merge @ file:///tmp/build/80754af9/three-merge_1607553261110/work
# tifffile @ file:///tmp/build/80754af9/tifffile_1627275862826/work
# tinycss @ file:///tmp/build/80754af9/tinycss_1617713798712/work
# toml @ file:///tmp/build/80754af9/toml_1616166611790/work
# toolz @ file:///home/linux1/recipes/ci/toolz_1610987900194/work
# tornado @ file:///C:/ci/tornado_1606924294691/work
# tqdm @ file:///tmp/build/80754af9/tqdm_1635330843403/work
# traitlets @ file:///tmp/build/80754af9/traitlets_1632522747050/work
# typed-ast @ file:///C:/ci/typed-ast_1624953797214/work
# typing-extensions @ file:///tmp/build/80754af9/typing_extensions_1631814937681/work
# ujson @ file:///C:/ci/ujson_1611259568517/work
# unicodecsv==0.14.1
# Unidecode @ file:///tmp/build/80754af9/unidecode_1614712377438/work
# urllib3==1.26.7
# watchdog @ file:///C:/ci/watchdog_1624955113064/work
# wcwidth @ file:///Users/ktietz/demo/mc3/conda-bld/wcwidth_1629357192024/work
# webencodings==0.5.1
# Werkzeug @ file:///tmp/build/80754af9/werkzeug_1635505089296/work
# whichcraft @ file:///tmp/build/80754af9/whichcraft_1617751293875/work
# widgetsnbextension @ file:///C:/ci/widgetsnbextension_1607531582688/work
# win-inet-pton @ file:///C:/ci/win_inet_pton_1605306162074/work
# win-unicode-console==0.5
# wincertstore==0.2
# wrapt @ file:///C:/ci/wrapt_1607574570428/work
# xlrd @ file:///tmp/build/80754af9/xlrd_1608072521494/work
# XlsxWriter @ file:///tmp/build/80754af9/xlsxwriter_1628603415431/work
# xlwings==0.24.9
# xlwt==1.3.0
# xmltodict @ file:///Users/ktietz/demo/mc3/conda-bld/xmltodict_1629301980723/work
# yapf @ file:///tmp/build/80754af9/yapf_1615749224965/work
# zict==2.0.0
# zipp @ file:///tmp/build/80754af9/zipp_1633618647012/work
# zope.event==4.5.0
# zope.interface @ file:///C:/ci/zope.interface_1625036252485/work
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\kelvi\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\kelvi\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
class City:
    '''
    City wraps up the info about a city, including its name, coordinates,
    and belonging country.
    '''
    def __init__(self, city_name, country_code):
        self.city_name = city_name
        
        
        self.country_code = country_code

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# bluff nz
# norman wells ca
# saskylakh ru
# saskylakh ru
# chake chake tz
# hithadhoo mv
# tuktoyaktuk ca
# evanston us
# amderma ru
# saint-philippe re
# bereda so
# iqaluit ca
# novikovo ru
# grand gaube mu
# san pedro ar
# cidreira br
# miri my
# rikitea pf
# kapaa us
# aasiaat gl
# klaksvik fo
# laguna br
# grand river south east mu
# upernavik gl
# bluff nz
# yellowknife ca
# hithadhoo mv
# hermanus za
# nanakuli us
# aktau kz
# tsihombe mg
# kruisfontein za
# katsuura jp
# yellowknife ca
# rikitea pf
# rikitea pf
# arlit ne
# punta arenas cl
# amapa br
# mahibadhoo mv
# upernavik gl
# vaini to
# puerto ayora ec
# punta arenas cl
# busselton au
# new norfolk au
# bluff nz
# jamestown sh
# ewa beach us
# vaitupu wf
# mataura pf
# bluff nz
# cape town za
# kirakira sb
# rikitea pf
# kieta pg
# malwan in
# lompoc us
# kendari id
# barrow us
# port hardy ca
# hilo us
# susuman ru
# cape town za
# georgetown sh
# ushuaia ar
# tiksi ru
# avarua ck
# cabo san lucas mx
# victoria sc
# yumbel cl
# blois fr
# busselton au
# galesong id
# kargasok ru
# busselton au
# albany au
# barrow us
# arraial do cabo br
# rikitea pf
# atuona pf
# punta arenas cl
# narsaq gl
# vao nc
# carnarvon za
# kapaa us
# victoria point au
# bengkulu id
# butaritari ki
# lagoa pt
# bluff nz
# sao miguel do araguaia br
# beloha mg
# jamestown sh
# hoquiam us
# port keats au
# san andres co
# cape town za
# pouebo nc
# victoria sc
# tezu in
# gopalganj in
# cap malheureux mu
# georgetown sh
# bambous virieux mu
# chokurdakh ru
# taolanaro mg
# esfarayen ir
# illoqqortoormiut gl
# taolanaro mg
# les cayes ht
# albany au
# tuatapere nz
# namibe ao
# ambon id
# mandalgovi mn
# coquimbo cl
# ushuaia ar
# victoria sc
# busselton au
# vaini to
# cherskiy ru
# leningradskiy ru
# belushya guba ru
# salalah om
# saskylakh ru
# ushuaia ar
# hermanus za
# kavaratti in
# san antonio cl
# ostrovnoy ru
# truckee us
# kostomuksha ru
# hobart au
# punta arenas cl
# diamantino br
# puerto ayora ec
# mataura pf
# camacha pt
# qaanaaq gl
# derzhavinsk kz
# ushuaia ar
# taolanaro mg
# mataura pf
# ambulu id
# mandalgovi mn
# cape town za
# soyo ao
# avera pf
# lewisporte ca
# kodiak us
# mys shmidta ru
# nichlaul in
# new norfolk au
# butaritari ki
# kapaa us
# two rivers us
# atuona pf
# kupang id
# tasiilaq gl
# lebu cl
# punta arenas cl
# tasiilaq gl
# atuona pf
# taolanaro mg
# kedgwick ca
# koshurnikovo ru
# cape town za
# saint george bm
# tabialan ph
# ushuaia ar
# busselton au
# quesnel ca
# hohhot cn
# ribeira grande pt
# tazovskiy ru
# lagoa pt
# butaritari ki
# rungata ki
# barrow us
# butaritari ki
# barentsburg sj
# butaritari ki
# bengkulu id
# busselton au
# upernavik gl
# samarai pg
# belturbet ie
# saint-philippe re
# dikson ru
# nome us
# vaini to
# rikitea pf
# sarhari pk
# bayeux fr
# rikitea pf
# soyo ao
# albany au
# vaini to
# albany au
# marawi sd
# ushuaia ar
# lompoc us
# jambi id
# ribeira grande pt
# punta arenas cl
# hermanus za
# mataura pf
# calera cl
# ballina ie
# mar del plata ar
# rikitea pf
# ushuaia ar
# vaitupu wf
# eirunepe br
# najran sa
# bengkulu id
# lata sb
# cockburn town tc
# lebu cl
# namibe ao
# marcona pe
# mahebourg mu
# mar del plata ar
# mackay au
# nizhneyansk ru
# lompoc us
# krasne ua
# chuy uy
# caravelas br
# ushuaia ar
# saryshagan kz
# alofi nu
# canakkale tr
# sitka us
# vardo no
# thompson ca
# naze jp
# amderma ru
# mar del plata ar
# lata sb
# college us
# acapulco mx
# busselton au
# kodiak us
# busselton au
# vaini to
# carai br
# kieta pg
# kapaa us
# semme sn
# ciudad bolivar ve
# road town vg
# bluff nz
# angoche mz
# puerto ayora ec
# yulara au
# bilibino ru
# petropavlovsk-kamchatskiy ru
# castro cl
# mar del plata ar
# east london za
# clyde river ca
# nanortalik gl
# hermanus za
# albany au
# ushuaia ar
# kapaa us
# naze jp
# tarakan id
# saskylakh ru
# hobart au
# xinzhi cn
# ryotsu jp
# kapaa us
# beloha mg
# kodiak us
# butaritari ki
# ushuaia ar
# castro cl
# quatre cocos mu
# albany au
# kapaa us
# bethel us
# albany au
# tsihombe mg
# atuona pf
# port alfred za
# hilo us
# gizo sb
# bako et
# busselton au
# busselton au
# ciras af
# amderma ru
# punta arenas cl
# sentyabrskiy ru
# mathbaria bd
# tasiilaq gl
# barrow us
# torbay ca
# atherton au
# vaini to
# bengkulu id
# hermanus za
# palabuhanratu id
# jamestown sh
# taolanaro mg
# asau tv
# tuktoyaktuk ca
# ishigaki jp
# jamestown sh
# sao filipe cv
# kapaa us
# ushuaia ar
# yellowknife ca
# ust-nera ru
# port lincoln au
# acarau br
# bredasdorp za
# atar mr
# lukovetskiy ru
# fairbanks us
# yellowknife ca
# panguna pg
# ushuaia ar
# gimli ca
# norman wells ca
# sitka us
# vaini to
# flinders au
# sitka us
# kontagora ng
# bluff nz
# walvis bay na
# new norfolk au
# punta arenas cl
# albany au
# carnarvon au
# barentsburg sj
# nikolskoye ru
# rikitea pf
# goias br
# cape town za
# punta arenas cl
# hobart au
# samusu ws
# albany au
# ouahigouya bf
# bambous virieux mu
# thai binh vn
# presidencia roque saenz pena ar
# port moresby pg
# sitka us
# hobart au
# provideniya ru
# butaritari ki
# aripuana br
# punta arenas cl
# albany au
# albany au
# puerto del rosario es
# bluff nz
# mataura pf
# hermanus za
# albany au
# hobart au
# vao nc
# sfantu gheorghe ro
# ushuaia ar
# erenhot cn
# rikitea pf
# faanui pf
# rundu na
# punta arenas cl
# urdzhar kz
# busselton au
# lorengau pg
# arkhangelsk ru
# leeton au
# pochutla mx
# saint-pierre pm
# mehamn no
# tukrah ly
# peterhead gb
# saryozek kz
# lubango ao
# illoqqortoormiut gl
# ponta do sol pt
# punta arenas cl
# taolanaro mg
# satitoa ws
# mahebourg mu
# kapaa us
# vila franca do campo pt
# acapulco mx
# arraial do cabo br
# vardo no
# roma au
# constitucion mx
# kodiak us
# sobolevo ru
# tomatlan mx
# boysun uz
# rikitea pf
# hermanus za
# barrow us
# balykshi kz
# yellowknife ca
# san rafael ar
# touros br
# mahebourg mu
# vaini to
# bluff nz
# hvammstangi is
# nuevo cuscatlan sv
# busselton au
# grand river south east mu
# rikitea pf
# clyde river ca
# alenquer br
# mamaku nz
# chokurdakh ru
# jamestown sh
# barrow us
# carnarvon au
# lagoa pt
# barentsburg sj
# etchoropo mx
# keffi ng
# zyryanka ru
# ilulissat gl
# bonthe sl
# nemuro jp
# upernavik gl
# mahebourg mu
# hermanus za
# busselton au
# busselton au
# beloha mg
# suntar ru
# albany au
# amderma ru
# necochea ar
# cape town za
# hobart au
# yellowknife ca
# hobart au
# waipawa nz
# rikitea pf
# praia cv
# hermanus za
# huarmey pe
# nome us
# albany au
# saint anthony ca
# torbay ca
# vestmannaeyjar is
# hilo us
# butaritari ki
# punta arenas cl
# illoqqortoormiut gl
# bambous virieux mu
# saskylakh ru
# rikitea pf
# wanning cn
# hobart au
# pevek ru
# rikitea pf
# finschhafen pg
# cidreira br
# barentsburg sj
# albany au
# kushima jp
# banmankhi in
# puerto el triunfo sv
# new norfolk au
# traverse city us
# port alfred za
# rikitea pf
# pasinler tr
# atuona pf
# mandalgovi mn
# hermanus za
# jamestown sh
# cape town za
# rio grande br
# chlorakas cy
# ushuaia ar
# atuona pf
# kabare cd
# chernyshevskiy ru
# te anau nz
# korla cn
# yunjinghong cn
# the valley ai
# pringsewu id
# yulara au
# attawapiskat ca
# grand river south east mu
# san ramon bo
# bethel us
# kapaa us
# podor sn
# rikitea pf
# rikitea pf
# nilopolis br
# necochea ar
# rikitea pf
# mataura pf
# mar del plata ar
# taolanaro mg
# thunder bay ca
# illoqqortoormiut gl
# lorengau pg
# eskasem af
# soeng sang th
# saskylakh ru
# busselton au
# rikitea pf
# cherskiy ru
# talaya ru
# port alfred za
# pevek ru
# cabo san lucas mx
# tricase it
# bar harbor us
# mar del plata ar
# busselton au
# taolanaro mg
# castro cl
# surt ly
# torbay ca
# ushuaia ar
# dunn us
# mataura pf
# springfield us
# nisia floresta br
# cape town za
# bluff nz
# avera pf
# ikom ng
# clyde river ca
# vaini to
# zhigansk ru
# busselton au
# atuona pf
# fairbanks us
# dezhou cn
# hobart au
# punta arenas cl
# balikpapan id
# port hedland au
# castro cl
# ushuaia ar
# bridgetown ca
# novoagansk ru
# arraial do cabo br
# taolanaro mg
# beaverlodge ca
# havelock us
# shetpe kz
# teguldet ru
# mar del plata ar
# bubaque gw
# brisbane au
# rikitea pf
# nylstroom za
# illoqqortoormiut gl
# mahebourg mu
# yellowknife ca
# torbay ca
# ushuaia ar
# nikolskoye ru
# nea peramos gr
# portland au
# busselton au
# amaraji br
# progreso mx
# jalpan mx
# zhicheng cn
# ushuaia ar
# mataura pf
# colares pt
# bengkulu id
# tasiilaq gl
# rikitea pf
# mahebourg mu
# yumen cn
# cocobeach ga
# airai pw
# eyl so
# am timan td
# kodiak us
# kapaa us
# hobart au
# hilo us
# cairns au
# bengkulu id
# georgetown sh
# hamina fi
# cherskiy ru
# busselton au
# chokurdakh ru
# pinega ru
# qaanaaq gl
# mount isa au
# teguise es
# chajul gt
# hun ly
# khatanga ru
# carrollton us
# avarua ck
# zhigansk ru
# aklavik ca
# baijiantan cn
# haines junction ca
# hermanus za
# kaitangata nz
# deputatskiy ru
# jamestown sh
# hermanus za
# albany au
# kapaa us
# najran sa
# kpandae gh
# barentsburg sj
# hobart au
# rikitea pf
# esperance au
# kesennuma jp
# kodiak us
# atuona pf
# mataura pf
# cape town za
# port elizabeth za
# rikitea pf
# cape town za
# castro cl
# markala ml
# mataura pf
# rikitea pf
# hilo us
# matara lk
# victoria sc
# meulaboh id
# bengkulu id
# namibe ao
# puerto ayora ec
# hilo us
# tuktoyaktuk ca
# illoqqortoormiut gl
# lolua tv
# clyde river ca
# saleaula ws
# kapaa us
# hilo us
# mar del plata ar
# herat af
# arraial do cabo br
# carbonear ca
# tabas ir
# belyy yar ru
# butaritari ki
# hilo us
# mar del plata ar
# atuona pf
# temyasovo ru
# bluff nz
# north bend us
# rovaniemi fi
# saleaula ws
# port hedland au
# oranjemund na
# xining cn
# hilo us
# cascais pt
# hermanus za
# rikitea pf
# khabary ru
# hovd mn
# rikitea pf
# viedma ar
# faya td
# atuona pf
# tarakan id
# kruisfontein za
# torbay ca
# obigarm tj
# punta arenas cl
# hobart au
# ushuaia ar
# mar del plata ar
# punta arenas cl
# dengzhou cn
# novoagansk ru
# sokolo ml
# mbanza-ngungu cd
# souillac mu
# khatanga ru
# belushya guba ru
# puerto ayora ec
# punta arenas cl
# punta arenas cl
# cabo san lucas mx
# punta arenas cl
# prince rupert ca
# ushuaia ar
# olafsvik is
# tsihombe mg
# klaksvik fo
# saint-philippe re
# puerto madryn ar
# albany au
# soyo ao
# mount gambier au
# bluff nz
# hobbs us
# port hedland au
# ribeira grande pt
# voh nc
# rikitea pf
# bredasdorp za
# mataura pf
# rikitea pf
# laguna br
# pevek ru
# atar mr
# nikolskoye ru
# bluff nz
# baishishan cn
# mataura pf
# alofi nu
# baykit ru
# ylojarvi fi
# uberlandia br
# rabo de peixe pt
# klaksvik fo
# rikitea pf
# tuatapere nz
# skjervoy no
# matamoros mx
# punta arenas cl
# saint-philippe re
# upernavik gl
# cap malheureux mu
# dunedin nz
# albany au
# coihaique cl
# hobart au
# lorengau pg
# oktyabrskoye ru
# puerto ayora ec
# taolanaro mg
# chuy uy
# mys shmidta ru
# formoso do araguaia br
# busselton au
# samusu ws
# chuy uy
# patamundai in
# port hedland au
# beringovskiy ru
# avarua ck
# jiaohe cn
# tuktoyaktuk ca
# lebu cl
# saskylakh ru
# bengkulu id
# rikitea pf
# ribeira grande pt
# east london za
# jamestown sh
# jomalig ph
# mataura pf
# kapaa us
# tecoanapa mx
# codrington ag
# arcata us
# batemans bay au
# mataura pf
# qaanaaq gl
# beyneu kz
# beloha mg
# venado tuerto ar
# iqaluit ca
# marcona pe
# mataura pf
# codrington ag
# saint-georges gf
# georgetown sh
# mahebourg mu
# busselton au
# chara ru
# bubaque gw
# quelimane mz
# kapaa us
# umzimvubu za
# saldanha za
# awbari ly
# hobart au
# dillon us
# luocheng cn
# belushya guba ru
# mys shmidta ru
# bluff nz
# hermanus za
# rikitea pf
# jamestown sh
# fortuna us
# cidreira br
# saint-philippe re
# durban za
# guarapari br
# hofn is
# port alfred za
# butaritari ki
# nanortalik gl
# port alfred za
# dano bf
# ushuaia ar
# makakilo city us
# ronne dk
# chuy uy
# ndele cf
# hilo us
# cape town za
# hasaki jp
# waipawa nz
# yellowknife ca
# tasiilaq gl
# mataura pf
# bilibino ru
# khatanga ru
# seymchan ru
# hermanus za
# jurm af
# zhuhai cn
# ushuaia ar
# phek in
# qaanaaq gl
# mecca sa
# mar del plata ar
# castro cl
# yarmouth ca
# taolanaro mg
# gukovo ru
# ushuaia ar
# zaranj af
# barentsburg sj
# maneromango tz
# arraial do cabo br
# abu samrah qa
# albany au
# aosta it
# vila velha br
# viedma ar
# qaanaaq gl
# carnarvon au
# jamestown sh
# cape town za
# mataura pf
# bluff nz
# albany au
# jamestown sh
# mar del plata ar
# mehamn no
# port-gentil ga
# nushki pk
# husavik is
# ulladulla au
# hermanus za
# jinchengjiang cn
# denpasar id
# sabang id
# cape town za
# saskylakh ru
# vao nc
# ouallam ne
# tura ru
# albany au
# ponta do sol cv
# puerto ayora ec
# new norfolk au
# barentsburg sj
# lasa cn
# kahului us
# bredasdorp za
# albany au
# rawson ar
# margate za
# hami cn
# mataura pf
# tidore id
# tasiilaq gl
# pevek ru
# sioux lookout ca
# druzhba ua
# cao bang vn
# punta arenas cl
# voi ke
# qaanaaq gl
# eldikan ru
# rikitea pf
# norman wells ca
# kapaa us
# puerto leguizamo co
# provideniya ru
# hermanus za
# ahipara nz
# rupert us
# okha ru
# erzin ru
# punta arenas cl
# pacific grove us
# veraval in
# jamestown sh
# saskylakh ru
# san quintin mx
# sobolevo ru
# saleaula ws
# vaini to
# dalbandin pk
# severo-kurilsk ru
# jamestown sh
# hobart au
# calbuco cl
# rikitea pf
# hobart au
# zhaozhou cn
# novaya chigla ru
# thompson ca
# san luis cu
# tumannyy ru
# busselton au
# mataura pf
# la ronge ca
# ushuaia ar
# inhambane mz
# castro cl
# tyrma ru
# chuy uy
# grand gaube mu
# taolanaro mg
# puerto ayora ec
# olafsvik is
# thompson ca
# castro cl
# saint-francois gp
# beyneu kz
# rikitea pf
# ribeira brava pt
# illoqqortoormiut gl
# tres picos mx
# tilichiki ru
# faanui pf
# jamestown sh
# half moon bay us
# vicksburg us
# wlodawa pl
# belyy yar ru
# vaini to
# hobart au
# ilulissat gl
# vila franca do campo pt
# east london za
# port elizabeth za
# hilo us
# valparaiso cl
# bluff nz
# bonwapitse bw
# puerto ayora ec
# anyama ci
# saldanha za
# vaini to
# general roca ar
# tabou ci
# clyde river ca
# grand river south east mu
# gardan diwal af
# darhan mn
# taolanaro mg
# ushuaia ar
# avarua ck
# hermanus za
# punta arenas cl
# ushuaia ar
# katsuura jp
# new norfolk au
# illoqqortoormiut gl
# sorvag fo
# carnarvon au
# coffs harbour au
# mar del plata ar
# aflu dz
# belushya guba ru
# carnarvon au
# kaitangata nz
# hilo us
# taolanaro mg
# karasburg na
# sungairaya id
# chuy uy
# coihueco cl
# klaksvik fo
# hwange zw
# bredasdorp za
# rikitea pf
# anton lizardo mx
# busselton au
# severo-kurilsk ru
# megion ru
# shubarkuduk kz
# mataura pf
# nogales us
# tumannyy ru
# kapaa us
# bredasdorp za
# bluff nz
# rikitea pf
# fortuna us
# longyearbyen sj
# mataura pf
# ushuaia ar
# port alfred za
# buique br
# el colomo mx
# lagoa pt
# rikitea pf
# qaanaaq gl
# maceio br
# wanning cn
# talara pe
# katherine au
# flin flon ca
# bluff nz
# oum hadjer td
# vaini to
# mataura pf
# ushuaia ar
# kodiak us
# rikitea pf
# namatanai pg
# kavieng pg
# lemesos cy
# harlingen nl
# provideniya ru
# cabo san lucas mx
# provideniya ru
# taoudenni ml
# cape town za
# guerrero negro mx
# nikolskoye ru
# kapaa us
# tasiilaq gl
# ushuaia ar
# mys shmidta ru
# iskandar uz
# egvekinot ru
# butaritari ki
# chokurdakh ru
# port alfred za
# erzin ru
# rikitea pf
# houma us
# lorengau pg
# waingapu id
# suzu jp
# rikitea pf
# chokurdakh ru
# sao filipe cv
# avarua ck
# butaritari ki
# severo-kurilsk ru
# kamaishi jp
# taolanaro mg
# bredasdorp za
# goure ne
# bluff nz
# yellowknife ca
# nizhneyansk ru
# bluff nz
# qaanaaq gl
# hermanus za
# bambous virieux mu
# port blair in
# irati br
# east london za
# new norfolk au
# busselton au
# inhambane mz
# yichang cn
# ushuaia ar
# vanavara ru
# saint-francois gp
# cape town za
# thompson ca
# vestmannaeyjar is
# punta arenas cl
# atuona pf
# cape town za
# clyde river ca
# kumano jp
# kamenka ru
# ushuaia ar
# besskorbnaya ru
# yulara au
# busselton au
# bluff nz
# pisco pe
# tasiilaq gl
# beyneu kz
# carnarvon au
# grand-santi gf
# chiscas co
# zhigansk ru
# albany au
# punta arenas cl
# narsaq gl
# sitka us
# busselton au
# saint-philippe re
# bredasdorp za
# qaqortoq gl
# avarua ck
# cabo san lucas mx
# rikitea pf
# avarua ck
# impfondo cg
# new norfolk au
# jamestown sh
# eyl so
# punta arenas cl
# clyde river ca
# copiapo cl
# axim gh
# rikitea pf
# hobart au
# east london za
# elko us
# cayenne gf
# andahuaylas pe
# carnarvon au
# cape town za
# longyearbyen sj
# clyde river ca
# chuy uy
# cabedelo br
# nizhneyansk ru
# mataura pf
# san cristobal ec
# ostrovnoy ru
# isangel vu
# illoqqortoormiut gl
# guerrero negro mx
# jamestown sh
# barentsburg sj
# ribeira grande pt
# port alfred za
# duz tn
# saskylakh ru
# chuy uy
# villanueva co
# vaini to
# riyadh sa
# great falls us
# albany au
# grindavik is
# hilo us
# haines junction ca
# lewistown us
# barrow us
# yar-sale ru
# port macquarie au
# mataura pf
# vaitape pf
# aklavik ca
# new norfolk au
# yellowknife ca
# busselton au
# vaini to
# noumea nc
# olinda br
# lata sb
# bredasdorp za
# adrar dz
# nizhneyansk ru
# jamestown sh
# saleaula ws
# mzimba mw
# tuktoyaktuk ca
# victoria sc
# castro cl
# moskovskiy ru
# new norfolk au
# progreso mx
# nikolskoye ru
# taolanaro mg
# vaini to
# beni mazar eg
# svirstroy ru
# khatanga ru
# albany au
# avarua ck
# dunedin nz
# hermanus za
# codrington ag
# hilo us
# atuona pf
# upernavik gl
# punta arenas cl
# mys shmidta ru
# busselton au
# ushuaia ar
# taolanaro mg
# janakkala fi
# bredasdorp za
# honiara sb
# sorong id
# busselton au
# te anau nz
# port alfred za
# barentsburg sj
# caravelas br
# lorengau pg
# cape town za
# saint-ambroise ca
# jamestown sh
# avarua ck
# miranda br
# taolanaro mg
# saskylakh ru
# bluff nz
# bilibino ru
# belushya guba ru
# jamestown sh
# mandurah au
# barrow us
# dikson ru
# itaituba br
# tsihombe mg
# ushuaia ar
# berlevag no
# jamestown sh
# oudtshoorn za
# punta arenas cl
# mar del plata ar
# gafanha da encarnacao pt
# severo-kurilsk ru
# te anau nz
# odweyne so
# ashland us
# tasiilaq gl
# saskylakh ru
# makubetsu jp
# galiwinku au
# saint george bm
# ambalavao mg
# chipinge zw
# barentsburg sj
# atuona pf
# lebanon us
# palmer us
# nueva loja ec
# castro cl
# barrow us
# nabisar pk
# new norfolk au
# vaini to
# albany au
# ushuaia ar
# nikolskoye ru
# mataura pf
# bredasdorp za
# rikitea pf
# qaqortoq gl
# illoqqortoormiut gl
# tessalit ml
# avarua ck
# geraldton au
# norman wells ca
# fortuna foothills us
# wukari ng
# khatanga ru
# atuona pf
# hovd mn
# ushuaia ar
# punta arenas cl
# abu dhabi ae
# longyearbyen sj
# mayor pablo lagerenza py
# georgetown sh
# talcahuano cl
# zhitikara kz
# nanortalik gl
# ahipara nz
# norman wells ca
# novoanninskiy ru
# albany au
# tiksi ru
# palana ru
# qaqortoq gl
# geraldton au
# mangan in
# punta arenas cl
# touros br
# port alfred za
# amapala hn
# svetlogorsk ru
# bluff nz
# punta arenas cl
# ushuaia ar
# faanui pf
# cape town za
# louisbourg ca
# kruisfontein za
# jamestown sh
# barrow us
# torbay ca
# saint anthony ca
# atar mr
# nizhneyansk ru
# libertador general san martin ar
# pullman us
# soe id
# avarua ck
# hilo us
# hofn is
# dikson ru
# iqaluit ca
# tuktoyaktuk ca
# hobart au
# ukiah us
# ancud cl
# hermanus za
# rikitea pf
# atar mr
# lebu cl
# haines junction ca
# bluff nz
# kapaa us
# tuktoyaktuk ca
# vila velha br
# tuatapere nz
# georgetown sh
# ponta do sol cv
# biltine td
# mar del plata ar
# hermanus za
# omboue ga
# talavera pe
# barentsburg sj
# isangel vu
# bluff nz
# raga sd
# kahului us
# chokurdakh ru
# punta arenas cl
# mocambique mz
# saint george bm
# provideniya ru
# khatanga ru
# touba ci
# poum nc
# ushuaia ar
# portland au
# carnarvon au
# pervomayskoye ru
# dhidhdhoo mv
# cochrane ca
# severomorsk ru
# lavrentiya ru
# henties bay na
# thompson ca
# laguna br
# hasaki jp
# san patricio mx
# albany au
# edea cm
# hervey bay au
# tasiilaq gl
# punta arenas cl
# kapaa us
# amahai id
# sheffield lake us
# clinton us
# faya td
# vaini to
# faya td
# rikitea pf
# kavieng pg
# moose factory ca
# atuona pf
# meulaboh id
# avarua ck
# rikitea pf
# mafra br
# taolanaro mg
# srednekolymsk ru
# rikitea pf
# olafsvik is
# punta arenas cl
# mataura pf
# upernavik gl
# hobart au
# thompson ca
# young uy
# longyearbyen sj
# pangnirtung ca
# norman wells ca
# rikitea pf
# yulara au
# mataura pf
# carnarvon au
# yunjinghong cn
# illoqqortoormiut gl
# porto novo cv
# hobart au
# sistranda no
# vestmannaeyjar is
# iqaluit ca
# ushuaia ar
# saldanha za
# busselton au
# dunedin nz
# naze jp
# butaritari ki
# ilhabela br
# farafangana mg
# yeoryiani gr
# belushya guba ru
# yellowknife ca
# bredasdorp za
# nizhneyansk ru
# castro cl
# rikitea pf
# kemijarvi fi
# punta arenas cl
# adeje es
# mar del plata ar
# muzhi ru
# sistranda no
# fortuna us
# bandarbeyla so
# buraydah sa
# rikitea pf
# albany au
# avarua ck
# amderma ru
# nanchang cn
# ilulissat gl
# beringovskiy ru
# amderma ru
# belushya guba ru
# port alfred za
# saint-augustin ca
# jamestown sh
# clyde river ca
# ushuaia ar
# oriximina br
# dikson ru
# narsaq gl
# jamestown sh
# carballo es
# illoqqortoormiut gl
# lugovoy ru
# yellowknife ca
# minab ir
# chuy uy
# flinders au
# suslovo ru
# busselton au
# teya ru
# leningradskiy ru
# saskylakh ru
# manacapuru br
# mataura pf
# odienne ci
# barrow us
# hilo us
# bandarbeyla so
# mataura pf
# fortuna us
# schortens de
# toliary mg
# ushuaia ar
# atuona pf
# matameye ne
# taolanaro mg
# atar mr
# narsaq gl
# santa ana pe
# yellowknife ca
# havre-saint-pierre ca
# san cristobal ec
# ust-omchug ru
# busselton au
# newport us
# rikitea pf
# tiksi ru

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 617

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2a9169035ea6eb8c1b16a9de7e444748

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2a9169035ea6eb8c1b16a9de7e444748&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# call the response code with the get() method using the status_code
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":84.04,"feels_like":88.7,"temp_min":73.11,"temp_max":90.64,"pressure":1014,"humidity":64},"visibility":10000,"wind":{"speed":5.01,"deg":113,"gust":8.99},"clouds":{"all":100},"dt":1653161043,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1653124644,"sunset":1653177873},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 84.04,
#   'feels_like': 88.7,
#   'temp_min': 73.11,
#   'temp_max': 90.64,
#   'pressure': 1014,
#   'humidity': 64},
#  'visibility': 10000,
#  'wind': {'speed': 5.01, 'deg': 113, 'gust': 8.99},
#  'clouds': {'all': 100},
#  'dt': 1653161043,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1653124644,
#   'sunset': 1653177873},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Import the dependencies.
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
# Personal Practice
# new_city="Nairobi"

# %%
# Create an endpoint URL for a city.
# city_url = url + "&q=" + "Nairobi"
# city_weather = requests.get(city_url)
# city_weather

# %%
# Get the JSON text of the 'Get' request.
# city_weather.json()

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
 print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2a9169035ea6eb8c1b16a9de7e444748&q=Bston

# %%
# For each city in our lats_lngs list, we need to retrieve the following data and add it to a DataFrame:

# City, country, and date

# Latitude and longitude

# Maximum temperature

# Humidity

# Cloudiness

# Wind speed

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

city_weather = requests.get(city_url)

city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 84.04,
#   'feels_like': 88.7,
#   'temp_min': 73.11,
#   'temp_max': 90.64,
#   'pressure': 1014,
#   'humidity': 64},
#  'visibility': 10000,
#  'wind': {'speed': 5.01, 'deg': 113, 'gust': 8.99},
#  'clouds': {'all': 100},
#  'dt': 1653161043,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1653124644,
#   'sunset': 1653177873},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']["country"]
# Out:
# 'US'

# %%
boston_data['coord']['lat']
# Out:
# 42.3584

# %%
lat = boston_data["coord"]["lat"]

lng = boston_data["coord"]["lon"]

max_temp = boston_data["main"]["temp_max"]

humidity = boston_data["main"]["humidity"]

clouds = boston_data["clouds"]["all"]

wind = boston_data["wind"]["speed"]

print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 90.64 64 100 5.01

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Get the date from the JSON file.
date = boston_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 5, 21, 19, 24, 3)

# %%
# We can convert this datetime format to 2019-10-21 17:24:35 using the Python string format method strftime()
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-05-21 19:24:03'

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")

print("-----------------------------")

# Create counters.
record_count = 1

set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        record_count = 1
        
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | bluff
# Processing Record 2 of Set 13 | norman wells
# Processing Record 3 of Set 13 | saskylakh
# Processing Record 4 of Set 13 | chake chake
# Processing Record 5 of Set 13 | hithadhoo
# Processing Record 6 of Set 13 | tuktoyaktuk
# Processing Record 7 of Set 13 | evanston
# Processing Record 8 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 13 | saint-philippe
# Processing Record 10 of Set 13 | bereda
# Processing Record 11 of Set 13 | iqaluit
# Processing Record 12 of Set 13 | novikovo
# Processing Record 13 of Set 13 | grand gaube
# Processing Record 14 of Set 13 | san pedro
# Processing Record 15 of Set 13 | cidreira
# Processing Record 16 of Set 13 | miri
# Processing Record 17 of Set 13 | rikitea
# Processing Record 18 of Set 13 | kapaa
# Processing Record 19 of Set 13 | aasiaat
# Processing Record 20 of Set 13 | klaksvik
# Processing Record 21 of Set 13 | laguna
# Processing Record 22 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 13 | upernavik
# Processing Record 24 of Set 13 | yellowknife
# Processing Record 25 of Set 13 | hermanus
# Processing Record 26 of Set 13 | nanakuli
# Processing Record 27 of Set 13 | aktau
# Processing Record 28 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 13 | kruisfontein
# Processing Record 30 of Set 13 | katsuura
# Processing Record 31 of Set 13 | arlit
# Processing Record 32 of Set 13 | punta arenas
# Processing Record 33 of Set 13 | amapa
# Processing Record 34 of Set 13 | mahibadhoo
# Processing Record 35 of Set 13 | vaini
# Processing Record 36 of Set 13 | puerto ayora
# Processing Record 37 of Set 13 | busselton
# Processing Record 38 of Set 13 | new norfolk
# Processing Record 39 of Set 13 | jamestown
# Processing Record 40 of Set 13 | ewa beach
# Processing Record 41 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 13 | mataura
# Processing Record 43 of Set 13 | cape town
# Processing Record 44 of Set 13 | kirakira
# Processing Record 45 of Set 13 | kieta
# Processing Record 46 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 13 | lompoc
# Processing Record 48 of Set 13 | kendari
# Processing Record 49 of Set 13 | barrow
# Processing Record 50 of Set 13 | port hardy
# Processing Record 1 of Set 14 | hilo
# Processing Record 2 of Set 14 | susuman
# Processing Record 3 of Set 14 | georgetown
# Processing Record 4 of Set 14 | ushuaia
# Processing Record 5 of Set 14 | tiksi
# Processing Record 6 of Set 14 | avarua
# Processing Record 7 of Set 14 | cabo san lucas
# Processing Record 8 of Set 14 | victoria
# Processing Record 9 of Set 14 | yumbel
# Processing Record 10 of Set 14 | blois
# Processing Record 11 of Set 14 | galesong
# Processing Record 12 of Set 14 | kargasok
# Processing Record 13 of Set 14 | albany
# Processing Record 14 of Set 14 | arraial do cabo
# Processing Record 15 of Set 14 | atuona
# Processing Record 16 of Set 14 | narsaq
# Processing Record 17 of Set 14 | vao
# Processing Record 18 of Set 14 | carnarvon
# Processing Record 19 of Set 14 | victoria point
# Processing Record 20 of Set 14 | bengkulu
# Processing Record 21 of Set 14 | butaritari
# Processing Record 22 of Set 14 | lagoa
# Processing Record 23 of Set 14 | sao miguel do araguaia
# Processing Record 24 of Set 14 | beloha
# Processing Record 25 of Set 14 | hoquiam
# Processing Record 26 of Set 14 | port keats
# Processing Record 27 of Set 14 | san andres
# Processing Record 28 of Set 14 | pouebo
# Processing Record 29 of Set 14 | tezu
# Processing Record 30 of Set 14 | gopalganj
# Processing Record 31 of Set 14 | cap malheureux
# Processing Record 32 of Set 14 | bambous virieux
# Processing Record 33 of Set 14 | chokurdakh
# Processing Record 34 of Set 14 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 14 | esfarayen
# Processing Record 36 of Set 14 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 14 | les cayes
# Processing Record 38 of Set 14 | tuatapere
# Processing Record 39 of Set 14 | namibe
# Processing Record 40 of Set 14 | ambon
# Processing Record 41 of Set 14 | mandalgovi
# Processing Record 42 of Set 14 | coquimbo
# Processing Record 43 of Set 14 | cherskiy
# Processing Record 44 of Set 14 | leningradskiy
# Processing Record 45 of Set 14 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 14 | salalah
# Processing Record 47 of Set 14 | kavaratti
# Processing Record 48 of Set 14 | san antonio
# Processing Record 49 of Set 14 | ostrovnoy
# Processing Record 50 of Set 14 | truckee
# Processing Record 1 of Set 15 | kostomuksha
# Processing Record 2 of Set 15 | hobart
# Processing Record 3 of Set 15 | diamantino
# Processing Record 4 of Set 15 | camacha
# Processing Record 5 of Set 15 | qaanaaq
# Processing Record 6 of Set 15 | derzhavinsk
# Processing Record 7 of Set 15 | ambulu
# Processing Record 8 of Set 15 | soyo
# Processing Record 9 of Set 15 | avera
# Processing Record 10 of Set 15 | lewisporte
# Processing Record 11 of Set 15 | kodiak
# Processing Record 12 of Set 15 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 15 | nichlaul
# Processing Record 14 of Set 15 | two rivers
# Processing Record 15 of Set 15 | kupang
# Processing Record 16 of Set 15 | tasiilaq
# Processing Record 17 of Set 15 | lebu
# Processing Record 18 of Set 15 | kedgwick
# Processing Record 19 of Set 15 | koshurnikovo
# Processing Record 20 of Set 15 | saint george
# Processing Record 21 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 22 of Set 15 | quesnel
# Processing Record 23 of Set 15 | hohhot
# Processing Record 24 of Set 15 | ribeira grande
# Processing Record 25 of Set 15 | tazovskiy
# Processing Record 26 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 15 | samarai
# Processing Record 29 of Set 15 | belturbet
# Processing Record 30 of Set 15 | dikson
# Processing Record 31 of Set 15 | nome
# Processing Record 32 of Set 15 | sarhari
# Processing Record 33 of Set 15 | bayeux
# Processing Record 34 of Set 15 | marawi
# Processing Record 35 of Set 15 | jambi
# Processing Record 36 of Set 15 | calera
# Processing Record 37 of Set 15 | ballina
# Processing Record 38 of Set 15 | mar del plata
# Processing Record 39 of Set 15 | eirunepe
# Processing Record 40 of Set 15 | najran
# Processing Record 41 of Set 15 | lata
# Processing Record 42 of Set 15 | cockburn town
# Processing Record 43 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 15 | mahebourg
# Processing Record 45 of Set 15 | mackay
# Processing Record 46 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 15 | krasne
# Processing Record 48 of Set 15 | chuy
# Processing Record 49 of Set 15 | caravelas
# Processing Record 50 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 1 of Set 16 | alofi
# Processing Record 2 of Set 16 | canakkale
# Processing Record 3 of Set 16 | sitka
# Processing Record 4 of Set 16 | vardo
# Processing Record 5 of Set 16 | thompson
# Processing Record 6 of Set 16 | naze
# Processing Record 7 of Set 16 | college
# Processing Record 8 of Set 16 | acapulco
# Processing Record 9 of Set 16 | carai
# Processing Record 10 of Set 16 | semme
# Processing Record 11 of Set 16 | ciudad bolivar
# Processing Record 12 of Set 16 | road town
# Processing Record 13 of Set 16 | angoche
# Processing Record 14 of Set 16 | yulara
# Processing Record 15 of Set 16 | bilibino
# Processing Record 16 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 16 | castro
# Processing Record 18 of Set 16 | east london
# Processing Record 19 of Set 16 | clyde river
# Processing Record 20 of Set 16 | nanortalik
# Processing Record 21 of Set 16 | tarakan
# Processing Record 22 of Set 16 | xinzhi
# Processing Record 23 of Set 16 | ryotsu
# Processing Record 24 of Set 16 | quatre cocos
# Processing Record 25 of Set 16 | bethel
# Processing Record 26 of Set 16 | port alfred
# Processing Record 27 of Set 16 | gizo
# Processing Record 28 of Set 16 | bako
# Processing Record 29 of Set 16 | ciras
# City not found. Skipping...
# Processing Record 30 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 16 | mathbaria
# Processing Record 32 of Set 16 | torbay
# Processing Record 33 of Set 16 | atherton
# Processing Record 34 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 16 | asau
# Processing Record 36 of Set 16 | ishigaki
# Processing Record 37 of Set 16 | sao filipe
# Processing Record 38 of Set 16 | ust-nera
# Processing Record 39 of Set 16 | port lincoln
# Processing Record 40 of Set 16 | acarau
# Processing Record 41 of Set 16 | bredasdorp
# Processing Record 42 of Set 16 | atar
# Processing Record 43 of Set 16 | lukovetskiy
# Processing Record 44 of Set 16 | fairbanks
# Processing Record 45 of Set 16 | panguna
# Processing Record 46 of Set 16 | gimli
# Processing Record 47 of Set 16 | flinders
# Processing Record 48 of Set 16 | kontagora
# Processing Record 49 of Set 16 | walvis bay
# Processing Record 50 of Set 16 | nikolskoye
# Processing Record 1 of Set 17 | goias
# Processing Record 2 of Set 17 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 17 | ouahigouya
# Processing Record 4 of Set 17 | thai binh
# Processing Record 5 of Set 17 | presidencia roque saenz pena
# Processing Record 6 of Set 17 | port moresby
# Processing Record 7 of Set 17 | provideniya
# Processing Record 8 of Set 17 | aripuana
# Processing Record 9 of Set 17 | puerto del rosario
# Processing Record 10 of Set 17 | sfantu gheorghe
# Processing Record 11 of Set 17 | erenhot
# Processing Record 12 of Set 17 | faanui
# Processing Record 13 of Set 17 | rundu
# Processing Record 14 of Set 17 | urdzhar
# City not found. Skipping...
# Processing Record 15 of Set 17 | lorengau
# Processing Record 16 of Set 17 | arkhangelsk
# Processing Record 17 of Set 17 | leeton
# Processing Record 18 of Set 17 | pochutla
# Processing Record 19 of Set 17 | saint-pierre
# Processing Record 20 of Set 17 | mehamn
# Processing Record 21 of Set 17 | tukrah
# Processing Record 22 of Set 17 | peterhead
# Processing Record 23 of Set 17 | saryozek
# Processing Record 24 of Set 17 | lubango
# Processing Record 25 of Set 17 | ponta do sol
# Processing Record 26 of Set 17 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 17 | vila franca do campo
# Processing Record 28 of Set 17 | roma
# Processing Record 29 of Set 17 | constitucion
# Processing Record 30 of Set 17 | sobolevo
# Processing Record 31 of Set 17 | tomatlan
# Processing Record 32 of Set 17 | boysun
# Processing Record 33 of Set 17 | balykshi
# Processing Record 34 of Set 17 | san rafael
# Processing Record 35 of Set 17 | touros
# Processing Record 36 of Set 17 | hvammstangi
# City not found. Skipping...
# Processing Record 37 of Set 17 | nuevo cuscatlan
# Processing Record 38 of Set 17 | alenquer
# Processing Record 39 of Set 17 | mamaku
# Processing Record 40 of Set 17 | etchoropo
# Processing Record 41 of Set 17 | keffi
# Processing Record 42 of Set 17 | zyryanka
# Processing Record 43 of Set 17 | ilulissat
# Processing Record 44 of Set 17 | bonthe
# Processing Record 45 of Set 17 | nemuro
# Processing Record 46 of Set 17 | suntar
# Processing Record 47 of Set 17 | necochea
# Processing Record 48 of Set 17 | waipawa
# Processing Record 49 of Set 17 | praia
# Processing Record 50 of Set 17 | huarmey
# Processing Record 1 of Set 18 | saint anthony
# Processing Record 2 of Set 18 | vestmannaeyjar
# Processing Record 3 of Set 18 | wanning
# Processing Record 4 of Set 18 | pevek
# Processing Record 5 of Set 18 | finschhafen
# Processing Record 6 of Set 18 | kushima
# Processing Record 7 of Set 18 | banmankhi
# Processing Record 8 of Set 18 | puerto el triunfo
# Processing Record 9 of Set 18 | traverse city
# Processing Record 10 of Set 18 | pasinler
# Processing Record 11 of Set 18 | rio grande
# Processing Record 12 of Set 18 | chlorakas
# Processing Record 13 of Set 18 | kabare
# Processing Record 14 of Set 18 | chernyshevskiy
# Processing Record 15 of Set 18 | te anau
# Processing Record 16 of Set 18 | korla
# Processing Record 17 of Set 18 | yunjinghong
# City not found. Skipping...
# Processing Record 18 of Set 18 | the valley
# Processing Record 19 of Set 18 | pringsewu
# Processing Record 20 of Set 18 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 18 | san ramon
# Processing Record 22 of Set 18 | podor
# Processing Record 23 of Set 18 | nilopolis
# Processing Record 24 of Set 18 | thunder bay
# Processing Record 25 of Set 18 | eskasem
# City not found. Skipping...
# Processing Record 26 of Set 18 | soeng sang
# Processing Record 27 of Set 18 | talaya
# Processing Record 28 of Set 18 | tricase
# Processing Record 29 of Set 18 | bar harbor
# Processing Record 30 of Set 18 | surt
# Processing Record 31 of Set 18 | dunn
# Processing Record 32 of Set 18 | springfield
# Processing Record 33 of Set 18 | nisia floresta
# Processing Record 34 of Set 18 | ikom
# Processing Record 35 of Set 18 | zhigansk
# Processing Record 36 of Set 18 | dezhou
# Processing Record 37 of Set 18 | balikpapan
# Processing Record 38 of Set 18 | port hedland
# Processing Record 39 of Set 18 | bridgetown
# Processing Record 40 of Set 18 | novoagansk
# Processing Record 41 of Set 18 | beaverlodge
# Processing Record 42 of Set 18 | havelock
# Processing Record 43 of Set 18 | shetpe
# Processing Record 44 of Set 18 | teguldet
# Processing Record 45 of Set 18 | bubaque
# Processing Record 46 of Set 18 | brisbane
# Processing Record 47 of Set 18 | nylstroom
# City not found. Skipping...
# Processing Record 48 of Set 18 | nea peramos
# Processing Record 49 of Set 18 | portland
# Processing Record 50 of Set 18 | amaraji
# Processing Record 1 of Set 19 | progreso
# Processing Record 2 of Set 19 | jalpan
# Processing Record 3 of Set 19 | zhicheng
# Processing Record 4 of Set 19 | colares
# Processing Record 5 of Set 19 | yumen
# Processing Record 6 of Set 19 | cocobeach
# Processing Record 7 of Set 19 | airai
# Processing Record 8 of Set 19 | eyl
# Processing Record 9 of Set 19 | am timan
# Processing Record 10 of Set 19 | cairns
# Processing Record 11 of Set 19 | hamina
# Processing Record 12 of Set 19 | pinega
# Processing Record 13 of Set 19 | mount isa
# Processing Record 14 of Set 19 | teguise
# Processing Record 15 of Set 19 | chajul
# Processing Record 16 of Set 19 | hun
# Processing Record 17 of Set 19 | khatanga
# Processing Record 18 of Set 19 | carrollton
# Processing Record 19 of Set 19 | aklavik
# Processing Record 20 of Set 19 | baijiantan
# Processing Record 21 of Set 19 | haines junction
# Processing Record 22 of Set 19 | kaitangata
# Processing Record 23 of Set 19 | deputatskiy
# Processing Record 24 of Set 19 | kpandae
# Processing Record 25 of Set 19 | esperance
# Processing Record 26 of Set 19 | kesennuma
# City not found. Skipping...
# Processing Record 27 of Set 19 | port elizabeth
# Processing Record 28 of Set 19 | markala
# Processing Record 29 of Set 19 | matara
# Processing Record 30 of Set 19 | meulaboh
# Processing Record 31 of Set 19 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 19 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 19 | herat
# Processing Record 34 of Set 19 | carbonear
# Processing Record 35 of Set 19 | tabas
# Processing Record 36 of Set 19 | belyy yar
# Processing Record 37 of Set 19 | temyasovo
# Processing Record 38 of Set 19 | north bend
# Processing Record 39 of Set 19 | rovaniemi
# Processing Record 40 of Set 19 | oranjemund
# Processing Record 41 of Set 19 | xining
# Processing Record 42 of Set 19 | cascais
# Processing Record 43 of Set 19 | khabary
# Processing Record 44 of Set 19 | hovd
# Processing Record 45 of Set 19 | viedma
# Processing Record 46 of Set 19 | faya
# Processing Record 47 of Set 19 | obigarm
# Processing Record 48 of Set 19 | dengzhou
# Processing Record 49 of Set 19 | sokolo
# Processing Record 50 of Set 19 | mbanza-ngungu
# Processing Record 1 of Set 20 | souillac
# Processing Record 2 of Set 20 | prince rupert
# Processing Record 3 of Set 20 | olafsvik
# Processing Record 4 of Set 20 | puerto madryn
# Processing Record 5 of Set 20 | mount gambier
# Processing Record 6 of Set 20 | hobbs
# Processing Record 7 of Set 20 | voh
# Processing Record 8 of Set 20 | baishishan
# Processing Record 9 of Set 20 | baykit
# Processing Record 10 of Set 20 | ylojarvi
# Processing Record 11 of Set 20 | uberlandia
# Processing Record 12 of Set 20 | rabo de peixe
# Processing Record 13 of Set 20 | skjervoy
# Processing Record 14 of Set 20 | matamoros
# Processing Record 15 of Set 20 | dunedin
# Processing Record 16 of Set 20 | coihaique
# Processing Record 17 of Set 20 | oktyabrskoye
# Processing Record 18 of Set 20 | formoso do araguaia
# City not found. Skipping...
# Processing Record 19 of Set 20 | patamundai
# Processing Record 20 of Set 20 | beringovskiy
# Processing Record 21 of Set 20 | jiaohe
# Processing Record 22 of Set 20 | jomalig
# City not found. Skipping...
# Processing Record 23 of Set 20 | tecoanapa
# Processing Record 24 of Set 20 | codrington
# Processing Record 25 of Set 20 | arcata
# Processing Record 26 of Set 20 | batemans bay
# Processing Record 27 of Set 20 | beyneu
# Processing Record 28 of Set 20 | venado tuerto
# Processing Record 29 of Set 20 | saint-georges
# Processing Record 30 of Set 20 | chara
# Processing Record 31 of Set 20 | quelimane
# Processing Record 32 of Set 20 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 20 | saldanha
# Processing Record 34 of Set 20 | awbari
# Processing Record 35 of Set 20 | dillon
# Processing Record 36 of Set 20 | luocheng
# Processing Record 37 of Set 20 | fortuna
# Processing Record 38 of Set 20 | durban
# Processing Record 39 of Set 20 | guarapari
# Processing Record 40 of Set 20 | hofn
# Processing Record 41 of Set 20 | dano
# Processing Record 42 of Set 20 | makakilo city
# Processing Record 43 of Set 20 | ronne
# Processing Record 44 of Set 20 | ndele
# Processing Record 45 of Set 20 | hasaki
# Processing Record 46 of Set 20 | seymchan
# Processing Record 47 of Set 20 | jurm
# Processing Record 48 of Set 20 | zhuhai
# Processing Record 49 of Set 20 | phek
# Processing Record 50 of Set 20 | mecca
# Processing Record 1 of Set 21 | yarmouth
# Processing Record 2 of Set 21 | gukovo
# Processing Record 3 of Set 21 | zaranj
# Processing Record 4 of Set 21 | maneromango
# Processing Record 5 of Set 21 | abu samrah
# Processing Record 6 of Set 21 | aosta
# Processing Record 7 of Set 21 | vila velha
# Processing Record 8 of Set 21 | port-gentil
# Processing Record 9 of Set 21 | nushki
# Processing Record 10 of Set 21 | husavik
# Processing Record 11 of Set 21 | ulladulla
# Processing Record 12 of Set 21 | jinchengjiang
# City not found. Skipping...
# Processing Record 13 of Set 21 | denpasar
# Processing Record 14 of Set 21 | sabang
# Processing Record 15 of Set 21 | ouallam
# Processing Record 16 of Set 21 | tura
# Processing Record 17 of Set 21 | lasa
# Processing Record 18 of Set 21 | kahului
# Processing Record 19 of Set 21 | rawson
# Processing Record 20 of Set 21 | margate
# Processing Record 21 of Set 21 | hami
# Processing Record 22 of Set 21 | tidore
# City not found. Skipping...
# Processing Record 23 of Set 21 | sioux lookout
# Processing Record 24 of Set 21 | druzhba
# Processing Record 25 of Set 21 | cao bang
# Processing Record 26 of Set 21 | voi
# Processing Record 27 of Set 21 | eldikan
# City not found. Skipping...
# Processing Record 28 of Set 21 | puerto leguizamo
# Processing Record 29 of Set 21 | ahipara
# Processing Record 30 of Set 21 | rupert
# Processing Record 31 of Set 21 | okha
# Processing Record 32 of Set 21 | erzin
# Processing Record 33 of Set 21 | pacific grove
# Processing Record 34 of Set 21 | veraval
# Processing Record 35 of Set 21 | san quintin
# Processing Record 36 of Set 21 | dalbandin
# Processing Record 37 of Set 21 | severo-kurilsk
# Processing Record 38 of Set 21 | calbuco
# Processing Record 39 of Set 21 | zhaozhou
# Processing Record 40 of Set 21 | novaya chigla
# Processing Record 41 of Set 21 | san luis
# Processing Record 42 of Set 21 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 21 | la ronge
# Processing Record 44 of Set 21 | inhambane
# Processing Record 45 of Set 21 | tyrma
# Processing Record 46 of Set 21 | saint-francois
# Processing Record 47 of Set 21 | ribeira brava
# Processing Record 48 of Set 21 | tres picos
# Processing Record 49 of Set 21 | tilichiki
# Processing Record 50 of Set 21 | half moon bay
# Processing Record 1 of Set 22 | vicksburg
# Processing Record 2 of Set 22 | wlodawa
# Processing Record 3 of Set 22 | valparaiso
# Processing Record 4 of Set 22 | bonwapitse
# Processing Record 5 of Set 22 | anyama
# Processing Record 6 of Set 22 | general roca
# Processing Record 7 of Set 22 | tabou
# Processing Record 8 of Set 22 | gardan diwal
# City not found. Skipping...
# Processing Record 9 of Set 22 | darhan
# Processing Record 10 of Set 22 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 22 | coffs harbour
# Processing Record 12 of Set 22 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 22 | karasburg
# Processing Record 14 of Set 22 | sungairaya
# Processing Record 15 of Set 22 | coihueco
# Processing Record 16 of Set 22 | hwange
# Processing Record 17 of Set 22 | anton lizardo
# Processing Record 18 of Set 22 | megion
# Processing Record 19 of Set 22 | shubarkuduk
# Processing Record 20 of Set 22 | nogales
# Processing Record 21 of Set 22 | longyearbyen
# Processing Record 22 of Set 22 | buique
# Processing Record 23 of Set 22 | el colomo
# Processing Record 24 of Set 22 | maceio
# Processing Record 25 of Set 22 | talara
# Processing Record 26 of Set 22 | katherine
# Processing Record 27 of Set 22 | flin flon
# Processing Record 28 of Set 22 | oum hadjer
# Processing Record 29 of Set 22 | namatanai
# Processing Record 30 of Set 22 | kavieng
# Processing Record 31 of Set 22 | lemesos
# City not found. Skipping...
# Processing Record 32 of Set 22 | harlingen
# Processing Record 33 of Set 22 | taoudenni
# Processing Record 34 of Set 22 | guerrero negro
# Processing Record 35 of Set 22 | iskandar
# Processing Record 36 of Set 22 | egvekinot
# Processing Record 37 of Set 22 | houma
# Processing Record 38 of Set 22 | waingapu
# Processing Record 39 of Set 22 | suzu
# City not found. Skipping...
# Processing Record 40 of Set 22 | kamaishi
# Processing Record 41 of Set 22 | goure
# Processing Record 42 of Set 22 | port blair
# Processing Record 43 of Set 22 | irati
# Processing Record 44 of Set 22 | yichang
# Processing Record 45 of Set 22 | vanavara
# Processing Record 46 of Set 22 | kumano
# Processing Record 47 of Set 22 | kamenka
# Processing Record 48 of Set 22 | besskorbnaya
# Processing Record 49 of Set 22 | pisco
# Processing Record 50 of Set 22 | grand-santi
# Processing Record 1 of Set 23 | chiscas
# Processing Record 2 of Set 23 | qaqortoq
# Processing Record 3 of Set 23 | impfondo
# Processing Record 4 of Set 23 | copiapo
# Processing Record 5 of Set 23 | axim
# Processing Record 6 of Set 23 | elko
# Processing Record 7 of Set 23 | cayenne
# Processing Record 8 of Set 23 | andahuaylas
# Processing Record 9 of Set 23 | cabedelo
# Processing Record 10 of Set 23 | san cristobal
# Processing Record 11 of Set 23 | isangel
# Processing Record 12 of Set 23 | duz
# City not found. Skipping...
# Processing Record 13 of Set 23 | villanueva
# Processing Record 14 of Set 23 | riyadh
# Processing Record 15 of Set 23 | great falls
# Processing Record 16 of Set 23 | grindavik
# Processing Record 17 of Set 23 | lewistown
# Processing Record 18 of Set 23 | yar-sale
# Processing Record 19 of Set 23 | port macquarie
# Processing Record 20 of Set 23 | vaitape
# Processing Record 21 of Set 23 | noumea
# Processing Record 22 of Set 23 | olinda
# Processing Record 23 of Set 23 | adrar
# Processing Record 24 of Set 23 | mzimba
# Processing Record 25 of Set 23 | moskovskiy
# Processing Record 26 of Set 23 | beni mazar
# Processing Record 27 of Set 23 | svirstroy
# Processing Record 28 of Set 23 | janakkala
# Processing Record 29 of Set 23 | honiara
# Processing Record 30 of Set 23 | sorong
# Processing Record 31 of Set 23 | saint-ambroise
# Processing Record 32 of Set 23 | miranda
# Processing Record 33 of Set 23 | mandurah
# Processing Record 34 of Set 23 | itaituba
# Processing Record 35 of Set 23 | berlevag
# Processing Record 36 of Set 23 | oudtshoorn
# Processing Record 37 of Set 23 | gafanha da encarnacao
# Processing Record 38 of Set 23 | odweyne
# Processing Record 39 of Set 23 | ashland
# Processing Record 40 of Set 23 | makubetsu
# Processing Record 41 of Set 23 | galiwinku
# City not found. Skipping...
# Processing Record 42 of Set 23 | ambalavao
# Processing Record 43 of Set 23 | chipinge
# Processing Record 44 of Set 23 | lebanon
# Processing Record 45 of Set 23 | palmer
# Processing Record 46 of Set 23 | nueva loja
# Processing Record 47 of Set 23 | nabisar
# Processing Record 48 of Set 23 | tessalit
# Processing Record 49 of Set 23 | geraldton
# Processing Record 50 of Set 23 | fortuna foothills
# Processing Record 1 of Set 24 | wukari
# Processing Record 2 of Set 24 | abu dhabi
# Processing Record 3 of Set 24 | mayor pablo lagerenza
# Processing Record 4 of Set 24 | talcahuano
# Processing Record 5 of Set 24 | zhitikara
# City not found. Skipping...
# Processing Record 6 of Set 24 | novoanninskiy
# Processing Record 7 of Set 24 | palana
# Processing Record 8 of Set 24 | mangan
# Processing Record 9 of Set 24 | amapala
# Processing Record 10 of Set 24 | svetlogorsk
# Processing Record 11 of Set 24 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 24 | libertador general san martin
# Processing Record 13 of Set 24 | pullman
# Processing Record 14 of Set 24 | soe
# Processing Record 15 of Set 24 | ukiah
# Processing Record 16 of Set 24 | ancud
# Processing Record 17 of Set 24 | biltine
# Processing Record 18 of Set 24 | omboue
# Processing Record 19 of Set 24 | talavera
# Processing Record 20 of Set 24 | raga
# Processing Record 21 of Set 24 | mocambique
# City not found. Skipping...
# Processing Record 22 of Set 24 | touba
# Processing Record 23 of Set 24 | poum
# Processing Record 24 of Set 24 | pervomayskoye
# Processing Record 25 of Set 24 | dhidhdhoo
# Processing Record 26 of Set 24 | cochrane
# Processing Record 27 of Set 24 | severomorsk
# Processing Record 28 of Set 24 | lavrentiya
# Processing Record 29 of Set 24 | henties bay
# Processing Record 30 of Set 24 | san patricio
# Processing Record 31 of Set 24 | edea
# Processing Record 32 of Set 24 | hervey bay
# Processing Record 33 of Set 24 | amahai
# Processing Record 34 of Set 24 | sheffield lake
# Processing Record 35 of Set 24 | clinton
# Processing Record 36 of Set 24 | moose factory
# Processing Record 37 of Set 24 | mafra
# Processing Record 38 of Set 24 | srednekolymsk
# Processing Record 39 of Set 24 | young
# Processing Record 40 of Set 24 | pangnirtung
# Processing Record 41 of Set 24 | porto novo
# Processing Record 42 of Set 24 | sistranda
# Processing Record 43 of Set 24 | ilhabela
# Processing Record 44 of Set 24 | farafangana
# Processing Record 45 of Set 24 | yeoryiani
# City not found. Skipping...
# Processing Record 46 of Set 24 | kemijarvi
# Processing Record 47 of Set 24 | adeje
# Processing Record 48 of Set 24 | muzhi
# Processing Record 49 of Set 24 | bandarbeyla
# Processing Record 50 of Set 24 | buraydah
# Processing Record 1 of Set 25 | nanchang
# Processing Record 2 of Set 25 | saint-augustin
# Processing Record 3 of Set 25 | oriximina
# Processing Record 4 of Set 25 | carballo
# Processing Record 5 of Set 25 | lugovoy
# Processing Record 6 of Set 25 | minab
# Processing Record 7 of Set 25 | suslovo
# Processing Record 8 of Set 25 | teya
# Processing Record 9 of Set 25 | manacapuru
# Processing Record 10 of Set 25 | odienne
# Processing Record 11 of Set 25 | schortens
# Processing Record 12 of Set 25 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 25 | matameye
# City not found. Skipping...
# Processing Record 14 of Set 25 | santa ana
# Processing Record 15 of Set 25 | havre-saint-pierre
# Processing Record 16 of Set 25 | ust-omchug
# Processing Record 17 of Set 25 | newport
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Bluff -46.6000  168.3333     50.34        80         100
# 1    Norman Wells  65.2820 -126.8329     42.84        87         100
# 2       Saskylakh  71.9167  114.0833     26.83        99          97
# 3     Chake Chake  -5.2459   39.7666     77.31        83          99
# 4       Hithadhoo  -0.6000   73.0833     83.05        70          12
# 5     Tuktoyaktuk  69.4541 -133.0374     30.20        69         100
# 6        Evanston  42.0411  -87.6901     61.92        88         100
# 7  Saint-Philippe -21.3585   55.7679     71.19        79          99
# 8          Bereda  43.2686   -7.5406     74.41        55         100
# 9         Iqaluit  63.7506  -68.5145     31.73        93         100
#
#    Wind Speed Country                 Date
# 0       29.48      NZ  2022-05-21 19:25:37
# 1       18.41      CA  2022-05-21 19:25:37
# 2        6.58      RU  2022-05-21 19:17:44
# 3        9.06      TZ  2022-05-21 19:25:38
# 4        8.21      MV  2022-05-21 19:21:18
# 5        9.22      CA  2022-05-21 19:25:38
# 6       10.36      US  2022-05-21 19:23:06
# 7       11.32      RE  2022-05-21 19:25:39
# 8        1.99      ES  2022-05-21 19:25:39
# 9       33.38      CA  2022-05-21 19:23:59

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig4.png")
# Show plot.
plt.show()

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt
# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")


# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")


plt.xlabel('Latitude')
plt.ylabel('Temp')

plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
  
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
 index13 = city_data_df.loc[13]

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature','Max Temp',(10,40))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity','% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression for %cloudinesss on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness','% Cloudiness',(10,55))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
     # Linear regression on the Northern Hemisphere
    x_values = northern_hemi_df["Lat"]
    y_values = northern_hemi_df["Wind Speed"]
     # Call the function.
    plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))

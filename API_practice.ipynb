# %%
# Import the dependencies.
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)

lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
   # print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
         # citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
pip freeze
# Out:
# alabaster @ file:///home/ktietz/src/ci/alabaster_1611921544520/work
# anaconda-client @ file:///C:/ci/anaconda-client_1635342725944/work
# anaconda-navigator==2.1.4
# anaconda-project @ file:///tmp/build/80754af9/anaconda-project_1626085644852/work
# anyio @ file:///C:/ci/anyio_1620153135622/work/dist
# appdirs==1.4.4
# argh==0.26.2
# argon2-cffi @ file:///C:/ci/argon2-cffi_1613037869401/work
# arrow @ file:///C:/ci/arrow_1617738834352/work
# asn1crypto @ file:///tmp/build/80754af9/asn1crypto_1596577642040/work
# astroid @ file:///C:/ci/astroid_1628063282661/work
# astropy @ file:///C:/ci/astropy_1629829318700/work
# async-generator @ file:///home/ktietz/src/ci/async_generator_1611927993394/work
# atomicwrites==1.4.0
# attrs @ file:///tmp/build/80754af9/attrs_1620827162558/work
# autopep8 @ file:///tmp/build/80754af9/autopep8_1620866417880/work
# Babel @ file:///tmp/build/80754af9/babel_1620871417480/work
# backcall @ file:///home/ktietz/src/ci/backcall_1611930011877/work
# backports.functools-lru-cache @ file:///tmp/build/80754af9/backports.functools_lru_cache_1618170165463/work
# backports.shutil-get-terminal-size @ file:///tmp/build/80754af9/backports.shutil_get_terminal_size_1608222128777/work
# backports.tempfile @ file:///home/linux1/recipes/ci/backports.tempfile_1610991236607/work
# backports.weakref==1.0.post1
# bcrypt @ file:///C:/ci/bcrypt_1607022693089/work
# beautifulsoup4 @ file:///tmp/build/80754af9/beautifulsoup4_1631874778482/work
# binaryornot @ file:///tmp/build/80754af9/binaryornot_1617751525010/work
# bitarray @ file:///C:/ci/bitarray_1629133068652/work
# bkcharts==0.2
# black==19.10b0
# bleach @ file:///tmp/build/80754af9/bleach_1628110601003/work
# bokeh @ file:///C:/ci/bokeh_1635306491714/work
# boto==2.49.0
# Bottleneck @ file:///C:/ci/bottleneck_1607557040328/work
# brotlipy==0.7.0
# cached-property @ file:///tmp/build/80754af9/cached-property_1600785575025/work
# certifi==2021.10.8
# cffi @ file:///C:/ci/cffi_1625831756778/work
# chardet @ file:///C:/ci/chardet_1607706937985/work
# charset-normalizer @ file:///tmp/build/80754af9/charset-normalizer_1630003229654/work
# citipy==0.0.5
# click==8.0.3
# cloudpickle @ file:///tmp/build/80754af9/cloudpickle_1632508026186/work
# clyent==1.2.2
# colorama @ file:///tmp/build/80754af9/colorama_1607707115595/work
# comtypes==1.1.10
# conda==4.12.0
# conda-build==3.21.6
# conda-content-trust @ file:///tmp/build/80754af9/conda-content-trust_1617045594566/work
# conda-pack @ file:///tmp/build/80754af9/conda-pack_1611163042455/work
# conda-package-handling @ file:///C:/ci/conda-package-handling_1618262410900/work
# conda-repo-cli @ file:///tmp/build/80754af9/conda-repo-cli_1620168426516/work
# conda-token @ file:///tmp/build/80754af9/conda-token_1620076980546/work
# conda-verify==3.4.2
# contextlib2 @ file:///Users/ktietz/demo/mc3/conda-bld/contextlib2_1630668244042/work
# cookiecutter @ file:///tmp/build/80754af9/cookiecutter_1617748928239/work
# cryptography @ file:///C:/ci/cryptography_1633520531101/work
# cycler==0.10.0
# Cython @ file:///C:/ci/cython_1636018292912/work
# cytoolz==0.11.0
# daal4py==2021.3.0
# dask==2021.10.0
# debugpy @ file:///C:/ci/debugpy_1629222819322/work
# decorator @ file:///tmp/build/80754af9/decorator_1632776554403/work
# defusedxml @ file:///tmp/build/80754af9/defusedxml_1615228127516/work
# diff-match-patch @ file:///Users/ktietz/demo/mc3/conda-bld/diff-match-patch_1630511840874/work
# distributed @ file:///C:/ci/distributed_1635968318313/work
# docutils @ file:///C:/ci/docutils_1620828264669/work
# entrypoints==0.3
# et-xmlfile==1.1.0
# fastcache @ file:///C:/ci/fastcache_1607571310570/work
# filelock @ file:///tmp/build/80754af9/filelock_1635402558181/work
# flake8 @ file:///tmp/build/80754af9/flake8_1620776156532/work
# Flask @ file:///home/ktietz/src/ci/flask_1611932660458/work
# fonttools==4.25.0
# fsspec @ file:///tmp/build/80754af9/fsspec_1636116461911/work
# future @ file:///C:/ci/future_1607568713721/work
# geojson==2.5.0
# gevent @ file:///C:/ci/gevent_1628273776273/work
# glob2 @ file:///home/linux1/recipes/ci/glob2_1610991677669/work
# gmaps==0.9.0
# greenlet @ file:///C:/ci/greenlet_1628888275363/work
# h5py @ file:///C:/ci/h5py_1622088609188/work
# HeapDict @ file:///Users/ktietz/demo/mc3/conda-bld/heapdict_1630598515714/work
# html5lib @ file:///Users/ktietz/demo/mc3/conda-bld/html5lib_1629144453894/work
# idna @ file:///tmp/build/80754af9/idna_1622654382723/work
# imagecodecs @ file:///C:/ci/imagecodecs_1635511087451/work
# imageio @ file:///tmp/build/80754af9/imageio_1617700267927/work
# imagesize @ file:///Users/ktietz/demo/mc3/conda-bld/imagesize_1628863108022/work
# importlib-metadata @ file:///C:/ci/importlib-metadata_1631916826748/work
# inflection==0.5.1
# iniconfig @ file:///home/linux1/recipes/ci/iniconfig_1610983019677/work
# intervaltree @ file:///Users/ktietz/demo/mc3/conda-bld/intervaltree_1630511889664/work
# ipykernel @ file:///C:/ci/ipykernel_1633545585502/work/dist/ipykernel-6.4.1-py3-none-any.whl
# ipython @ file:///C:/ci/ipython_1635944283918/work
# ipython-genutils @ file:///tmp/build/80754af9/ipython_genutils_1606773439826/work
# ipywidgets @ file:///tmp/build/80754af9/ipywidgets_1634143127070/work
# isort @ file:///tmp/build/80754af9/isort_1628603791788/work
# itsdangerous @ file:///tmp/build/80754af9/itsdangerous_1621432558163/work
# jdcal @ file:///Users/ktietz/demo/mc3/conda-bld/jdcal_1630584345063/work
# jedi @ file:///C:/ci/jedi_1611341083684/work
# Jinja2 @ file:///tmp/build/80754af9/jinja2_1612213139570/work
# jinja2-time @ file:///tmp/build/80754af9/jinja2-time_1617751524098/work
# joblib @ file:///tmp/build/80754af9/joblib_1635411271373/work
# json5 @ file:///tmp/build/80754af9/json5_1624432770122/work
# jsonschema @ file:///Users/ktietz/demo/mc3/conda-bld/jsonschema_1630511932244/work
# jupyter @ file:///C:/ci/jupyter_1607685287094/work
# jupyter-client @ file:///tmp/build/80754af9/jupyter_client_1616770841739/work
# jupyter-console @ file:///tmp/build/80754af9/jupyter_console_1616615302928/work
# jupyter-core @ file:///C:/ci/jupyter_core_1633420716440/work
# jupyter-server @ file:///C:/ci/jupyter_server_1616084298419/work
# jupyterlab @ file:///tmp/build/80754af9/jupyterlab_1635799997693/work
# jupyterlab-pygments @ file:///tmp/build/80754af9/jupyterlab_pygments_1601490720602/work
# jupyterlab-server @ file:///tmp/build/80754af9/jupyterlab_server_1633419203660/work
# jupyterlab-widgets @ file:///tmp/build/80754af9/jupyterlab_widgets_1609884341231/work
# kdtree==0.16
# keyring @ file:///C:/ci/keyring_1629321702436/work
# kiwisolver @ file:///C:/ci/kiwisolver_1612282555033/work
# lazy-object-proxy @ file:///C:/ci/lazy-object-proxy_1616529288960/work
# libarchive-c @ file:///tmp/build/80754af9/python-libarchive-c_1617780486945/work
# llvmlite==0.37.0
# locket==0.2.1
# lxml @ file:///C:/ci/lxml_1616443418777/work
# MarkupSafe @ file:///C:/ci/markupsafe_1607027406824/work
# matplotlib @ file:///C:/ci/matplotlib-suite_1634667159685/work
# matplotlib-inline @ file:///tmp/build/80754af9/matplotlib-inline_1628242447089/work
# mccabe==0.6.1
# menuinst @ file:///C:/ci/menuinst_1631733438520/work
# mistune @ file:///C:/ci/mistune_1607359457024/work
# mkl-fft==1.3.1
# mkl-random @ file:///C:/ci/mkl_random_1626186184308/work
# mkl-service==2.4.0
# mock @ file:///tmp/build/80754af9/mock_1607622725907/work
# more-itertools @ file:///tmp/build/80754af9/more-itertools_1635423142362/work
# mpmath==1.2.1
# msgpack @ file:///C:/ci/msgpack-python_1612287350784/work
# multipledispatch @ file:///C:/ci/multipledispatch_1607574329826/work
# munkres==1.1.4
# mypy-extensions==0.4.3
# mysql-connector-python==8.0.27
# navigator-updater==0.2.1
# nbclassic @ file:///tmp/build/80754af9/nbclassic_1616085367084/work
# nbclient @ file:///tmp/build/80754af9/nbclient_1614364831625/work
# nbconvert @ file:///C:/ci/nbconvert_1624479160025/work
# nbformat @ file:///tmp/build/80754af9/nbformat_1617383369282/work
# nest-asyncio @ file:///tmp/build/80754af9/nest-asyncio_1613680548246/work
# networkx @ file:///tmp/build/80754af9/networkx_1633639043937/work
# nltk==3.6.5
# nose @ file:///tmp/build/80754af9/nose_1606773131901/work
# notebook @ file:///C:/ci/notebook_1635393701545/work
# numba @ file:///C:/ci/numba_1635186062888/work
# numexpr @ file:///C:/ci/numexpr_1618856728739/work
# numpy @ file:///C:/ci/numpy_and_numpy_base_1626271900803/work
# numpydoc @ file:///tmp/build/80754af9/numpydoc_1605117425582/work
# olefile @ file:///Users/ktietz/demo/mc3/conda-bld/olefile_1629805411829/work
# openpyxl @ file:///tmp/build/80754af9/openpyxl_1632777717936/work
# packaging @ file:///tmp/build/80754af9/packaging_1625611678980/work
# pandas @ file:///C:/ci/pandas_1635506685681/work
# pandocfilters @ file:///C:/ci/pandocfilters_1605114832805/work
# paramiko @ file:///tmp/build/80754af9/paramiko_1598886428689/work
# parso @ file:///tmp/build/80754af9/parso_1617223946239/work
# partd @ file:///tmp/build/80754af9/partd_1618000087440/work
# path @ file:///C:/ci/path_1624287837534/work
# pathlib2 @ file:///C:/ci/pathlib2_1625585796814/work
# pathspec==0.7.0
# patsy==0.5.2
# pep8==1.7.1
# pexpect @ file:///tmp/build/80754af9/pexpect_1605563209008/work
# pickleshare @ file:///tmp/build/80754af9/pickleshare_1606932040724/work
# Pillow==8.4.0
# pkginfo==1.7.1
# pluggy @ file:///C:/ci/pluggy_1615976440052/work
# ply==3.11
# poyo @ file:///tmp/build/80754af9/poyo_1617751526755/work
# prometheus-client @ file:///tmp/build/80754af9/prometheus_client_1623189609245/work
# prompt-toolkit @ file:///tmp/build/80754af9/prompt-toolkit_1633440160888/work
# psutil @ file:///C:/ci/psutil_1612298199233/work
# ptyprocess @ file:///tmp/build/80754af9/ptyprocess_1609355006118/work/dist/ptyprocess-0.7.0-py2.py3-none-any.whl
# py @ file:///tmp/build/80754af9/py_1607971587848/work
# pycodestyle @ file:///tmp/build/80754af9/pycodestyle_1615748559966/work
# pycosat==0.6.3
# pycparser @ file:///tmp/build/80754af9/pycparser_1594388511720/work
# pycurl==7.44.1
# pydocstyle @ file:///tmp/build/80754af9/pydocstyle_1621600989141/work
# pyerfa @ file:///C:/ci/pyerfa_1621560974055/work
# pyflakes @ file:///tmp/build/80754af9/pyflakes_1617200973297/work
# Pygments @ file:///tmp/build/80754af9/pygments_1629234116488/work
# PyJWT @ file:///C:/ci/pyjwt_1619682721924/work
# pylint @ file:///C:/ci/pylint_1627536884966/work
# pyls-spyder==0.4.0
# PyNaCl @ file:///C:/ci/pynacl_1607612759007/work
# pyodbc===4.0.0-unsupported
# pyOpenSSL @ file:///tmp/build/80754af9/pyopenssl_1635333100036/work
# pyparsing @ file:///tmp/build/80754af9/pyparsing_1635766073266/work
# pyreadline==2.1
# pyrsistent @ file:///C:/ci/pyrsistent_1636093225342/work
# PySocks @ file:///C:/ci/pysocks_1605307512533/work
# pytest==6.2.4
# python-dateutil @ file:///tmp/build/80754af9/python-dateutil_1626374649649/work
# python-lsp-black @ file:///tmp/build/80754af9/python-lsp-black_1634232156041/work
# python-lsp-jsonrpc==1.0.0
# python-lsp-server==1.2.4
# python-slugify @ file:///tmp/build/80754af9/python-slugify_1620405669636/work
# pytz==2021.3
# PyWavelets @ file:///C:/ci/pywavelets_1607645631519/work
# pywin32==228
# pywin32-ctypes @ file:///C:/ci/pywin32-ctypes_1607553594546/work
# pywinpty @ file:///C:/ci/pywinpty_1607419945780/work
# PyYAML==6.0
# pyzmq @ file:///C:/ci/pyzmq_1628276105793/work
# QDarkStyle @ file:///tmp/build/80754af9/qdarkstyle_1617386714626/work
# qstylizer @ file:///tmp/build/80754af9/qstylizer_1617713584600/work/dist/qstylizer-0.1.10-py2.py3-none-any.whl
# QtAwesome @ file:///tmp/build/80754af9/qtawesome_1615991616277/work
# qtconsole @ file:///tmp/build/80754af9/qtconsole_1632739723211/work
# QtPy @ file:///tmp/build/80754af9/qtpy_1629397026935/work
# regex @ file:///C:/ci/regex_1628063427816/work
# requests @ file:///tmp/build/80754af9/requests_1629994808627/work
# rope @ file:///tmp/build/80754af9/rope_1623703006312/work
# Rtree @ file:///C:/ci/rtree_1618421015405/work
# ruamel-yaml-conda @ file:///C:/ci/ruamel_yaml_1616016898638/work
# scikit-image==0.18.3
# scikit-learn @ file:///C:/ci/scikit-learn_1622739499047/work
# scikit-learn-intelex==2021.20210714.120553
# scipy @ file:///C:/ci/scipy_1630606917240/work
# seaborn @ file:///tmp/build/80754af9/seaborn_1629307859561/work
# Send2Trash @ file:///tmp/build/80754af9/send2trash_1632406701022/work
# simplegeneric==0.8.1
# singledispatch @ file:///tmp/build/80754af9/singledispatch_1629321204894/work
# sip==4.19.13
# six @ file:///tmp/build/80754af9/six_1623709665295/work
# sniffio @ file:///C:/ci/sniffio_1614030527509/work
# snowballstemmer @ file:///tmp/build/80754af9/snowballstemmer_1611258885636/work
# sortedcollections @ file:///tmp/build/80754af9/sortedcollections_1611172717284/work
# sortedcontainers @ file:///tmp/build/80754af9/sortedcontainers_1623949099177/work
# soupsieve @ file:///tmp/build/80754af9/soupsieve_1616183228191/work
# Sphinx==4.2.0
# sphinxcontrib-applehelp @ file:///home/ktietz/src/ci/sphinxcontrib-applehelp_1611920841464/work
# sphinxcontrib-devhelp @ file:///home/ktietz/src/ci/sphinxcontrib-devhelp_1611920923094/work
# sphinxcontrib-htmlhelp @ file:///tmp/build/80754af9/sphinxcontrib-htmlhelp_1623945626792/work
# sphinxcontrib-jsmath @ file:///home/ktietz/src/ci/sphinxcontrib-jsmath_1611920942228/work
# sphinxcontrib-qthelp @ file:///home/ktietz/src/ci/sphinxcontrib-qthelp_1611921055322/work
# sphinxcontrib-serializinghtml @ file:///tmp/build/80754af9/sphinxcontrib-serializinghtml_1624451540180/work
# sphinxcontrib-websupport @ file:///tmp/build/80754af9/sphinxcontrib-websupport_1597081412696/work
# spyder @ file:///C:/ci/spyder_1636480369575/work
# spyder-kernels @ file:///C:/ci/spyder-kernels_1634237096710/work
# SQLAlchemy @ file:///C:/ci/sqlalchemy_1626948551162/work
# statsmodels==0.12.2
# sympy @ file:///C:/ci/sympy_1635219088507/work
# tables==3.6.1
# TBB==0.2
# tblib @ file:///Users/ktietz/demo/mc3/conda-bld/tblib_1629402031467/work
# terminado==0.9.4
# testpath @ file:///tmp/build/80754af9/testpath_1624638946665/work
# text-unidecode @ file:///Users/ktietz/demo/mc3/conda-bld/text-unidecode_1629401354553/work
# textdistance @ file:///tmp/build/80754af9/textdistance_1612461398012/work
# threadpoolctl @ file:///Users/ktietz/demo/mc3/conda-bld/threadpoolctl_1629802263681/work
# three-merge @ file:///tmp/build/80754af9/three-merge_1607553261110/work
# tifffile @ file:///tmp/build/80754af9/tifffile_1627275862826/work
# tinycss @ file:///tmp/build/80754af9/tinycss_1617713798712/work
# toml @ file:///tmp/build/80754af9/toml_1616166611790/work
# toolz @ file:///home/linux1/recipes/ci/toolz_1610987900194/work
# tornado @ file:///C:/ci/tornado_1606924294691/work
# tqdm @ file:///tmp/build/80754af9/tqdm_1635330843403/work
# traitlets @ file:///tmp/build/80754af9/traitlets_1632522747050/work
# typed-ast @ file:///C:/ci/typed-ast_1624953797214/work
# typing-extensions @ file:///tmp/build/80754af9/typing_extensions_1631814937681/work
# ujson @ file:///C:/ci/ujson_1611259568517/work
# unicodecsv==0.14.1
# Unidecode @ file:///tmp/build/80754af9/unidecode_1614712377438/work
# urllib3==1.26.7
# watchdog @ file:///C:/ci/watchdog_1624955113064/work
# wcwidth @ file:///Users/ktietz/demo/mc3/conda-bld/wcwidth_1629357192024/work
# webencodings==0.5.1
# Werkzeug @ file:///tmp/build/80754af9/werkzeug_1635505089296/work
# whichcraft @ file:///tmp/build/80754af9/whichcraft_1617751293875/work
# widgetsnbextension @ file:///C:/ci/widgetsnbextension_1607531582688/work
# win-inet-pton @ file:///C:/ci/win_inet_pton_1605306162074/work
# win-unicode-console==0.5
# wincertstore==0.2
# wrapt @ file:///C:/ci/wrapt_1607574570428/work
# xlrd @ file:///tmp/build/80754af9/xlrd_1608072521494/work
# XlsxWriter @ file:///tmp/build/80754af9/xlsxwriter_1628603415431/work
# xlwings==0.24.9
# xlwt==1.3.0
# xmltodict @ file:///Users/ktietz/demo/mc3/conda-bld/xmltodict_1629301980723/work
# yapf @ file:///tmp/build/80754af9/yapf_1615749224965/work
# zict==2.0.0
# zipp @ file:///tmp/build/80754af9/zipp_1633618647012/work
# zope.event==4.5.0
# zope.interface @ file:///C:/ci/zope.interface_1625036252485/work
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\kelvi\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\kelvi\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
class City:
    '''
    City wraps up the info about a city, including its name, coordinates,
    and belonging country.
    '''
    def __init__(self, city_name, country_code):
        self.city_name = city_name
        
        
        self.country_code = country_code

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# castro cl
# saldanha za
# kibakwe tz
# tazovskiy ru
# lorengau pg
# bilma ne
# mar del plata ar
# umm lajj sa
# victor harbor au
# los llanos de aridane es
# paita pe
# thompson ca
# ushuaia ar
# hobart au
# krasnyy chikoy ru
# port alfred za
# awjilah ly
# avarua ck
# bredasdorp za
# buena vista bo
# cape town za
# kapaa us
# kapaa us
# mataura pf
# bredasdorp za
# rikitea pf
# kapaa us
# puerto ayora ec
# nikolskoye ru
# yellowknife ca
# grand gaube mu
# hermanus za
# villa bruzual ve
# hambantota lk
# jamestown sh
# grand river south east mu
# ilulissat gl
# otradnoye ru
# castro cl
# bredasdorp za
# yankton us
# vila vu
# mar del plata ar
# mehamn no
# jamestown sh
# poum nc
# arraial do cabo br
# east london za
# souillac mu
# porto torres it
# mataura pf
# atasu kz
# bluff nz
# salme ee
# belushya guba ru
# taolanaro mg
# new norfolk au
# tasiilaq gl
# kapaa us
# mataura pf
# kapaa us
# colonial heights us
# atar mr
# komsomolskiy ru
# kuche cn
# airai pw
# bethel us
# bluff nz
# busselton au
# mount darwin zw
# lavrentiya ru
# punta arenas cl
# kodiak us
# tuktoyaktuk ca
# punta arenas cl
# pacific grove us
# te anau nz
# maceio br
# chipinge zw
# bluff nz
# morondava mg
# tuktoyaktuk ca
# cape town za
# bredasdorp za
# punta arenas cl
# vaini to
# bredasdorp za
# kapaa us
# waddan ly
# klyuchi ru
# illoqqortoormiut gl
# alofi nu
# vestmannaeyjar is
# nyurba ru
# ushuaia ar
# chokurdakh ru
# thompson ca
# amherst ca
# ushuaia ar
# uryupinsk ru
# mys shmidta ru
# ushuaia ar
# karratha au
# kavieng pg
# bredasdorp za
# gualeguay ar
# bluff nz
# katsuura jp
# rikitea pf
# bluff nz
# khatanga ru
# rikitea pf
# busselton au
# kapaa us
# port alfred za
# carnarvon au
# bredasdorp za
# barentsburg sj
# vaini to
# wa gh
# kapaa us
# cayenne gf
# saskylakh ru
# barrow us
# ushuaia ar
# tumannyy ru
# lompoc us
# gotsu jp
# datong cn
# hithadhoo mv
# mudyuga ru
# uacon ph
# pevek ru
# fairbanks us
# busselton au
# hilo us
# east london za
# doha kw
# artyk ru
# nizhneyansk ru
# luderitz na
# iqaluit ca
# nemuro jp
# albany au
# rudnichnyy ru
# east london za
# port alfred za
# busselton au
# geraldton au
# touros br
# yaan cn
# mudon mm
# vaini to
# vaini to
# coquimbo cl
# new norfolk au
# kaitangata nz
# busselton au
# nome us
# hobart au
# edson ca
# avarua ck
# norman wells ca
# peniche pt
# upernavik gl
# skara se
# torbay ca
# pisco pe
# kodiak us
# sao joao da barra br
# kahului us
# nouadhibou mr
# atuona pf
# ushuaia ar
# tuktoyaktuk ca
# melnikovo ru
# brae gb
# lipin bor ru
# atuona pf
# richards bay za
# atuona pf
# pevek ru
# egvekinot ru
# pisco pe
# ukiah us
# georgetown sh
# ancud cl
# jalu ly
# busselton au
# leningradskiy ru
# hobart au
# tulun ru
# port elizabeth za
# kaitangata nz
# hithadhoo mv
# lgov ru
# jamestown sh
# rikitea pf
# hambantota lk
# swan river ca
# jamestown sh
# kastamonu tr
# rikitea pf
# dukat ru
# arraial do cabo br
# tuktoyaktuk ca
# rikitea pf
# illoqqortoormiut gl
# bucerias mx
# georgetown sh
# faya td
# ribeira grande pt
# olafsvik is
# puerto madryn ar
# saleaula ws
# taolanaro mg
# fort nelson ca
# yellowknife ca
# ponta do sol cv
# bonavista ca
# bredasdorp za
# santa isabel do rio negro br
# saint-francois gp
# thompson ca
# faanui pf
# ushuaia ar
# vostok ru
# rawson ar
# airai pw
# nome us
# bredasdorp za
# nikolskoye ru
# moose factory ca
# cidreira br
# albany au
# lebu cl
# taolanaro mg
# tete mz
# tasiilaq gl
# bambous virieux mu
# chokurdakh ru
# castro cl
# yellowknife ca
# salta ar
# imeni poliny osipenko ru
# amderma ru
# martapura id
# tasiilaq gl
# salamiyah sy
# albany au
# merauke id
# shanhetun cn
# busselton au
# bredasdorp za
# kutum sd
# lakes entrance au
# buchanan lr
# thompson ca
# rikitea pf
# puerto ayora ec
# ushuaia ar
# ushuaia ar
# ushuaia ar
# punta arenas cl
# bluff nz
# airai pw
# atuona pf
# grand river south east mu
# crotone it
# ushuaia ar
# victoria sc
# bluff nz
# barcelona ve
# saskylakh ru
# rocha uy
# taolanaro mg
# mataura pf
# castro cl
# albany au
# cherskiy ru
# hami cn
# victoria sc
# jamestown sh
# nikolskoye ru
# brive-la-gaillarde fr
# krasnoselkup ru
# cayenne gf
# pacific grove us
# qaanaaq gl
# play cu vn
# barrow us
# kapaa us
# maceio br
# bud no
# longyearbyen sj
# karasjok no
# mulege mx
# tigil ru
# pemangkat id
# hithadhoo mv
# hermanus za
# chuy uy
# east london za
# crestview us
# mataura pf
# cabo san lucas mx
# tuxpan mx
# maunabo us
# uige ao
# georgetown sh
# upanema br
# ushuaia ar
# catalina ca
# birao cf
# yellowknife ca
# russellville us
# tucurui br
# tra vinh vn
# yellowknife ca
# ushuaia ar
# ushuaia ar
# praia da vitoria pt
# barrow us
# lensk ru
# sao joao da barra br
# chuy uy
# necochea ar
# vostok ru
# tasiilaq gl
# santa marinella it
# punta arenas cl
# talcahuano cl
# barentsburg sj
# chuy uy
# ust-shonosha ru
# abha sa
# punta arenas cl
# amderma ru
# pangnirtung ca
# la puebla de cazalla es
# qaanaaq gl
# kavaratti in
# mataura pf
# carnarvon au
# jamestown sh
# rikitea pf
# mataura pf
# atuona pf
# sentyabrskiy ru
# kapaa us
# elizabeth city us
# saint paul ca
# sao joao da barra br
# rikitea pf
# albany au
# albany au
# lavrentiya ru
# rikitea pf
# poquoson us
# new norfolk au
# georgetown sh
# samusu ws
# lavrentiya ru
# cape town za
# yar-sale ru
# the pas ca
# kutum sd
# schalksmuhle de
# krasnokamensk ru
# norman wells ca
# virginia beach us
# vaini to
# wattegama lk
# cabo san lucas mx
# marfino ru
# albany au
# cape town za
# port elizabeth za
# talnakh ru
# albany au
# faya td
# rikitea pf
# ugoofaaru mv
# avarua ck
# socorro us
# georgetown sh
# bluff nz
# iturama br
# kudahuvadhoo mv
# sentyabrskiy ru
# georgetown sh
# egvekinot ru
# bluff nz
# kaitangata nz
# kodiak us
# pringsewu id
# tuktoyaktuk ca
# jiquilisco sv
# bredasdorp za
# half moon bay us
# victoria sc
# sorland no
# balabac ph
# pisco pe
# albany au
# jamestown sh
# kapaa us
# high level ca
# kloulklubed pw
# neka ir
# victoria sc
# ushuaia ar
# tourlaville fr
# cockburn town tc
# bredasdorp za
# touros br
# ginda er
# belushya guba ru
# rikitea pf
# general jose eduvigis diaz py
# castro cl
# busselton au
# el balyana eg
# busselton au
# geraldton au
# leningradskiy ru
# chuy uy
# barentsburg sj
# homer us
# punta arenas cl
# rikitea pf
# kuche cn
# lavrentiya ru
# zhigansk ru
# thompson ca
# rikitea pf
# albany au
# rikitea pf
# tiksi ru
# ixtapa mx
# rikitea pf
# karratha au
# san patricio mx
# rikitea pf
# santiago de cuba cu
# tautira pf
# dunedin nz
# lubben de
# manzanillo mx
# olafsvik is
# jacmel ht
# guymon us
# itagiba br
# labuhan id
# hobart au
# port hedland au
# ushuaia ar
# tezpur in
# hermanus za
# ushuaia ar
# chaumont fr
# rikitea pf
# belushya guba ru
# jamestown sh
# oranjemund na
# khatanga ru
# albany au
# kulebaki ru
# zabaykalsk ru
# kapaa us
# punta arenas cl
# atuona pf
# bethel us
# butaritari ki
# attawapiskat ca
# saint george bm
# busselton au
# rikitea pf
# rikitea pf
# ostrovnoy ru
# salalah om
# busselton au
# kaitangata nz
# tasiilaq gl
# bluff nz
# tayshet ru
# hilo us
# qaanaaq gl
# luganville vu
# beringovskiy ru
# tasiilaq gl
# busselton au
# mataura pf
# port elizabeth za
# sindand af
# taolanaro mg
# dingle ie
# chavantes br
# fairbanks us
# cairns au
# casper us
# troitskoye ru
# saint-philippe re
# myitkyina mm
# la asuncion ve
# tsumeb na
# aklavik ca
# manokwari id
# kahului us
# san quintin mx
# ushuaia ar
# hithadhoo mv
# kashan ir
# kapaa us
# longyearbyen sj
# barentsburg sj
# ahuimanu us
# puerto ayora ec
# chuy uy
# narsaq gl
# albany au
# nantucket us
# mataura pf
# thompson ca
# attawapiskat ca
# taolanaro mg
# saint-philippe re
# formoso do araguaia br
# sao jose da coroa grande br
# tsihombe mg
# cape town za
# taolanaro mg
# nizhneyansk ru
# ushuaia ar
# condado cu
# narnaul in
# kahului us
# severo-kurilsk ru
# busselton au
# ushuaia ar
# dandong cn
# bluff nz
# kapaa us
# saint-philippe re
# lipin bor ru
# santa maria cv
# lundazi zm
# bluff nz
# veraval in
# tumannyy ru
# severo-kurilsk ru
# punta arenas cl
# thinadhoo mv
# umzimvubu za
# ushuaia ar
# jamestown sh
# cape town za
# atuona pf
# aswan eg
# albany au
# saint-philippe re
# irtyshskiy ru
# macomer it
# savannah bight hn
# ushuaia ar
# east london za
# airai pw
# kodiak us
# newala tz
# iquitos pe
# busselton au
# vaini to
# mokhsogollokh ru
# butaritari ki
# jamestown sh
# puerto ayora ec
# bredasdorp za
# georgetown sh
# kouqian cn
# hami cn
# albany au
# udachnyy ru
# zheleznodorozhnyy ru
# kapaa us
# kapaa us
# taolanaro mg
# paidha ug
# nanortalik gl
# rikitea pf
# port alfred za
# saldanha za
# atuona pf
# atuona pf
# leninogorsk ru
# kapaa us
# hilo us
# ravar ir
# kimbe pg
# tome-acu br
# natal br
# andenes no
# tambopata pe
# taolanaro mg
# jamestown sh
# mataura pf
# beloha mg
# souillac mu
# kodiak us
# cidreira br
# atuona pf
# karaton kz
# tongchuan cn
# hermanus za
# bluff nz
# albany au
# dudinka ru
# hobart au
# bluff nz
# grindavik is
# punta arenas cl
# victoria sc
# bambous virieux mu
# mataura pf
# iskateley ru
# dalvik is
# dzhusaly kz
# jiutai cn
# port lincoln au
# ponta do sol cv
# grand river south east mu
# constitucion mx
# balabagan ph
# castro cl
# turukhansk ru
# marzuq ly
# cockburn town tc
# georgetown sh
# vaini to
# carnarvon au
# taltal cl
# jamestown sh
# neepawa ca
# biloela au
# mar del plata ar
# puerto ayora ec
# hermanus za
# longyearbyen sj
# dibai in
# severo-kurilsk ru
# pangnirtung ca
# fortuna us
# cherskiy ru
# ensley us
# qaanaaq gl
# mackay au
# port alfred za
# ilulissat gl
# carnarvon au
# sao filipe cv
# illoqqortoormiut gl
# ushuaia ar
# talnakh ru
# bonthe sl
# fortuna us
# mataura pf
# bethel us
# castro cl
# murmashi ru
# umzimvubu za
# cape town za
# mataura pf
# nanortalik gl
# castro cl
# krasnoselkup ru
# ahipara nz
# port alfred za
# ushuaia ar
# gazimurskiy zavod ru
# nizhneyansk ru
# durham us
# bandarbeyla so
# san jeronimo mx
# grindavik is
# ushuaia ar
# norman wells ca
# puerto ayora ec
# sur om
# albany au
# zwedru lr
# bluff nz
# bluff nz
# magaria ne
# severo-kurilsk ru
# richards bay za
# coquimbo cl
# khariessa gr
# bengkulu id
# avarua ck
# provideniya ru
# hobart au
# lorengau pg
# busselton au
# punta arenas cl
# sikonge tz
# isla vista us
# deoria in
# katsuura jp
# phan thiet vn
# bluff nz
# hermanus za
# tiksi ru
# rikitea pf
# taonan cn
# tsihombe mg
# albany au
# busselton au
# mataura pf
# rikitea pf
# hobart au
# akureyri is
# pierre us
# arraial do cabo br
# busselton au
# lucapa ao
# west bay ky
# cape town za
# albany au
# hilo us
# vaitupu wf
# mataura pf
# albany au
# albany au
# tawkar sd
# hilo us
# ushuaia ar
# yellowknife ca
# merauke id
# taolanaro mg
# ilulissat gl
# kapaa us
# belushya guba ru
# petropavl kz
# port hardy ca
# busselton au
# omboue ga
# yatou cn
# illoqqortoormiut gl
# rikitea pf
# tsihombe mg
# ushuaia ar
# namibe ao
# faanui pf
# cockburn town tc
# belmonte br
# aklavik ca
# naryan-mar ru
# bluff nz
# attawapiskat ca
# camacha pt
# kabo cf
# yafran ly
# taolanaro mg
# sumbe ao
# lebu cl
# busselton au
# taolanaro mg
# lagoa pt
# hermanus za
# lebu cl
# dikson ru
# atuona pf
# carnarvon au
# bubaque gw
# rikitea pf
# kodiak us
# kargil in
# qaanaaq gl
# dikson ru
# saleaula ws
# nanortalik gl
# mataura pf
# new norfolk au
# kushima jp
# butaritari ki
# tuktoyaktuk ca
# qaanaaq gl
# albany au
# belaya gora ru
# tabiauea ki
# kamaishi jp
# attawapiskat ca
# labuhan id
# narsaq gl
# busselton au
# atuona pf
# bengkulu id
# ushuaia ar
# attawapiskat ca
# meulaboh id
# tuktoyaktuk ca
# neokhorion gr
# castro cl
# sitka us
# taolanaro mg
# negombo lk
# hilo us
# bethel us
# dikson ru
# tasiilaq gl
# haines junction ca
# cape town za
# la massana ad
# ushuaia ar
# alice springs au
# mataura pf
# jamestown sh
# new waterford ca
# esmeraldas br
# santa maria la alta mx
# cape town za
# bluff nz
# kahului us
# albany au
# castro cl
# mataura pf
# hermanus za
# pelym ru
# ribeira grande pt
# alofi nu
# khatanga ru
# peniche pt
# saint-pierre pm
# wattegama lk
# tiksi ru
# new norfolk au
# klaksvik fo
# herat af
# vaini to
# saint-philippe re
# taolanaro mg
# ginda er
# castro cl
# dunedin nz
# siilinjarvi fi
# busselton au
# genhe cn
# mataura pf
# cananeia br
# amderma ru
# punta arenas cl
# rongcheng cn
# yellowknife ca
# birao cf
# hirara jp
# mar del plata ar
# vaini to
# winnipeg ca
# asau tv
# barentsburg sj
# bluff nz
# mataura pf
# sangar ru
# east london za
# komsomolskiy ru
# tall kayf iq
# ushuaia ar
# victoria sc
# kulhudhuffushi mv
# koumac nc
# mys shmidta ru
# vereeniging za
# nanortalik gl
# hermanus za
# albany au
# vaini to
# hithadhoo mv
# saint-philippe re
# hobart au
# avarua ck
# provideniya ru
# castro cl
# punta arenas cl
# barentsburg sj
# ushuaia ar
# busselton au
# boaco ni
# anchorage us
# taltal cl
# rock sound bs
# avarua ck
# liverpool ca
# ilulissat gl
# san vicente ph
# husavik is
# akdepe tm
# cloquet us
# airai pw
# sestri levante it
# luderitz na
# busselton au
# hobart au
# acapulco mx
# pacific grove us
# cape town za
# busselton au
# kingsville us
# port lincoln au
# taolanaro mg
# padang id
# hilo us
# mataura pf
# semirom ir
# bahjoi in
# fortuna foothills us
# meulaboh id
# tuktoyaktuk ca
# torbay ca
# avarua ck
# new norfolk au
# vaini to
# rikitea pf
# port lincoln au
# hithadhoo mv
# labutta mm
# grand river south east mu
# vestmannaeyjar is
# mwene-ditu cd
# grand river south east mu
# coihaique cl
# jarjis tn
# chapais ca
# norman wells ca
# novobirilyussy ru
# huarmey pe
# tuktoyaktuk ca
# mataura pf
# bluff nz
# linguere sn
# talnakh ru
# taolanaro mg
# busselton au
# atuona pf
# rikitea pf
# fortuna us
# tasiilaq gl
# mezen ru
# ushuaia ar
# necochea ar
# illoqqortoormiut gl
# narsaq gl
# thinadhoo mv
# palabuhanratu id
# cherskiy ru
# georgetown sh
# kruisfontein za
# nabire id
# carnarvon au
# tual id
# nikolskoye ru
# mar del plata ar
# butaritari ki
# mys shmidta ru
# arraial do cabo br
# rikitea pf
# busselton au
# kabwe zm
# ponta delgada pt
# san cristobal ec
# arraial do cabo br
# grand gaube mu
# oranjemund na
# george town ky
# pangnirtung ca
# hermanus za
# foumban cm
# kwinana au
# ostrovnoy ru
# khatanga ru
# port elizabeth za
# snezhnogorsk ru
# vestmannaeyjar is
# yar-sale ru
# touros br
# jamestown sh
# samusu ws
# fort nelson ca
# butaritari ki
# punta arenas cl
# upernavik gl
# jamestown sh
# port alfred za
# busselton au
# vaini to
# barrow us
# rengasdengklok id
# tual id
# petropavlovsk-kamchatskiy ru
# geraldton au
# vila franca do campo pt
# samusu ws
# biak id
# san patricio mx
# marquette us
# ust-kuyga ru
# mataura pf
# rikitea pf
# salalah om
# krasnoselkup ru
# ushuaia ar
# illoqqortoormiut gl
# canoinhas br
# asau tv
# saleaula ws
# saint-philippe re
# fort oglethorpe us
# rikitea pf
# haines junction ca
# asau tv
# bluff nz
# storforshei no
# khatanga ru
# qaanaaq gl
# attawapiskat ca
# hilo us
# korcula hr
# bluff nz
# kawalu id
# saint-philippe re
# illoqqortoormiut gl
# taolanaro mg
# mar del plata ar
# bambous virieux mu
# upernavik gl
# butaritari ki
# seoul kr
# batagay-alyta ru
# moerai pf
# busselton au
# mataura pf
# olafsvik is
# la gaulette mu
# yellowknife ca
# bredasdorp za
# qaanaaq gl
# mataura pf
# mar del plata ar
# albany au
# bredasdorp za
# hofn is
# albany au
# arraial do cabo br
# gat ly
# tsihombe mg
# litoral del san juan co
# airai pw
# busselton au
# narsaq gl
# port blair in
# rikitea pf
# barrow us
# kapaa us
# bredasdorp za
# castro cl
# atuona pf
# lagoa pt
# punta arenas cl
# spornoye ru
# hermanus za
# dali cn
# mataura pf
# port alfred za
# pucallpa pe
# butaritari ki
# east london za
# yarke pole ua
# hilo us
# vaini to
# merauke id
# rikitea pf
# cape town za
# chokurdakh ru
# esperance au
# waingapu id
# sugod ph
# port elizabeth za
# hamilton bm
# hithadhoo mv
# hermanus za
# dikson ru
# khudumelapye bw
# ardabil ir
# paita nc
# tuatapere nz
# kenora ca
# rikitea pf
# kapaa us
# albany au
# elat il
# punta arenas cl
# ust-kamchatsk ru
# bluff nz
# sao filipe cv
# portland au
# tezu in
# paramonga pe
# busselton au
# castro cl
# camaguey cu
# ushuaia ar
# umm bab qa
# lebu cl
# rikitea pf
# ushuaia ar
# carnarvon au
# poya nc
# vaini to
# vardo no
# saskylakh ru
# yellowknife ca
# ushuaia ar
# punta arenas cl
# busselton au
# yellowknife ca
# saint-francois gp
# kapaa us
# punta arenas cl
# port victoria ke
# east london za
# rikitea pf
# lagoa pt
# nikolskoye ru
# arraial do cabo br
# saleaula ws
# almenara br
# jamame so
# punta arenas cl
# san francisco del mar mx
# kommunar ru
# college us
# avera pf
# panaba mx
# cherskiy ru
# vaini to
# yellowknife ca
# ancud cl
# laguna br
# atar mr
# kruisfontein za
# qaanaaq gl
# tasiilaq gl
# xique-xique br
# hobart au
# hilo us
# bethel us
# east london za
# fairbanks us
# souillac mu
# new norfolk au
# mar del plata ar
# hanmer springs nz
# tuktoyaktuk ca
# bluff nz
# barrow us
# mataura pf
# new norfolk au
# kavieng pg
# kurilsk ru
# luganville vu
# henties bay na
# juba sd
# hilo us
# nouakchott mr
# cape town za
# klaksvik fo
# zyryanka ru
# saint-augustin ca
# mataura pf
# athens us
# codrington ag
# fairbanks us
# guerrero negro mx
# punta arenas cl
# saskylakh ru
# san quintin mx
# ushuaia ar
# cape town za
# namatanai pg
# itacarambi br
# castro cl
# calama cl
# hobyo so
# punta arenas cl
# hamilton bm
# east london za
# belushya guba ru
# atuona pf
# cidreira br
# kodiak us
# fershampenuaz ru
# rovaniemi fi
# qaanaaq gl
# bubaque gw
# hasaki jp
# bredasdorp za
# sisimiut gl
# norman wells ca
# urulga ru
# taolanaro mg
# taolanaro mg
# carnarvon au
# fortuna us
# ushuaia ar
# tura ru
# iqaluit ca
# barrow us
# lao cai vn
# yulara au
# mar del plata ar
# yumen cn
# fortuna us
# ahome mx
# bethel us
# arraial do cabo br
# saint george bm
# kapaa us
# vaini to
# mataura pf
# busselton au
# viedma ar
# chuy uy
# castro cl
# punta arenas cl
# pangkalanbuun id
# saryshagan kz
# kaitangata nz
# hithadhoo mv
# castro cl
# aljezur pt
# chuy uy
# khatanga ru
# torbay ca
# agirish ru
# terrace ca
# busselton au
# castro cl
# rivadavia ar
# port blair in
# mina mx
# mongo td
# puerto ayora ec
# taolanaro mg
# sechura pe
# avarua ck
# sitka us
# ribeira grande pt
# wenling cn
# los llanos de aridane es
# bargal so
# chokurdakh ru
# yellowknife ca
# carnarvon au
# baykit ru
# porbandar in
# egvekinot ru
# mahebourg mu
# yellowknife ca
# qaanaaq gl
# taolanaro mg
# saint-philippe re
# san quintin mx
# iqaluit ca
# manta ec
# fort nelson ca
# ixtapa mx
# cuiluan cn
# ushuaia ar
# barhi in
# vangaindrano mg
# puerto ayora ec
# muravlenko ru
# denpasar id
# hobart au
# illoqqortoormiut gl
# vaini to
# vila franca do campo pt
# lata sb
# shache cn
# tuatapere nz
# hilo us
# hermanus za
# huarmey pe
# port elizabeth za
# mar del plata ar
# kununurra au
# labuan my
# sentyabrskiy ru
# mopti ml
# east london za
# seybaplaya mx
# japura br
# susangerd ir
# rikitea pf
# severo-kurilsk ru
# chokurdakh ru
# te anau nz
# busselton au
# viedma ar
# mar del plata ar
# salalah om
# lompoc us
# chuy uy
# lagoa pt
# ushuaia ar
# punta arenas cl
# carnarvon au
# coutances fr
# esperance au
# geraldton au
# guilin cn
# ingham au
# hobart au
# varciorog ro
# berlevag no
# bolshaya chernigovka ru
# albany au
# belushya guba ru
# atuona pf
# ulverstone au
# buala sb
# avarua ck
# hasaki jp
# busselton au
# nguiu au
# chicama pe
# tuatapere nz
# ushuaia ar
# busselton au
# puerto berrio co
# hithadhoo mv
# rikitea pf
# yulara au
# shibetsu jp
# hermanus za
# tuktoyaktuk ca
# farafangana mg
# bluff nz
# port alfred za
# amderma ru
# villarrica cl
# hobart au
# hobart au
# hovd mn
# port alfred za
# new norfolk au
# port alfred za
# mataura pf
# mar del plata ar
# cabra ph
# kiruna se
# rikitea pf
# hobart au
# rikitea pf
# barbar sd
# tiarei pf
# matara lk
# yellandu in
# te anau nz
# port alfred za
# great yarmouth gb
# cidreira br
# bluff nz
# quatre cocos mu
# illoqqortoormiut gl
# busselton au
# dikson ru
# sentyabrskiy ru
# ushuaia ar
# khatanga ru
# lubumbashi cd
# maldonado uy
# upernavik gl
# batavia us
# praia da vitoria pt
# oskarshamn se
# arraial do cabo br
# verkhnevilyuysk ru
# nikolskoye ru
# zhanaozen kz
# barentsburg sj
# barentsburg sj
# high level ca
# nakhon ratchasima th
# aonla in
# saskylakh ru
# awbari ly
# qaanaaq gl
# cape town za
# busselton au
# ribeira grande pt
# caravelas br
# mar del plata ar
# ilulissat gl
# khatanga ru
# ushuaia ar
# barrow us
# ribeira grande pt
# bolungarvik is
# matamoros mx
# synya ru
# tiksi ru
# zhigansk ru
# palabuhanratu id
# hobart au
# nizhneyansk ru
# new norfolk au
# ostrovnoy ru
# rikitea pf
# sao filipe cv
# mataura pf
# lavrentiya ru
# lompoc us
# bluff nz
# jamestown sh
# nikolskoye ru
# caravelas br
# bartica gy
# half moon bay us
# jamestown sh
# mahebourg mu
# upernavik gl
# hithadhoo mv
# ushuaia ar
# isla mujeres mx
# hilo us
# lavrentiya ru
# etchoropo mx
# khatanga ru
# avera pf
# talcahuano cl
# batagay-alyta ru
# lusambo cd
# wanning cn
# castro cl
# cidreira br
# port alfred za
# marcona pe
# salina us
# lebu cl
# illoqqortoormiut gl
# butaritari ki
# kruisfontein za
# puerto ayora ec
# mullaitivu lk
# nishihara jp
# rikitea pf
# tam ky vn
# chokurdakh ru
# mataura pf
# esperance au
# derzhavinsk kz
# hermanus za
# leningradskiy ru
# kloulklubed pw
# khatanga ru
# mataura pf
# tasiilaq gl
# sirpur in
# hobart au
# reo bf
# ushuaia ar
# jamestown sh
# kapaa us
# maceio br
# salamiyah sy
# lasa cn
# necochea ar
# ancud cl
# mataura pf
# punta arenas cl
# port elizabeth za
# rikitea pf
# iwanai jp
# busselton au
# biltine td
# dali cn
# chumikan ru
# georgetown sh
# busselton au
# kirakira sb
# san patricio mx
# tiksi ru
# belushya guba ru
# hilo us
# port alfred za
# jaru br
# rikitea pf
# rome us
# rossland ca
# rikitea pf
# torbay ca

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 600

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2a9169035ea6eb8c1b16a9de7e444748

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2a9169035ea6eb8c1b16a9de7e444748&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# call the response code with the get() method using the status_code
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"base":"stations","main":{"temp":55.94,"feels_like":53.91,"temp_min":49.33,"temp_max":59.16,"pressure":1011,"humidity":57},"visibility":10000,"wind":{"speed":0,"deg":0},"clouds":{"all":100},"dt":1652931362,"sys":{"type":1,"id":3486,"country":"US","sunrise":1652865601,"sunset":1652918494},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 55.94,
#   'feels_like': 53.91,
#   'temp_min': 49.33,
#   'temp_max': 59.16,
#   'pressure': 1011,
#   'humidity': 57},
#  'visibility': 10000,
#  'wind': {'speed': 0, 'deg': 0},
#  'clouds': {'all': 100},
#  'dt': 1652931362,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1652865601,
#   'sunset': 1652918494},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Import the dependencies.
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
# Personal Practice
# new_city="Nairobi"

# %%
# Create an endpoint URL for a city.
# city_url = url + "&q=" + "Nairobi"
# city_weather = requests.get(city_url)
# city_weather

# %%
# Get the JSON text of the 'Get' request.
# city_weather.json()

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
 print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2a9169035ea6eb8c1b16a9de7e444748&q=Bston

# %%
# For each city in our lats_lngs list, we need to retrieve the following data and add it to a DataFrame:

# City, country, and date

# Latitude and longitude

# Maximum temperature

# Humidity

# Cloudiness

# Wind speed

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

city_weather = requests.get(city_url)

city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 55.94,
#   'feels_like': 53.91,
#   'temp_min': 49.33,
#   'temp_max': 59.16,
#   'pressure': 1011,
#   'humidity': 57},
#  'visibility': 10000,
#  'wind': {'speed': 0, 'deg': 0},
#  'clouds': {'all': 100},
#  'dt': 1652931362,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1652865601,
#   'sunset': 1652918494},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']["country"]
# Out:
# 'US'

# %%
boston_data['coord']['lat']
# Out:
# 42.3584

# %%
lat = boston_data["coord"]["lat"]

lng = boston_data["coord"]["lon"]

max_temp = boston_data["main"]["temp_max"]

humidity = boston_data["main"]["humidity"]

clouds = boston_data["clouds"]["all"]

wind = boston_data["wind"]["speed"]

print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 59.16 57 100 0

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Get the date from the JSON file.
date = boston_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 5, 19, 3, 36, 2)

# %%
# We can convert this datetime format to 2019-10-21 17:24:35 using the Python string format method strftime()
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-05-19 03:36:02'

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")

print("-----------------------------")

# Create counters.
record_count = 1

set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        record_count = 1
        
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 12 | castro
# Processing Record 2 of Set 12 | saldanha
# Processing Record 3 of Set 12 | kibakwe
# Processing Record 4 of Set 12 | tazovskiy
# Processing Record 5 of Set 12 | lorengau
# Processing Record 6 of Set 12 | bilma
# Processing Record 7 of Set 12 | mar del plata
# Processing Record 8 of Set 12 | umm lajj
# Processing Record 9 of Set 12 | victor harbor
# Processing Record 10 of Set 12 | los llanos de aridane
# Processing Record 11 of Set 12 | paita
# Processing Record 12 of Set 12 | thompson
# Processing Record 13 of Set 12 | ushuaia
# Processing Record 14 of Set 12 | hobart
# Processing Record 15 of Set 12 | krasnyy chikoy
# Processing Record 16 of Set 12 | port alfred
# Processing Record 17 of Set 12 | awjilah
# Processing Record 18 of Set 12 | avarua
# Processing Record 19 of Set 12 | bredasdorp
# Processing Record 20 of Set 12 | buena vista
# Processing Record 21 of Set 12 | cape town
# Processing Record 22 of Set 12 | kapaa
# Processing Record 23 of Set 12 | mataura
# Processing Record 24 of Set 12 | rikitea
# Processing Record 25 of Set 12 | puerto ayora
# Processing Record 26 of Set 12 | nikolskoye
# Processing Record 27 of Set 12 | yellowknife
# Processing Record 28 of Set 12 | grand gaube
# Processing Record 29 of Set 12 | hermanus
# Processing Record 30 of Set 12 | villa bruzual
# Processing Record 31 of Set 12 | hambantota
# Processing Record 32 of Set 12 | jamestown
# Processing Record 33 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 12 | ilulissat
# Processing Record 35 of Set 12 | otradnoye
# Processing Record 36 of Set 12 | yankton
# Processing Record 37 of Set 12 | vila
# Processing Record 38 of Set 12 | mehamn
# Processing Record 39 of Set 12 | poum
# Processing Record 40 of Set 12 | arraial do cabo
# Processing Record 41 of Set 12 | east london
# Processing Record 42 of Set 12 | souillac
# Processing Record 43 of Set 12 | porto torres
# Processing Record 44 of Set 12 | atasu
# Processing Record 45 of Set 12 | bluff
# Processing Record 46 of Set 12 | salme
# Processing Record 47 of Set 12 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 12 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 12 | new norfolk
# Processing Record 50 of Set 12 | tasiilaq
# Processing Record 1 of Set 13 | colonial heights
# Processing Record 2 of Set 13 | atar
# Processing Record 3 of Set 13 | komsomolskiy
# Processing Record 4 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 13 | airai
# Processing Record 6 of Set 13 | bethel
# Processing Record 7 of Set 13 | busselton
# Processing Record 8 of Set 13 | mount darwin
# Processing Record 9 of Set 13 | lavrentiya
# Processing Record 10 of Set 13 | punta arenas
# Processing Record 11 of Set 13 | kodiak
# Processing Record 12 of Set 13 | tuktoyaktuk
# Processing Record 13 of Set 13 | pacific grove
# Processing Record 14 of Set 13 | te anau
# Processing Record 15 of Set 13 | maceio
# Processing Record 16 of Set 13 | chipinge
# Processing Record 17 of Set 13 | morondava
# Processing Record 18 of Set 13 | vaini
# Processing Record 19 of Set 13 | waddan
# Processing Record 20 of Set 13 | klyuchi
# Processing Record 21 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 13 | alofi
# Processing Record 23 of Set 13 | vestmannaeyjar
# Processing Record 24 of Set 13 | nyurba
# Processing Record 25 of Set 13 | chokurdakh
# Processing Record 26 of Set 13 | amherst
# Processing Record 27 of Set 13 | uryupinsk
# Processing Record 28 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 13 | karratha
# Processing Record 30 of Set 13 | kavieng
# Processing Record 31 of Set 13 | gualeguay
# Processing Record 32 of Set 13 | katsuura
# Processing Record 33 of Set 13 | khatanga
# Processing Record 34 of Set 13 | carnarvon
# Processing Record 35 of Set 13 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 13 | wa
# City not found. Skipping...
# Processing Record 37 of Set 13 | cayenne
# Processing Record 38 of Set 13 | saskylakh
# Processing Record 39 of Set 13 | barrow
# Processing Record 40 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 13 | lompoc
# Processing Record 42 of Set 13 | gotsu
# Processing Record 43 of Set 13 | datong
# Processing Record 44 of Set 13 | hithadhoo
# Processing Record 45 of Set 13 | mudyuga
# City not found. Skipping...
# Processing Record 46 of Set 13 | uacon
# Processing Record 47 of Set 13 | pevek
# Processing Record 48 of Set 13 | fairbanks
# Processing Record 49 of Set 13 | hilo
# Processing Record 50 of Set 13 | doha
# Processing Record 1 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 14 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 14 | luderitz
# Processing Record 4 of Set 14 | iqaluit
# Processing Record 5 of Set 14 | nemuro
# Processing Record 6 of Set 14 | albany
# Processing Record 7 of Set 14 | rudnichnyy
# Processing Record 8 of Set 14 | geraldton
# Processing Record 9 of Set 14 | touros
# Processing Record 10 of Set 14 | yaan
# Processing Record 11 of Set 14 | mudon
# Processing Record 12 of Set 14 | coquimbo
# Processing Record 13 of Set 14 | kaitangata
# Processing Record 14 of Set 14 | nome
# Processing Record 15 of Set 14 | edson
# Processing Record 16 of Set 14 | norman wells
# Processing Record 17 of Set 14 | peniche
# Processing Record 18 of Set 14 | upernavik
# Processing Record 19 of Set 14 | skara
# Processing Record 20 of Set 14 | torbay
# Processing Record 21 of Set 14 | pisco
# Processing Record 22 of Set 14 | sao joao da barra
# Processing Record 23 of Set 14 | kahului
# Processing Record 24 of Set 14 | nouadhibou
# Processing Record 25 of Set 14 | atuona
# Processing Record 26 of Set 14 | melnikovo
# Processing Record 27 of Set 14 | brae
# Processing Record 28 of Set 14 | lipin bor
# Processing Record 29 of Set 14 | richards bay
# Processing Record 30 of Set 14 | egvekinot
# Processing Record 31 of Set 14 | ukiah
# Processing Record 32 of Set 14 | georgetown
# Processing Record 33 of Set 14 | ancud
# Processing Record 34 of Set 14 | jalu
# Processing Record 35 of Set 14 | leningradskiy
# Processing Record 36 of Set 14 | tulun
# Processing Record 37 of Set 14 | port elizabeth
# Processing Record 38 of Set 14 | lgov
# Processing Record 39 of Set 14 | swan river
# Processing Record 40 of Set 14 | kastamonu
# Processing Record 41 of Set 14 | dukat
# Processing Record 42 of Set 14 | bucerias
# Processing Record 43 of Set 14 | faya
# Processing Record 44 of Set 14 | ribeira grande
# Processing Record 45 of Set 14 | olafsvik
# Processing Record 46 of Set 14 | puerto madryn
# Processing Record 47 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 14 | fort nelson
# Processing Record 49 of Set 14 | ponta do sol
# Processing Record 50 of Set 14 | bonavista
# Processing Record 1 of Set 15 | santa isabel do rio negro
# Processing Record 2 of Set 15 | saint-francois
# Processing Record 3 of Set 15 | faanui
# Processing Record 4 of Set 15 | vostok
# Processing Record 5 of Set 15 | rawson
# Processing Record 6 of Set 15 | moose factory
# Processing Record 7 of Set 15 | cidreira
# Processing Record 8 of Set 15 | lebu
# Processing Record 9 of Set 15 | tete
# Processing Record 10 of Set 15 | bambous virieux
# Processing Record 11 of Set 15 | salta
# Processing Record 12 of Set 15 | imeni poliny osipenko
# Processing Record 13 of Set 15 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 15 | martapura
# Processing Record 15 of Set 15 | salamiyah
# Processing Record 16 of Set 15 | merauke
# Processing Record 17 of Set 15 | shanhetun
# Processing Record 18 of Set 15 | kutum
# Processing Record 19 of Set 15 | lakes entrance
# Processing Record 20 of Set 15 | buchanan
# Processing Record 21 of Set 15 | crotone
# Processing Record 22 of Set 15 | victoria
# Processing Record 23 of Set 15 | barcelona
# Processing Record 24 of Set 15 | rocha
# Processing Record 25 of Set 15 | cherskiy
# Processing Record 26 of Set 15 | hami
# Processing Record 27 of Set 15 | brive-la-gaillarde
# Processing Record 28 of Set 15 | krasnoselkup
# Processing Record 29 of Set 15 | qaanaaq
# Processing Record 30 of Set 15 | play cu
# City not found. Skipping...
# Processing Record 31 of Set 15 | bud
# Processing Record 32 of Set 15 | longyearbyen
# Processing Record 33 of Set 15 | karasjok
# Processing Record 34 of Set 15 | mulege
# Processing Record 35 of Set 15 | tigil
# Processing Record 36 of Set 15 | pemangkat
# Processing Record 37 of Set 15 | chuy
# Processing Record 38 of Set 15 | crestview
# Processing Record 39 of Set 15 | cabo san lucas
# Processing Record 40 of Set 15 | tuxpan
# Processing Record 41 of Set 15 | maunabo
# Processing Record 42 of Set 15 | uige
# Processing Record 43 of Set 15 | upanema
# Processing Record 44 of Set 15 | catalina
# Processing Record 45 of Set 15 | birao
# Processing Record 46 of Set 15 | russellville
# Processing Record 47 of Set 15 | tucurui
# Processing Record 48 of Set 15 | tra vinh
# Processing Record 49 of Set 15 | praia da vitoria
# Processing Record 50 of Set 15 | lensk
# Processing Record 1 of Set 16 | necochea
# Processing Record 2 of Set 16 | santa marinella
# Processing Record 3 of Set 16 | talcahuano
# Processing Record 4 of Set 16 | ust-shonosha
# Processing Record 5 of Set 16 | abha
# Processing Record 6 of Set 16 | pangnirtung
# Processing Record 7 of Set 16 | la puebla de cazalla
# Processing Record 8 of Set 16 | kavaratti
# Processing Record 9 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 16 | elizabeth city
# Processing Record 11 of Set 16 | saint paul
# Processing Record 12 of Set 16 | poquoson
# Processing Record 13 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 16 | yar-sale
# Processing Record 15 of Set 16 | the pas
# Processing Record 16 of Set 16 | schalksmuhle
# Processing Record 17 of Set 16 | krasnokamensk
# Processing Record 18 of Set 16 | virginia beach
# Processing Record 19 of Set 16 | wattegama
# Processing Record 20 of Set 16 | marfino
# Processing Record 21 of Set 16 | talnakh
# Processing Record 22 of Set 16 | ugoofaaru
# Processing Record 23 of Set 16 | socorro
# Processing Record 24 of Set 16 | iturama
# Processing Record 25 of Set 16 | kudahuvadhoo
# Processing Record 26 of Set 16 | pringsewu
# Processing Record 27 of Set 16 | jiquilisco
# Processing Record 28 of Set 16 | half moon bay
# Processing Record 29 of Set 16 | sorland
# Processing Record 30 of Set 16 | balabac
# Processing Record 31 of Set 16 | high level
# Processing Record 32 of Set 16 | kloulklubed
# Processing Record 33 of Set 16 | neka
# Processing Record 34 of Set 16 | tourlaville
# Processing Record 35 of Set 16 | cockburn town
# Processing Record 36 of Set 16 | ginda
# Processing Record 37 of Set 16 | general jose eduvigis diaz
# Processing Record 38 of Set 16 | el balyana
# City not found. Skipping...
# Processing Record 39 of Set 16 | homer
# Processing Record 40 of Set 16 | zhigansk
# Processing Record 41 of Set 16 | tiksi
# Processing Record 42 of Set 16 | ixtapa
# Processing Record 43 of Set 16 | san patricio
# Processing Record 44 of Set 16 | santiago de cuba
# Processing Record 45 of Set 16 | tautira
# Processing Record 46 of Set 16 | dunedin
# Processing Record 47 of Set 16 | lubben
# Processing Record 48 of Set 16 | manzanillo
# Processing Record 49 of Set 16 | jacmel
# Processing Record 50 of Set 16 | guymon
# Processing Record 1 of Set 17 | itagiba
# Processing Record 2 of Set 17 | labuhan
# Processing Record 3 of Set 17 | port hedland
# Processing Record 4 of Set 17 | tezpur
# Processing Record 5 of Set 17 | chaumont
# Processing Record 6 of Set 17 | oranjemund
# Processing Record 7 of Set 17 | kulebaki
# Processing Record 8 of Set 17 | zabaykalsk
# Processing Record 9 of Set 17 | butaritari
# Processing Record 10 of Set 17 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 17 | saint george
# Processing Record 12 of Set 17 | ostrovnoy
# Processing Record 13 of Set 17 | salalah
# Processing Record 14 of Set 17 | tayshet
# Processing Record 15 of Set 17 | luganville
# Processing Record 16 of Set 17 | beringovskiy
# Processing Record 17 of Set 17 | sindand
# City not found. Skipping...
# Processing Record 18 of Set 17 | dingle
# Processing Record 19 of Set 17 | chavantes
# Processing Record 20 of Set 17 | cairns
# Processing Record 21 of Set 17 | casper
# Processing Record 22 of Set 17 | troitskoye
# Processing Record 23 of Set 17 | saint-philippe
# Processing Record 24 of Set 17 | myitkyina
# Processing Record 25 of Set 17 | la asuncion
# Processing Record 26 of Set 17 | tsumeb
# Processing Record 27 of Set 17 | aklavik
# Processing Record 28 of Set 17 | manokwari
# Processing Record 29 of Set 17 | san quintin
# Processing Record 30 of Set 17 | kashan
# Processing Record 31 of Set 17 | ahuimanu
# Processing Record 32 of Set 17 | narsaq
# Processing Record 33 of Set 17 | nantucket
# Processing Record 34 of Set 17 | formoso do araguaia
# City not found. Skipping...
# Processing Record 35 of Set 17 | sao jose da coroa grande
# Processing Record 36 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 17 | condado
# Processing Record 38 of Set 17 | narnaul
# Processing Record 39 of Set 17 | severo-kurilsk
# Processing Record 40 of Set 17 | dandong
# Processing Record 41 of Set 17 | santa maria
# Processing Record 42 of Set 17 | lundazi
# Processing Record 43 of Set 17 | veraval
# Processing Record 44 of Set 17 | thinadhoo
# Processing Record 45 of Set 17 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 17 | aswan
# Processing Record 47 of Set 17 | irtyshskiy
# Processing Record 48 of Set 17 | macomer
# Processing Record 49 of Set 17 | savannah bight
# Processing Record 50 of Set 17 | newala
# Processing Record 1 of Set 18 | iquitos
# Processing Record 2 of Set 18 | mokhsogollokh
# Processing Record 3 of Set 18 | kouqian
# Processing Record 4 of Set 18 | udachnyy
# Processing Record 5 of Set 18 | zheleznodorozhnyy
# Processing Record 6 of Set 18 | paidha
# Processing Record 7 of Set 18 | nanortalik
# Processing Record 8 of Set 18 | leninogorsk
# Processing Record 9 of Set 18 | ravar
# Processing Record 10 of Set 18 | kimbe
# Processing Record 11 of Set 18 | tome-acu
# City not found. Skipping...
# Processing Record 12 of Set 18 | natal
# Processing Record 13 of Set 18 | andenes
# Processing Record 14 of Set 18 | tambopata
# Processing Record 15 of Set 18 | beloha
# Processing Record 16 of Set 18 | karaton
# Processing Record 17 of Set 18 | tongchuan
# Processing Record 18 of Set 18 | dudinka
# Processing Record 19 of Set 18 | grindavik
# Processing Record 20 of Set 18 | iskateley
# Processing Record 21 of Set 18 | dalvik
# Processing Record 22 of Set 18 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 18 | jiutai
# Processing Record 24 of Set 18 | port lincoln
# Processing Record 25 of Set 18 | constitucion
# Processing Record 26 of Set 18 | balabagan
# Processing Record 27 of Set 18 | turukhansk
# Processing Record 28 of Set 18 | marzuq
# Processing Record 29 of Set 18 | taltal
# Processing Record 30 of Set 18 | neepawa
# Processing Record 31 of Set 18 | biloela
# Processing Record 32 of Set 18 | dibai
# Processing Record 33 of Set 18 | fortuna
# Processing Record 34 of Set 18 | ensley
# Processing Record 35 of Set 18 | mackay
# Processing Record 36 of Set 18 | sao filipe
# Processing Record 37 of Set 18 | bonthe
# Processing Record 38 of Set 18 | murmashi
# Processing Record 39 of Set 18 | ahipara
# Processing Record 40 of Set 18 | gazimurskiy zavod
# Processing Record 41 of Set 18 | durham
# Processing Record 42 of Set 18 | bandarbeyla
# Processing Record 43 of Set 18 | san jeronimo
# Processing Record 44 of Set 18 | sur
# Processing Record 45 of Set 18 | zwedru
# Processing Record 46 of Set 18 | magaria
# Processing Record 47 of Set 18 | khariessa
# City not found. Skipping...
# Processing Record 48 of Set 18 | bengkulu
# Processing Record 49 of Set 18 | provideniya
# Processing Record 50 of Set 18 | sikonge
# Processing Record 1 of Set 19 | isla vista
# Processing Record 2 of Set 19 | deoria
# Processing Record 3 of Set 19 | phan thiet
# Processing Record 4 of Set 19 | taonan
# Processing Record 5 of Set 19 | akureyri
# Processing Record 6 of Set 19 | pierre
# Processing Record 7 of Set 19 | lucapa
# Processing Record 8 of Set 19 | west bay
# Processing Record 9 of Set 19 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 19 | tawkar
# City not found. Skipping...
# Processing Record 11 of Set 19 | petropavl
# Processing Record 12 of Set 19 | port hardy
# Processing Record 13 of Set 19 | omboue
# Processing Record 14 of Set 19 | yatou
# Processing Record 15 of Set 19 | namibe
# Processing Record 16 of Set 19 | belmonte
# Processing Record 17 of Set 19 | naryan-mar
# Processing Record 18 of Set 19 | camacha
# Processing Record 19 of Set 19 | kabo
# Processing Record 20 of Set 19 | yafran
# Processing Record 21 of Set 19 | sumbe
# Processing Record 22 of Set 19 | lagoa
# Processing Record 23 of Set 19 | dikson
# Processing Record 24 of Set 19 | bubaque
# Processing Record 25 of Set 19 | kargil
# Processing Record 26 of Set 19 | kushima
# Processing Record 27 of Set 19 | belaya gora
# Processing Record 28 of Set 19 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 19 | kamaishi
# Processing Record 30 of Set 19 | meulaboh
# Processing Record 31 of Set 19 | neokhorion
# Processing Record 32 of Set 19 | sitka
# Processing Record 33 of Set 19 | negombo
# Processing Record 34 of Set 19 | haines junction
# Processing Record 35 of Set 19 | la massana
# Processing Record 36 of Set 19 | alice springs
# Processing Record 37 of Set 19 | new waterford
# Processing Record 38 of Set 19 | esmeraldas
# Processing Record 39 of Set 19 | santa maria la alta
# Processing Record 40 of Set 19 | pelym
# Processing Record 41 of Set 19 | saint-pierre
# Processing Record 42 of Set 19 | klaksvik
# Processing Record 43 of Set 19 | herat
# Processing Record 44 of Set 19 | siilinjarvi
# Processing Record 45 of Set 19 | genhe
# Processing Record 46 of Set 19 | cananeia
# Processing Record 47 of Set 19 | rongcheng
# Processing Record 48 of Set 19 | hirara
# Processing Record 49 of Set 19 | winnipeg
# Processing Record 50 of Set 19 | asau
# Processing Record 1 of Set 20 | sangar
# Processing Record 2 of Set 20 | tall kayf
# Processing Record 3 of Set 20 | kulhudhuffushi
# Processing Record 4 of Set 20 | koumac
# Processing Record 5 of Set 20 | vereeniging
# Processing Record 6 of Set 20 | boaco
# Processing Record 7 of Set 20 | anchorage
# Processing Record 8 of Set 20 | rock sound
# Processing Record 9 of Set 20 | liverpool
# Processing Record 10 of Set 20 | san vicente
# Processing Record 11 of Set 20 | husavik
# Processing Record 12 of Set 20 | akdepe
# Processing Record 13 of Set 20 | cloquet
# Processing Record 14 of Set 20 | sestri levante
# Processing Record 15 of Set 20 | acapulco
# Processing Record 16 of Set 20 | kingsville
# Processing Record 17 of Set 20 | padang
# Processing Record 18 of Set 20 | semirom
# Processing Record 19 of Set 20 | bahjoi
# Processing Record 20 of Set 20 | fortuna foothills
# Processing Record 21 of Set 20 | labutta
# City not found. Skipping...
# Processing Record 22 of Set 20 | mwene-ditu
# Processing Record 23 of Set 20 | coihaique
# Processing Record 24 of Set 20 | jarjis
# City not found. Skipping...
# Processing Record 25 of Set 20 | chapais
# Processing Record 26 of Set 20 | novobirilyussy
# Processing Record 27 of Set 20 | huarmey
# Processing Record 28 of Set 20 | linguere
# Processing Record 29 of Set 20 | mezen
# Processing Record 30 of Set 20 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 20 | kruisfontein
# Processing Record 32 of Set 20 | nabire
# Processing Record 33 of Set 20 | tual
# Processing Record 34 of Set 20 | kabwe
# Processing Record 35 of Set 20 | ponta delgada
# Processing Record 36 of Set 20 | san cristobal
# Processing Record 37 of Set 20 | george town
# Processing Record 38 of Set 20 | foumban
# Processing Record 39 of Set 20 | kwinana
# Processing Record 40 of Set 20 | snezhnogorsk
# Processing Record 41 of Set 20 | rengasdengklok
# Processing Record 42 of Set 20 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 20 | vila franca do campo
# Processing Record 44 of Set 20 | biak
# Processing Record 45 of Set 20 | marquette
# Processing Record 46 of Set 20 | ust-kuyga
# Processing Record 47 of Set 20 | canoinhas
# Processing Record 48 of Set 20 | fort oglethorpe
# Processing Record 49 of Set 20 | storforshei
# Processing Record 50 of Set 20 | korcula
# Processing Record 1 of Set 21 | kawalu
# Processing Record 2 of Set 21 | seoul
# Processing Record 3 of Set 21 | batagay-alyta
# Processing Record 4 of Set 21 | moerai
# Processing Record 5 of Set 21 | la gaulette
# City not found. Skipping...
# Processing Record 6 of Set 21 | hofn
# Processing Record 7 of Set 21 | gat
# Processing Record 8 of Set 21 | litoral del san juan
# City not found. Skipping...
# Processing Record 9 of Set 21 | port blair
# Processing Record 10 of Set 21 | spornoye
# Processing Record 11 of Set 21 | dali
# Processing Record 12 of Set 21 | pucallpa
# Processing Record 13 of Set 21 | yarke pole
# Processing Record 14 of Set 21 | esperance
# Processing Record 15 of Set 21 | waingapu
# Processing Record 16 of Set 21 | sugod
# Processing Record 17 of Set 21 | hamilton
# Processing Record 18 of Set 21 | khudumelapye
# Processing Record 19 of Set 21 | ardabil
# Processing Record 20 of Set 21 | tuatapere
# Processing Record 21 of Set 21 | kenora
# Processing Record 22 of Set 21 | elat
# Processing Record 23 of Set 21 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 21 | portland
# Processing Record 25 of Set 21 | tezu
# Processing Record 26 of Set 21 | paramonga
# Processing Record 27 of Set 21 | camaguey
# Processing Record 28 of Set 21 | umm bab
# Processing Record 29 of Set 21 | poya
# Processing Record 30 of Set 21 | vardo
# Processing Record 31 of Set 21 | port victoria
# Processing Record 32 of Set 21 | almenara
# Processing Record 33 of Set 21 | jamame
# Processing Record 34 of Set 21 | san francisco del mar
# Processing Record 35 of Set 21 | kommunar
# Processing Record 36 of Set 21 | college
# Processing Record 37 of Set 21 | avera
# Processing Record 38 of Set 21 | panaba
# Processing Record 39 of Set 21 | laguna
# Processing Record 40 of Set 21 | xique-xique
# Processing Record 41 of Set 21 | hanmer springs
# Processing Record 42 of Set 21 | kurilsk
# Processing Record 43 of Set 21 | henties bay
# Processing Record 44 of Set 21 | juba
# Processing Record 45 of Set 21 | nouakchott
# Processing Record 46 of Set 21 | zyryanka
# Processing Record 47 of Set 21 | saint-augustin
# Processing Record 48 of Set 21 | athens
# Processing Record 49 of Set 21 | codrington
# Processing Record 50 of Set 21 | guerrero negro
# Processing Record 1 of Set 22 | namatanai
# Processing Record 2 of Set 22 | itacarambi
# Processing Record 3 of Set 22 | calama
# Processing Record 4 of Set 22 | hobyo
# Processing Record 5 of Set 22 | fershampenuaz
# Processing Record 6 of Set 22 | rovaniemi
# Processing Record 7 of Set 22 | hasaki
# Processing Record 8 of Set 22 | sisimiut
# Processing Record 9 of Set 22 | urulga
# City not found. Skipping...
# Processing Record 10 of Set 22 | tura
# Processing Record 11 of Set 22 | lao cai
# Processing Record 12 of Set 22 | yulara
# Processing Record 13 of Set 22 | yumen
# Processing Record 14 of Set 22 | ahome
# Processing Record 15 of Set 22 | viedma
# Processing Record 16 of Set 22 | pangkalanbuun
# Processing Record 17 of Set 22 | saryshagan
# City not found. Skipping...
# Processing Record 18 of Set 22 | aljezur
# Processing Record 19 of Set 22 | agirish
# Processing Record 20 of Set 22 | terrace
# Processing Record 21 of Set 22 | rivadavia
# Processing Record 22 of Set 22 | mina
# Processing Record 23 of Set 22 | mongo
# Processing Record 24 of Set 22 | sechura
# Processing Record 25 of Set 22 | wenling
# Processing Record 26 of Set 22 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 22 | baykit
# Processing Record 28 of Set 22 | porbandar
# Processing Record 29 of Set 22 | mahebourg
# Processing Record 30 of Set 22 | manta
# Processing Record 31 of Set 22 | cuiluan
# Processing Record 32 of Set 22 | barhi
# Processing Record 33 of Set 22 | vangaindrano
# Processing Record 34 of Set 22 | muravlenko
# Processing Record 35 of Set 22 | denpasar
# Processing Record 36 of Set 22 | lata
# Processing Record 37 of Set 22 | shache
# Processing Record 38 of Set 22 | kununurra
# Processing Record 39 of Set 22 | labuan
# Processing Record 40 of Set 22 | mopti
# Processing Record 41 of Set 22 | seybaplaya
# Processing Record 42 of Set 22 | japura
# Processing Record 43 of Set 22 | susangerd
# Processing Record 44 of Set 22 | coutances
# Processing Record 45 of Set 22 | guilin
# Processing Record 46 of Set 22 | ingham
# Processing Record 47 of Set 22 | varciorog
# Processing Record 48 of Set 22 | berlevag
# Processing Record 49 of Set 22 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 50 of Set 22 | ulverstone
# Processing Record 1 of Set 23 | buala
# Processing Record 2 of Set 23 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 23 | chicama
# Processing Record 4 of Set 23 | puerto berrio
# Processing Record 5 of Set 23 | shibetsu
# Processing Record 6 of Set 23 | farafangana
# Processing Record 7 of Set 23 | villarrica
# Processing Record 8 of Set 23 | hovd
# Processing Record 9 of Set 23 | cabra
# Processing Record 10 of Set 23 | kiruna
# Processing Record 11 of Set 23 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 23 | tiarei
# Processing Record 13 of Set 23 | matara
# Processing Record 14 of Set 23 | yellandu
# Processing Record 15 of Set 23 | great yarmouth
# Processing Record 16 of Set 23 | quatre cocos
# Processing Record 17 of Set 23 | lubumbashi
# Processing Record 18 of Set 23 | maldonado
# Processing Record 19 of Set 23 | batavia
# Processing Record 20 of Set 23 | oskarshamn
# Processing Record 21 of Set 23 | verkhnevilyuysk
# Processing Record 22 of Set 23 | zhanaozen
# Processing Record 23 of Set 23 | nakhon ratchasima
# Processing Record 24 of Set 23 | aonla
# Processing Record 25 of Set 23 | awbari
# Processing Record 26 of Set 23 | caravelas
# Processing Record 27 of Set 23 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 23 | matamoros
# Processing Record 29 of Set 23 | synya
# Processing Record 30 of Set 23 | bartica
# Processing Record 31 of Set 23 | isla mujeres
# Processing Record 32 of Set 23 | etchoropo
# Processing Record 33 of Set 23 | lusambo
# Processing Record 34 of Set 23 | wanning
# Processing Record 35 of Set 23 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 23 | salina
# Processing Record 37 of Set 23 | mullaitivu
# City not found. Skipping...
# Processing Record 38 of Set 23 | nishihara
# Processing Record 39 of Set 23 | tam ky
# Processing Record 40 of Set 23 | derzhavinsk
# Processing Record 41 of Set 23 | sirpur
# Processing Record 42 of Set 23 | reo
# Processing Record 43 of Set 23 | lasa
# Processing Record 44 of Set 23 | iwanai
# Processing Record 45 of Set 23 | biltine
# Processing Record 46 of Set 23 | chumikan
# Processing Record 47 of Set 23 | kirakira
# Processing Record 48 of Set 23 | jaru
# Processing Record 49 of Set 23 | rome
# Processing Record 50 of Set 23 | rossland
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 Castro -24.7911  -50.0119     42.49        93          94
# 1               Saldanha -33.0117   17.9442     57.25        72          33
# 2                Kibakwe  -6.7167   36.3667     57.61        83          99
# 3              Tazovskiy  67.4667   78.7000     39.00        66          73
# 4               Lorengau  -2.0226  147.2712     86.79        63           9
# 5                  Bilma  18.6853   12.9164     83.43        21          59
# 6          Mar Del Plata -38.0023  -57.5575     47.95        75          17
# 7               Umm Lajj  25.0213   37.2685     83.08        52           0
# 8          Victor Harbor -35.5667  138.6167     59.00        72          24
# 9  Los Llanos De Aridane  28.6585  -17.9182     64.15        85           0
#
#    Wind Speed Country                 Date
# 0       10.71      BR  2022-05-19 03:30:44
# 1       11.10      ZA  2022-05-19 03:35:17
# 2        2.80      TZ  2022-05-19 03:38:52
# 3        7.11      RU  2022-05-19 03:38:52
# 4        8.19      PG  2022-05-19 03:29:19
# 5        2.66      NE  2022-05-19 03:38:53
# 6        1.99      AR  2022-05-19 03:31:54
# 7        7.61      SA  2022-05-19 03:35:24
# 8        7.65      AU  2022-05-19 03:38:53
# 9        5.75      ES  2022-05-19 03:33:06

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1652932511.9854465

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4972/2306291289.py in <module>
#      15
#      16 # Save the figure.
# ---> 17 plt.savefig("weather_data/Fig1.png")
#      18
#      19 # Show plot.
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     964 def savefig(*args, **kwargs):
#     965     fig = gcf()
# --> 966     res = fig.savefig(*args, **kwargs)
#     967     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     968     return res
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3013                 patch.set_edgecolor('none')
#    3014
# -> 3015         self.canvas.print_figure(fname, **kwargs)
#    3016
#    3017         if transparent:
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     507         """
#     508         FigureCanvasAgg.draw(self)
# --> 509         mpl.image.imsave(
#     510             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     511             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1614         pil_kwargs.setdefault("format", format)
#    1615         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1616         image.save(fname, **pil_kwargs)
#    1617
#    1618
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2235                 fp = builtins.open(filename, "r+b")
#    2236             else:
# -> 2237                 fp = builtins.open(filename, "w+b")
#    2238
#    2239         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weather_data/Fig1.png'

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show(

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")



# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# Import Matplotlib.
import matplotlib.pyplot as plt
# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# Calculate the regression line "y values" from the slope and intercept.
regress_values = x_values * slope + intercept

# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create a scatter plot of the x and y values.
plt.scatter(x_values,y_values)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(x_values,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.title(title)
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]

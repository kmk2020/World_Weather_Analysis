# %%
# Import the dependencies.
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)

lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
   # print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
         # citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
pip freeze
# Out:
# alabaster @ file:///home/ktietz/src/ci/alabaster_1611921544520/work
# anaconda-client @ file:///C:/ci/anaconda-client_1635342725944/work
# anaconda-navigator==2.1.4
# anaconda-project @ file:///tmp/build/80754af9/anaconda-project_1626085644852/work
# anyio @ file:///C:/ci/anyio_1620153135622/work/dist
# appdirs==1.4.4
# argh==0.26.2
# argon2-cffi @ file:///C:/ci/argon2-cffi_1613037869401/work
# arrow @ file:///C:/ci/arrow_1617738834352/work
# asn1crypto @ file:///tmp/build/80754af9/asn1crypto_1596577642040/work
# astroid @ file:///C:/ci/astroid_1628063282661/work
# astropy @ file:///C:/ci/astropy_1629829318700/work
# async-generator @ file:///home/ktietz/src/ci/async_generator_1611927993394/work
# atomicwrites==1.4.0
# attrs @ file:///tmp/build/80754af9/attrs_1620827162558/work
# autopep8 @ file:///tmp/build/80754af9/autopep8_1620866417880/work
# Babel @ file:///tmp/build/80754af9/babel_1620871417480/work
# backcall @ file:///home/ktietz/src/ci/backcall_1611930011877/work
# backports.functools-lru-cache @ file:///tmp/build/80754af9/backports.functools_lru_cache_1618170165463/work
# backports.shutil-get-terminal-size @ file:///tmp/build/80754af9/backports.shutil_get_terminal_size_1608222128777/work
# backports.tempfile @ file:///home/linux1/recipes/ci/backports.tempfile_1610991236607/work
# backports.weakref==1.0.post1
# bcrypt @ file:///C:/ci/bcrypt_1607022693089/work
# beautifulsoup4 @ file:///tmp/build/80754af9/beautifulsoup4_1631874778482/work
# binaryornot @ file:///tmp/build/80754af9/binaryornot_1617751525010/work
# bitarray @ file:///C:/ci/bitarray_1629133068652/work
# bkcharts==0.2
# black==19.10b0
# bleach @ file:///tmp/build/80754af9/bleach_1628110601003/work
# bokeh @ file:///C:/ci/bokeh_1635306491714/work
# boto==2.49.0
# Bottleneck @ file:///C:/ci/bottleneck_1607557040328/work
# brotlipy==0.7.0
# cached-property @ file:///tmp/build/80754af9/cached-property_1600785575025/work
# certifi==2021.10.8
# cffi @ file:///C:/ci/cffi_1625831756778/work
# chardet @ file:///C:/ci/chardet_1607706937985/work
# charset-normalizer @ file:///tmp/build/80754af9/charset-normalizer_1630003229654/work
# citipy==0.0.5
# click==8.0.3
# cloudpickle @ file:///tmp/build/80754af9/cloudpickle_1632508026186/work
# clyent==1.2.2
# colorama @ file:///tmp/build/80754af9/colorama_1607707115595/work
# comtypes==1.1.10
# conda==4.12.0
# conda-build==3.21.6
# conda-content-trust @ file:///tmp/build/80754af9/conda-content-trust_1617045594566/work
# conda-pack @ file:///tmp/build/80754af9/conda-pack_1611163042455/work
# conda-package-handling @ file:///C:/ci/conda-package-handling_1618262410900/work
# conda-repo-cli @ file:///tmp/build/80754af9/conda-repo-cli_1620168426516/work
# conda-token @ file:///tmp/build/80754af9/conda-token_1620076980546/work
# conda-verify==3.4.2
# contextlib2 @ file:///Users/ktietz/demo/mc3/conda-bld/contextlib2_1630668244042/work
# cookiecutter @ file:///tmp/build/80754af9/cookiecutter_1617748928239/work
# cryptography @ file:///C:/ci/cryptography_1633520531101/work
# cycler==0.10.0
# Cython @ file:///C:/ci/cython_1636018292912/work
# cytoolz==0.11.0
# daal4py==2021.3.0
# dask==2021.10.0
# debugpy @ file:///C:/ci/debugpy_1629222819322/work
# decorator @ file:///tmp/build/80754af9/decorator_1632776554403/work
# defusedxml @ file:///tmp/build/80754af9/defusedxml_1615228127516/work
# diff-match-patch @ file:///Users/ktietz/demo/mc3/conda-bld/diff-match-patch_1630511840874/work
# distributed @ file:///C:/ci/distributed_1635968318313/work
# docutils @ file:///C:/ci/docutils_1620828264669/work
# entrypoints==0.3
# et-xmlfile==1.1.0
# fastcache @ file:///C:/ci/fastcache_1607571310570/work
# filelock @ file:///tmp/build/80754af9/filelock_1635402558181/work
# flake8 @ file:///tmp/build/80754af9/flake8_1620776156532/work
# Flask @ file:///home/ktietz/src/ci/flask_1611932660458/work
# fonttools==4.25.0
# fsspec @ file:///tmp/build/80754af9/fsspec_1636116461911/work
# future @ file:///C:/ci/future_1607568713721/work
# geojson==2.5.0
# gevent @ file:///C:/ci/gevent_1628273776273/work
# glob2 @ file:///home/linux1/recipes/ci/glob2_1610991677669/work
# gmaps==0.9.0
# greenlet @ file:///C:/ci/greenlet_1628888275363/work
# h5py @ file:///C:/ci/h5py_1622088609188/work
# HeapDict @ file:///Users/ktietz/demo/mc3/conda-bld/heapdict_1630598515714/work
# html5lib @ file:///Users/ktietz/demo/mc3/conda-bld/html5lib_1629144453894/work
# idna @ file:///tmp/build/80754af9/idna_1622654382723/work
# imagecodecs @ file:///C:/ci/imagecodecs_1635511087451/work
# imageio @ file:///tmp/build/80754af9/imageio_1617700267927/work
# imagesize @ file:///Users/ktietz/demo/mc3/conda-bld/imagesize_1628863108022/work
# importlib-metadata @ file:///C:/ci/importlib-metadata_1631916826748/work
# inflection==0.5.1
# iniconfig @ file:///home/linux1/recipes/ci/iniconfig_1610983019677/work
# intervaltree @ file:///Users/ktietz/demo/mc3/conda-bld/intervaltree_1630511889664/work
# ipykernel @ file:///C:/ci/ipykernel_1633545585502/work/dist/ipykernel-6.4.1-py3-none-any.whl
# ipython @ file:///C:/ci/ipython_1635944283918/work
# ipython-genutils @ file:///tmp/build/80754af9/ipython_genutils_1606773439826/work
# ipywidgets @ file:///tmp/build/80754af9/ipywidgets_1634143127070/work
# isort @ file:///tmp/build/80754af9/isort_1628603791788/work
# itsdangerous @ file:///tmp/build/80754af9/itsdangerous_1621432558163/work
# jdcal @ file:///Users/ktietz/demo/mc3/conda-bld/jdcal_1630584345063/work
# jedi @ file:///C:/ci/jedi_1611341083684/work
# Jinja2 @ file:///tmp/build/80754af9/jinja2_1612213139570/work
# jinja2-time @ file:///tmp/build/80754af9/jinja2-time_1617751524098/work
# joblib @ file:///tmp/build/80754af9/joblib_1635411271373/work
# json5 @ file:///tmp/build/80754af9/json5_1624432770122/work
# jsonschema @ file:///Users/ktietz/demo/mc3/conda-bld/jsonschema_1630511932244/work
# jupyter @ file:///C:/ci/jupyter_1607685287094/work
# jupyter-client @ file:///tmp/build/80754af9/jupyter_client_1616770841739/work
# jupyter-console @ file:///tmp/build/80754af9/jupyter_console_1616615302928/work
# jupyter-core @ file:///C:/ci/jupyter_core_1633420716440/work
# jupyter-server @ file:///C:/ci/jupyter_server_1616084298419/work
# jupyterlab @ file:///tmp/build/80754af9/jupyterlab_1635799997693/work
# jupyterlab-pygments @ file:///tmp/build/80754af9/jupyterlab_pygments_1601490720602/work
# jupyterlab-server @ file:///tmp/build/80754af9/jupyterlab_server_1633419203660/work
# jupyterlab-widgets @ file:///tmp/build/80754af9/jupyterlab_widgets_1609884341231/work
# kdtree==0.16
# keyring @ file:///C:/ci/keyring_1629321702436/work
# kiwisolver @ file:///C:/ci/kiwisolver_1612282555033/work
# lazy-object-proxy @ file:///C:/ci/lazy-object-proxy_1616529288960/work
# libarchive-c @ file:///tmp/build/80754af9/python-libarchive-c_1617780486945/work
# llvmlite==0.37.0
# locket==0.2.1
# lxml @ file:///C:/ci/lxml_1616443418777/work
# MarkupSafe @ file:///C:/ci/markupsafe_1607027406824/work
# matplotlib @ file:///C:/ci/matplotlib-suite_1634667159685/work
# matplotlib-inline @ file:///tmp/build/80754af9/matplotlib-inline_1628242447089/work
# mccabe==0.6.1
# menuinst @ file:///C:/ci/menuinst_1631733438520/work
# mistune @ file:///C:/ci/mistune_1607359457024/work
# mkl-fft==1.3.1
# mkl-random @ file:///C:/ci/mkl_random_1626186184308/work
# mkl-service==2.4.0
# mock @ file:///tmp/build/80754af9/mock_1607622725907/work
# more-itertools @ file:///tmp/build/80754af9/more-itertools_1635423142362/work
# mpmath==1.2.1
# msgpack @ file:///C:/ci/msgpack-python_1612287350784/work
# multipledispatch @ file:///C:/ci/multipledispatch_1607574329826/work
# munkres==1.1.4
# mypy-extensions==0.4.3
# mysql-connector-python==8.0.27
# navigator-updater==0.2.1
# nbclassic @ file:///tmp/build/80754af9/nbclassic_1616085367084/work
# nbclient @ file:///tmp/build/80754af9/nbclient_1614364831625/work
# nbconvert @ file:///C:/ci/nbconvert_1624479160025/work
# nbformat @ file:///tmp/build/80754af9/nbformat_1617383369282/work
# nest-asyncio @ file:///tmp/build/80754af9/nest-asyncio_1613680548246/work
# networkx @ file:///tmp/build/80754af9/networkx_1633639043937/work
# nltk==3.6.5
# nose @ file:///tmp/build/80754af9/nose_1606773131901/work
# notebook @ file:///C:/ci/notebook_1635393701545/work
# numba @ file:///C:/ci/numba_1635186062888/work
# numexpr @ file:///C:/ci/numexpr_1618856728739/work
# numpy @ file:///C:/ci/numpy_and_numpy_base_1626271900803/work
# numpydoc @ file:///tmp/build/80754af9/numpydoc_1605117425582/work
# olefile @ file:///Users/ktietz/demo/mc3/conda-bld/olefile_1629805411829/work
# openpyxl @ file:///tmp/build/80754af9/openpyxl_1632777717936/work
# packaging @ file:///tmp/build/80754af9/packaging_1625611678980/work
# pandas @ file:///C:/ci/pandas_1635506685681/work
# pandocfilters @ file:///C:/ci/pandocfilters_1605114832805/work
# paramiko @ file:///tmp/build/80754af9/paramiko_1598886428689/work
# parso @ file:///tmp/build/80754af9/parso_1617223946239/work
# partd @ file:///tmp/build/80754af9/partd_1618000087440/work
# path @ file:///C:/ci/path_1624287837534/work
# pathlib2 @ file:///C:/ci/pathlib2_1625585796814/work
# pathspec==0.7.0
# patsy==0.5.2
# pep8==1.7.1
# pexpect @ file:///tmp/build/80754af9/pexpect_1605563209008/work
# pickleshare @ file:///tmp/build/80754af9/pickleshare_1606932040724/work
# Pillow==8.4.0
# pkginfo==1.7.1
# pluggy @ file:///C:/ci/pluggy_1615976440052/work
# ply==3.11
# poyo @ file:///tmp/build/80754af9/poyo_1617751526755/work
# prometheus-client @ file:///tmp/build/80754af9/prometheus_client_1623189609245/work
# prompt-toolkit @ file:///tmp/build/80754af9/prompt-toolkit_1633440160888/work
# psutil @ file:///C:/ci/psutil_1612298199233/work
# ptyprocess @ file:///tmp/build/80754af9/ptyprocess_1609355006118/work/dist/ptyprocess-0.7.0-py2.py3-none-any.whl
# py @ file:///tmp/build/80754af9/py_1607971587848/work
# pycodestyle @ file:///tmp/build/80754af9/pycodestyle_1615748559966/work
# pycosat==0.6.3
# pycparser @ file:///tmp/build/80754af9/pycparser_1594388511720/work
# pycurl==7.44.1
# pydocstyle @ file:///tmp/build/80754af9/pydocstyle_1621600989141/work
# pyerfa @ file:///C:/ci/pyerfa_1621560974055/work
# pyflakes @ file:///tmp/build/80754af9/pyflakes_1617200973297/work
# Pygments @ file:///tmp/build/80754af9/pygments_1629234116488/work
# PyJWT @ file:///C:/ci/pyjwt_1619682721924/work
# pylint @ file:///C:/ci/pylint_1627536884966/work
# pyls-spyder==0.4.0
# PyNaCl @ file:///C:/ci/pynacl_1607612759007/work
# pyodbc===4.0.0-unsupported
# pyOpenSSL @ file:///tmp/build/80754af9/pyopenssl_1635333100036/work
# pyparsing @ file:///tmp/build/80754af9/pyparsing_1635766073266/work
# pyreadline==2.1
# pyrsistent @ file:///C:/ci/pyrsistent_1636093225342/work
# PySocks @ file:///C:/ci/pysocks_1605307512533/work
# pytest==6.2.4
# python-dateutil @ file:///tmp/build/80754af9/python-dateutil_1626374649649/work
# python-lsp-black @ file:///tmp/build/80754af9/python-lsp-black_1634232156041/work
# python-lsp-jsonrpc==1.0.0
# python-lsp-server==1.2.4
# python-slugify @ file:///tmp/build/80754af9/python-slugify_1620405669636/work
# pytz==2021.3
# PyWavelets @ file:///C:/ci/pywavelets_1607645631519/work
# pywin32==228
# pywin32-ctypes @ file:///C:/ci/pywin32-ctypes_1607553594546/work
# pywinpty @ file:///C:/ci/pywinpty_1607419945780/work
# PyYAML==6.0
# pyzmq @ file:///C:/ci/pyzmq_1628276105793/work
# QDarkStyle @ file:///tmp/build/80754af9/qdarkstyle_1617386714626/work
# qstylizer @ file:///tmp/build/80754af9/qstylizer_1617713584600/work/dist/qstylizer-0.1.10-py2.py3-none-any.whl
# QtAwesome @ file:///tmp/build/80754af9/qtawesome_1615991616277/work
# qtconsole @ file:///tmp/build/80754af9/qtconsole_1632739723211/work
# QtPy @ file:///tmp/build/80754af9/qtpy_1629397026935/work
# regex @ file:///C:/ci/regex_1628063427816/work
# requests @ file:///tmp/build/80754af9/requests_1629994808627/work
# rope @ file:///tmp/build/80754af9/rope_1623703006312/work
# Rtree @ file:///C:/ci/rtree_1618421015405/work
# ruamel-yaml-conda @ file:///C:/ci/ruamel_yaml_1616016898638/work
# scikit-image==0.18.3
# scikit-learn @ file:///C:/ci/scikit-learn_1622739499047/work
# scikit-learn-intelex==2021.20210714.120553
# scipy @ file:///C:/ci/scipy_1630606917240/work
# seaborn @ file:///tmp/build/80754af9/seaborn_1629307859561/work
# Send2Trash @ file:///tmp/build/80754af9/send2trash_1632406701022/work
# simplegeneric==0.8.1
# singledispatch @ file:///tmp/build/80754af9/singledispatch_1629321204894/work
# sip==4.19.13
# six @ file:///tmp/build/80754af9/six_1623709665295/work
# sniffio @ file:///C:/ci/sniffio_1614030527509/work
# snowballstemmer @ file:///tmp/build/80754af9/snowballstemmer_1611258885636/work
# sortedcollections @ file:///tmp/build/80754af9/sortedcollections_1611172717284/work
# sortedcontainers @ file:///tmp/build/80754af9/sortedcontainers_1623949099177/work
# soupsieve @ file:///tmp/build/80754af9/soupsieve_1616183228191/work
# Sphinx==4.2.0
# sphinxcontrib-applehelp @ file:///home/ktietz/src/ci/sphinxcontrib-applehelp_1611920841464/work
# sphinxcontrib-devhelp @ file:///home/ktietz/src/ci/sphinxcontrib-devhelp_1611920923094/work
# sphinxcontrib-htmlhelp @ file:///tmp/build/80754af9/sphinxcontrib-htmlhelp_1623945626792/work
# sphinxcontrib-jsmath @ file:///home/ktietz/src/ci/sphinxcontrib-jsmath_1611920942228/work
# sphinxcontrib-qthelp @ file:///home/ktietz/src/ci/sphinxcontrib-qthelp_1611921055322/work
# sphinxcontrib-serializinghtml @ file:///tmp/build/80754af9/sphinxcontrib-serializinghtml_1624451540180/work
# sphinxcontrib-websupport @ file:///tmp/build/80754af9/sphinxcontrib-websupport_1597081412696/work
# spyder @ file:///C:/ci/spyder_1636480369575/work
# spyder-kernels @ file:///C:/ci/spyder-kernels_1634237096710/work
# SQLAlchemy @ file:///C:/ci/sqlalchemy_1626948551162/work
# statsmodels==0.12.2
# sympy @ file:///C:/ci/sympy_1635219088507/work
# tables==3.6.1
# TBB==0.2
# tblib @ file:///Users/ktietz/demo/mc3/conda-bld/tblib_1629402031467/work
# terminado==0.9.4
# testpath @ file:///tmp/build/80754af9/testpath_1624638946665/work
# text-unidecode @ file:///Users/ktietz/demo/mc3/conda-bld/text-unidecode_1629401354553/work
# textdistance @ file:///tmp/build/80754af9/textdistance_1612461398012/work
# threadpoolctl @ file:///Users/ktietz/demo/mc3/conda-bld/threadpoolctl_1629802263681/work
# three-merge @ file:///tmp/build/80754af9/three-merge_1607553261110/work
# tifffile @ file:///tmp/build/80754af9/tifffile_1627275862826/work
# tinycss @ file:///tmp/build/80754af9/tinycss_1617713798712/work
# toml @ file:///tmp/build/80754af9/toml_1616166611790/work
# toolz @ file:///home/linux1/recipes/ci/toolz_1610987900194/work
# tornado @ file:///C:/ci/tornado_1606924294691/work
# tqdm @ file:///tmp/build/80754af9/tqdm_1635330843403/work
# traitlets @ file:///tmp/build/80754af9/traitlets_1632522747050/work
# typed-ast @ file:///C:/ci/typed-ast_1624953797214/work
# typing-extensions @ file:///tmp/build/80754af9/typing_extensions_1631814937681/work
# ujson @ file:///C:/ci/ujson_1611259568517/work
# unicodecsv==0.14.1
# Unidecode @ file:///tmp/build/80754af9/unidecode_1614712377438/work
# urllib3==1.26.7
# watchdog @ file:///C:/ci/watchdog_1624955113064/work
# wcwidth @ file:///Users/ktietz/demo/mc3/conda-bld/wcwidth_1629357192024/work
# webencodings==0.5.1
# Werkzeug @ file:///tmp/build/80754af9/werkzeug_1635505089296/work
# whichcraft @ file:///tmp/build/80754af9/whichcraft_1617751293875/work
# widgetsnbextension @ file:///C:/ci/widgetsnbextension_1607531582688/work
# win-inet-pton @ file:///C:/ci/win_inet_pton_1605306162074/work
# win-unicode-console==0.5
# wincertstore==0.2
# wrapt @ file:///C:/ci/wrapt_1607574570428/work
# xlrd @ file:///tmp/build/80754af9/xlrd_1608072521494/work
# XlsxWriter @ file:///tmp/build/80754af9/xlsxwriter_1628603415431/work
# xlwings==0.24.9
# xlwt==1.3.0
# xmltodict @ file:///Users/ktietz/demo/mc3/conda-bld/xmltodict_1629301980723/work
# yapf @ file:///tmp/build/80754af9/yapf_1615749224965/work
# zict==2.0.0
# zipp @ file:///tmp/build/80754af9/zipp_1633618647012/work
# zope.event==4.5.0
# zope.interface @ file:///C:/ci/zope.interface_1625036252485/work
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\kelvi\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\kelvi\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
class City:
    '''
    City wraps up the info about a city, including its name, coordinates,
    and belonging country.
    '''
    def __init__(self, city_name, country_code):
        self.city_name = city_name
        
        
        self.country_code = country_code

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# hamilton bm
# kloulklubed pw
# rikitea pf
# severo-kurilsk ru
# chuy uy
# saint-augustin ca
# bathsheba bb
# rungata ki
# yellowknife ca
# saint-francois gp
# hithadhoo mv
# illoqqortoormiut gl
# rikitea pf
# ornskoldsvik se
# killybegs ie
# cherskiy ru
# saint-philippe re
# samusu ws
# new norfolk au
# menongue ao
# tupik ru
# salalah om
# prata br
# ribeira grande pt
# adelaide au
# kodiak us
# busselton au
# punta arenas cl
# mataura pf
# marienburg sr
# belgrade us
# necochea ar
# atuona pf
# taolanaro mg
# campoverde pe
# hobart au
# husavik is
# punta arenas cl
# ushuaia ar
# santa maria cv
# vila velha br
# vaini to
# barentsburg sj
# mataura pf
# ostrovnoy ru
# mitrofanovka ru
# illoqqortoormiut gl
# ushuaia ar
# kapaa us
# ushuaia ar
# kapoeta sd
# monrovia lr
# wagar sd
# butaritari ki
# carbondale us
# cascavel br
# jamestown sh
# belushya guba ru
# bambous virieux mu
# tsogni ga
# tuktoyaktuk ca
# aklavik ca
# hermanus za
# cidreira br
# yabelo et
# mount gambier au
# avarua ck
# kapaa us
# torbay ca
# faanui pf
# chuy uy
# neiafu to
# flin flon ca
# pisco pe
# longyearbyen sj
# punta arenas cl
# moyale et
# padang id
# saint george bm
# diego de almagro cl
# fairbanks us
# port keats au
# geraldton au
# bluff nz
# mataura pf
# hilo us
# pevek ru
# hobart au
# nikolskoye ru
# namibe ao
# dikson ru
# mataura pf
# taylor us
# bluff nz
# shunyi cn
# fiditi ng
# pisco pe
# hobart au
# opochka ru
# san rafael ar
# port alfred za
# busselton au
# bredasdorp za
# yellowknife ca
# hilo us
# barrow us
# ushuaia ar
# tura ru
# rikitea pf
# moree au
# taolanaro mg
# punta arenas cl
# yellowknife ca
# illoqqortoormiut gl
# vanavara ru
# prado br
# kapaa us
# hermanus za
# ushuaia ar
# east london za
# hermanus za
# poum nc
# guerrero negro mx
# tuktoyaktuk ca
# hilo us
# mataura pf
# saint-jerome ca
# cocorit mx
# kapaa us
# hasaki jp
# castro cl
# hobart au
# port alfred za
# bambous virieux mu
# ormara pk
# bredasdorp za
# vaini to
# general roca ar
# ushuaia ar
# kruisfontein za
# butaritari ki
# yambio sd
# bluff nz
# port elizabeth za
# rikitea pf
# mar del plata ar
# rikitea pf
# kahului us
# belushya guba ru
# madingou cg
# myaundzha ru
# gat ly
# busselton au
# mataura pf
# lagoa pt
# albany au
# buraydah sa
# lompoc us
# punta arenas cl
# punta arenas cl
# busselton au
# egvekinot ru
# rikitea pf
# shingu jp
# mgandu tz
# bauska lv
# illoqqortoormiut gl
# rikitea pf
# kavieng pg
# mlimba tz
# rikitea pf
# bluff nz
# sal rei cv
# punta arenas cl
# avarua ck
# clyde river ca
# rikitea pf
# rikitea pf
# nemuro jp
# mahebourg mu
# funtua ng
# dogondoutchi ne
# attawapiskat ca
# butaritari ki
# male mv
# wenatchee us
# saint-georges gf
# grindavik is
# yellowknife ca
# albany au
# bluff nz
# busselton au
# kruisfontein za
# emerald au
# along in
# rocky mountain house ca
# shingu jp
# port alfred za
# arraial do cabo br
# mataura pf
# nizwa om
# beringovskiy ru
# kumluca tr
# yellowknife ca
# coquimbo cl
# mataura pf
# katsuura jp
# hermanus za
# castro cl
# cape town za
# haines junction ca
# kapaa us
# ushuaia ar
# huarmey pe
# cape town za
# mamakan ru
# dorogobuzh ru
# kapaa us
# hobyo so
# kahului us
# usinsk ru
# derzhavinsk kz
# miles city us
# palabuhanratu id
# cape town za
# taolanaro mg
# amapa br
# rikitea pf
# ushuaia ar
# ushuaia ar
# nichinan jp
# kavaratti in
# ruatoria nz
# puerto ayora ec
# monteagudo bo
# rikitea pf
# vilhena br
# cape town za
# clyde river ca
# awjilah ly
# caravelas br
# shimoda jp
# port blair in
# butaritari ki
# mehamn no
# abu kamal sy
# atuona pf
# kodiak us
# los llanos de aridane es
# butaritari ki
# butaritari ki
# noyabrsk ru
# kodinsk ru
# longyearbyen sj
# avarua ck
# port macquarie au
# punta arenas cl
# punta arenas cl
# kapaa us
# alotau pg
# kavieng pg
# ushuaia ar
# busselton au
# matay eg
# ushuaia ar
# kavaratti in
# salalah om
# yellowknife ca
# barrow us
# bara sd
# hilo us
# carnarvon au
# kodiak us
# cape town za
# portland au
# beian cn
# port alfred za
# sangueya gn
# port hardy ca
# punta arenas cl
# ostrovnoy ru
# marrakesh ma
# maniitsoq gl
# mys shmidta ru
# mar del plata ar
# carnarvon au
# airai pw
# ushuaia ar
# vostok ru
# albany au
# akyab mm
# mar del plata ar
# jasper ca
# hilo us
# tessalit ml
# punta arenas cl
# barra patuca hn
# samusu ws
# rikitea pf
# souillac mu
# puerto madero mx
# pevek ru
# cape town za
# ushuaia ar
# yellowknife ca
# cidreira br
# margate za
# punta arenas cl
# jamestown sh
# belushya guba ru
# hermanus za
# mayo ca
# cherskiy ru
# torbay ca
# kinablangan ph
# ushuaia ar
# diu in
# puerto ayora ec
# butaritari ki
# rengo cl
# punta arenas cl
# ushuaia ar
# kahului us
# jamestown sh
# hilo us
# jamestown sh
# jamestown sh
# mataura pf
# vaini to
# arraial do cabo br
# pendleton us
# cape town za
# belushya guba ru
# mataura pf
# anadyr ru
# chokurdakh ru
# kishi ng
# guerrero negro mx
# alofi nu
# butaritari ki
# albany au
# trenggalek id
# vaini to
# taolanaro mg
# huarmey pe
# port blair in
# illoqqortoormiut gl
# busselton au
# ushuaia ar
# wangkui cn
# jamestown sh
# moree au
# albany au
# diffa ne
# lompoc us
# khatanga ru
# hami cn
# fortuna us
# prince rupert ca
# sumbawa id
# nenjiang cn
# sitka us
# hasaki jp
# albany au
# grand gaube mu
# umba ru
# busselton au
# punta arenas cl
# hermanus za
# hobart au
# saleaula ws
# ushuaia ar
# kavieng pg
# new norfolk au
# nioro ml
# ilulissat gl
# puerto ayora ec
# barrow us
# yellowknife ca
# bilma ne
# jamestown sh
# busselton au
# hammerfest no
# pokhara np
# naze jp
# jamestown sh
# albany au
# vaini to
# saint-pierre pm
# hermanus za
# rikitea pf
# albany au
# kavieng pg
# muika jp
# avarua ck
# port-gentil ga
# dikson ru
# heze cn
# ushuaia ar
# poum nc
# kutum sd
# qaanaaq gl
# rikitea pf
# port elizabeth za
# san cristobal ec
# tiksi ru
# kruisfontein za
# hermanus za
# primore ru
# kavieng pg
# mataura pf
# kaitangata nz
# qaanaaq gl
# ribeira grande pt
# magadan ru
# katobu id
# nouadhibou mr
# khasan ru
# nikolskoye ru
# new norfolk au
# rocha uy
# dinsor so
# tuktoyaktuk ca
# albany au
# port alfred za
# manuk mangkaw ph
# avarua ck
# havre-saint-pierre ca
# carrollton us
# qaanaaq gl
# katsuura jp
# khatanga ru
# saint-philippe re
# belushya guba ru
# east london za
# busselton au
# bredasdorp za
# carnarvon au
# sur om
# butaritari ki
# kalmunai lk
# nemuro jp
# hobart au
# airai pw
# ushuaia ar
# rikitea pf
# dryden ca
# punta arenas cl
# unai br
# bluff nz
# mataura pf
# avarua ck
# ostrovnoy ru
# ushuaia ar
# gidole et
# ushuaia ar
# cape town za
# tuatapere nz
# qaanaaq gl
# touros br
# ushuaia ar
# mys shmidta ru
# ushuaia ar
# southampton ca
# san matias bo
# bredasdorp za
# fortuna us
# tiksi ru
# norman wells ca
# broken hill au
# kiama au
# san julian bo
# severnoye ru
# strezhevoy ru
# severnyy ru
# carnarvon au
# manta ec
# tete mz
# viligili mv
# mahebourg mu
# kirovskiy ru
# barrow us
# jizan sa
# atuona pf
# ixtapa mx
# ushuaia ar
# sitka us
# east london za
# cidreira br
# taolanaro mg
# rikitea pf
# punta arenas cl
# barrow us
# albany au
# avarua ck
# rikitea pf
# chuy uy
# lompoc us
# kirksville us
# santa cruz cr
# saint george bm
# chokurdakh ru
# geraldton ca
# puerto ayora ec
# rikitea pf
# illoqqortoormiut gl
# kapaa us
# clyde river ca
# port elizabeth za
# thompson ca
# yola ng
# saskylakh ru
# carnarvon au
# san cristobal ec
# illoqqortoormiut gl
# laguna br
# mbandaka cd
# rikitea pf
# karratha au
# tasiilaq gl
# hobyo so
# jamestown sh
# khatanga ru
# albany au
# nouadhibou mr
# vaini to
# clyde river ca
# saskylakh ru
# okha ru
# lasa cn
# agrado co
# cape town za
# port blair in
# alofi nu
# ushuaia ar
# chokurdakh ru
# mataura pf
# bambous virieux mu
# kerema pg
# cayenne gf
# kapaa us
# taolanaro mg
# punta arenas cl
# kamenskoye ru
# barrow us
# bluff nz
# albany au
# cape town za
# mount isa au
# khatanga ru
# albany au
# larsnes no
# mataura pf
# san cristobal ec
# pevek ru
# new norfolk au
# kenai us
# kamenskoye ru
# ushuaia ar
# riyadh sa
# kletnya ru
# chuy uy
# attawapiskat ca
# mount gambier au
# ushuaia ar
# grand centre ca
# nouadhibou mr
# thompson ca
# kapaa us
# vaini to
# tabiauea ki
# iskateley ru
# placido de castro br
# east london za
# hlotse ls
# severo-kurilsk ru
# flin flon ca
# mataura pf
# petauke zm
# mildura au
# korla cn
# vila franca do campo pt
# lorengau pg
# yellowknife ca
# mataura pf
# rikitea pf
# anchorage us
# lyuban by
# kapaa us
# kargasok ru
# iranshahr ir
# airai pw
# punta arenas cl
# nizhneyansk ru
# enshi cn
# katsuura jp
# thompson ca
# albany au
# sitka us
# shimoda jp
# port alfred za
# punta arenas cl
# nikolskoye ru
# albany au
# asau tv
# te anau nz
# faanui pf
# hobart au
# phan thiet vn
# taolanaro mg
# busselton au
# porbandar in
# quelimane mz
# kavaratti in
# dikson ru
# katsuura jp
# corinto ni
# evansville us
# upernavik gl
# hermanus za
# ottumwa us
# klaksvik fo
# mataura pf
# chuy uy
# egvekinot ru
# vaini to
# narrabri au
# longyan cn
# puerto ayora ec
# codrington ag
# boende cd
# maraa br
# senanga zm
# castro cl
# albox es
# camaqua br
# ancud cl
# qaanaaq gl
# araguatins br
# mahibadhoo mv
# klaksvik fo
# constitucion cl
# bredasdorp za
# new norfolk au
# vaini to
# bluff nz
# jumla np
# klaksvik fo
# sarangani ph
# tezu in
# port augusta au
# hobart au
# salalah om
# butaritari ki
# kisangani cd
# bredasdorp za
# orocue co
# cape town za
# vaini to
# attawapiskat ca
# ushuaia ar
# rio gallegos ar
# gamba ga
# noumea nc
# qaanaaq gl
# hobart au
# nome us
# blagoyevo ru
# punta arenas cl
# yar-sale ru
# oda jp
# san carlos de bariloche ar
# bengkulu id
# hobyo so
# barentsburg sj
# cape town za
# ribeira grande pt
# tsihombe mg
# kapaa us
# vao nc
# busselton au
# falealupo ws
# albany au
# hermanus za
# new norfolk au
# roebourne au
# pangnirtung ca
# qaanaaq gl
# hilo us
# faanui pf
# vaini to
# karratha au
# hobart au
# bharuch in
# ushuaia ar
# albany au
# skjervoy no
# victoria sc
# saldanha za
# puerto ayora ec
# sambava mg
# amderma ru
# taolanaro mg
# kavaratti in
# vardo no
# lebu cl
# veraval in
# pangnirtung ca
# punta arenas cl
# camacupa ao
# taolanaro mg
# harper lr
# rikitea pf
# ancud cl
# port hedland au
# hithadhoo mv
# castro cl
# port alfred za
# san cristobal ec
# xadani mx
# albany au
# akyab mm
# lagoa pt
# anloga gh
# antalaha mg
# talnakh ru
# vostok ru
# klaksvik fo
# codrington ag
# yuzhno-kurilsk ru
# ushuaia ar
# progreso mx
# ushuaia ar
# wangaratta au
# rikitea pf
# busselton au
# grand river south east mu
# rikitea pf
# bahir dar et
# albany au
# pacific grove us
# puerto suarez bo
# kamaishi jp
# saldanha za
# belushya guba ru
# east london za
# warqla dz
# alyangula au
# jamestown sh
# port alfred za
# vila velha br
# tateyama jp
# kununurra au
# rikitea pf
# ponta do sol cv
# east london za
# arraial do cabo br
# busselton au
# maiduguri ng
# bairiki ki
# yulara au
# barrow us
# bogomila mk
# petropavlovsk-kamchatskiy ru
# vaitupu wf
# tabou ci
# iqaluit ca
# gurupi br
# champerico gt
# rikitea pf
# rikitea pf
# ushuaia ar
# cabo san lucas mx
# sangueya gn
# aloleng ph
# butaritari ki
# ilulissat gl
# georgetown sh
# hualmay pe
# jamestown sh
# virtsu ee
# vostok ru
# ushuaia ar
# lunino ru
# patnos tr
# ancud cl
# dodola et
# port elizabeth za
# candawaga ph
# qaanaaq gl
# alofi nu
# vaini to
# castro cl
# puerto ayora ec
# hilo us
# tezu in
# bokspits bw
# punta arenas cl
# atuona pf
# iqaluit ca
# vaini to
# provideniya ru
# tsihombe mg
# leshukonskoye ru
# east london za
# saint george us
# tasiilaq gl
# samusu ws
# mahebourg mu
# touros br
# rikitea pf
# rikitea pf
# acarau br
# albany au
# barrow us
# centenario do sul br
# albany au
# ancud cl
# illoqqortoormiut gl
# busselton au
# kargil in
# ushuaia ar
# ushuaia ar
# mtwara tz
# nioki cd
# dolores ar
# saskylakh ru
# new norfolk au
# kavaratti in
# tigil ru
# thompson ca
# belushya guba ru
# san patricio mx
# hermanus za
# quthing ls
# geraldton au
# phalodi in
# norman wells ca
# vaini to
# tucuman ar
# porbandar in
# illoqqortoormiut gl
# miri my
# tiarei pf
# kapaa us
# punta arenas cl
# hithadhoo mv
# alihe cn
# tsihombe mg
# punta arenas cl
# ushuaia ar
# cape town za
# awbari ly
# skrunda lv
# zhigalovo ru
# ushuaia ar
# taolanaro mg
# borlange se
# port elizabeth za
# mys shmidta ru
# tasiilaq gl
# whitehorse ca
# nikolskoye ru
# cape town za
# mataura pf
# emerald au
# dikson ru
# scottsburgh za
# baiao br
# ushuaia ar
# geraldton au
# umzimvubu za
# marzuq ly
# vitry-le-francois fr
# semporna my
# ushuaia ar
# atuona pf
# hambantota lk
# upernavik gl
# avarua ck
# punta arenas cl
# hermanus za
# qui nhon vn
# hermanus za
# vaitupu wf
# saint marys us
# hobart au
# hasaki jp
# warmbad na
# esperance au
# alice springs au
# jacqueville ci
# buchanan lr
# poum nc
# denpasar id
# rikitea pf
# hithadhoo mv
# punta arenas cl
# rikitea pf
# albany au
# alta floresta br
# nayudupeta in
# morondava mg
# port alfred za
# bambous virieux mu
# yellowknife ca
# rikitea pf
# kapaa us
# hithadhoo mv
# albany au
# cherskiy ru
# aklavik ca
# kungurtug ru
# stornoway gb
# rikitea pf
# guerrero negro mx
# yuksekova tr
# zhigansk ru
# barrow us
# butaritari ki
# punta arenas cl
# punta arenas cl
# souillac mu
# taolanaro mg
# bandarbeyla so
# bredasdorp za
# hermanus za
# pombia gr
# portland au
# waingapu id
# agadir ma
# sterling us
# kresttsy ru
# vardo no
# puerto ayora ec
# mercedes ar
# hun ly
# vaini to
# dalmatovo ru
# blackfoot us
# arraial do cabo br
# cape town za
# taolanaro mg
# skjervoy no
# dikson ru
# ushuaia ar
# port-gentil ga
# margate za
# spornoye ru
# vaitupu wf
# busselton au
# ulaangom mn
# yellowknife ca
# vaini to
# barentsburg sj
# puerto ayora ec
# mana gf
# provideniya ru
# kapaa us
# zhigansk ru
# bluff nz
# yertarskiy ru
# san patricio mx
# tomigusuku jp
# taolanaro mg
# bengkulu id
# asau tv
# gimli ca
# kesan tr
# raychikhinsk ru
# awbari ly
# bethel us
# kapaa us
# hamilton bm
# rikitea pf
# chuy uy
# punta arenas cl
# new norfolk au
# hithadhoo mv
# abu zabad sd
# avarua ck
# ushuaia ar
# kodiak us
# castro cl
# wulanhaote cn
# butaritari ki
# jamestown sh
# kuche cn
# hailey us
# tautira pf
# cape town za
# waling np
# punta arenas cl
# klaksvik fo
# miramar mx
# coos bay us
# tsihombe mg
# east london za
# albany au
# barrow us
# faanui pf
# punta arenas cl
# busselton au
# hilo us
# punta arenas cl
# belushya guba ru
# athabasca ca
# castro cl
# santa maria cv
# hasaki jp
# pryazha ru
# pullman us
# bredasdorp za
# mataura pf
# avera pf
# bajo baudo co
# longyearbyen sj
# sao filipe cv
# saint-leu re
# hilo us
# ushuaia ar
# mahebourg mu
# lithakia gr
# upernavik gl
# pevek ru
# jamestown sh
# kofele et
# mataura pf
# norman wells ca
# albany au
# torbay ca
# upernavik gl
# point pedro lk
# georgetown sh
# hithadhoo mv
# isangel vu
# port pirie au
# victoria sc
# codrington ag
# illoqqortoormiut gl
# grand centre ca
# jamestown sh
# saint-philippe re
# nanortalik gl
# payo ph
# naantali fi
# rikitea pf
# kautokeino no
# kaitangata nz
# kapaa us
# narsaq gl
# port alfred za
# rafai cf
# coihaique cl
# saleaula ws
# oksfjord no
# sentyabrskiy ru
# alexandria us
# mataura pf
# sept-iles ca
# butaritari ki
# east london za
# saint george bm
# victoria sc
# arraial do cabo br
# busselton au
# nantucket us
# ponta do sol cv
# ajdabiya ly
# hobart au
# albany au
# bilma ne
# iqaluit ca
# vaini to
# albany au
# palabuhanratu id
# iqaluit ca
# ushuaia ar
# rikitea pf
# sabha ly
# albany au
# lagoa pt
# rikitea pf
# jiexiu cn
# ushuaia ar
# kodiak us
# busselton au
# upernavik gl
# cidreira br
# port elizabeth za
# bluff nz
# mount isa au
# cherskiy ru
# albany au
# warrnambool au
# batagay-alyta ru
# victoria sc
# mopipi bw
# sao sebastiao br
# vilhena br
# cayenne gf
# puerto ayora ec
# mareeba au
# rikitea pf
# albany au
# rikitea pf
# taolanaro mg
# coos bay us
# atuona pf
# bluff nz
# lourdes fr
# gambela et
# namibe ao
# geraldton au
# sao jose da coroa grande br
# sentyabrskiy ru
# ushuaia ar
# busselton au
# tazovskiy ru
# ushuaia ar
# arraial do cabo br
# fortuna us
# bokspits bw
# sampit id
# hilo us
# buraydah sa
# taolanaro mg
# kouango cf
# soyo ao
# thompson ca
# punta arenas cl
# pevek ru
# tromso no
# qaanaaq gl
# victoria sc
# guarapari br
# nome us
# leningradskiy ru
# ust-maya ru
# carnarvon au
# rikitea pf
# arrifes pt
# newark us
# cape town za
# ushuaia ar
# ushuaia ar
# lasa cn
# leh in
# ushuaia ar
# saskylakh ru
# keita ne
# bandarbeyla so
# flin flon ca
# punta arenas cl
# touros br
# amderma ru
# kadykchan ru
# sitka us
# belushya guba ru
# bluff nz
# nizhniy baskunchak ru
# nabire id
# salyan az
# erechim br
# vaini to
# rikitea pf
# daru pg
# mys shmidta ru
# severo-kurilsk ru
# puerto ayora ec
# cape town za
# pisco pe
# saint-pierre pm
# atuona pf
# khatanga ru
# sentyabrskiy ru
# hobart au
# norman wells ca
# kastamonu tr
# provideniya ru
# illoqqortoormiut gl
# hobart au
# illoqqortoormiut gl
# kavieng pg
# asmar af
# vao nc
# kapaa us
# beringovskiy ru
# innisfail au
# katha mm
# castro cl
# kodiak us
# hermanus za
# inhambane mz
# pacific grove us
# souillac mu
# albany au
# kushmurun kz
# namibe ao
# illoqqortoormiut gl
# busselton au
# la rioja ar
# obigarm tj
# paita pe
# vila franca do campo pt
# alyangula au
# atuona pf
# lompoc us
# umzimvubu za
# mar del plata ar
# tuktoyaktuk ca
# babanusah sd
# new norfolk au
# vaini to
# thompson ca
# lishui cn
# hendek tr
# hobart au
# puerto palomas mx
# torres br
# hermanus za
# avarua ck
# vaini to
# ambulu id
# clyde river ca
# thompson ca
# east london za
# kavaratti in
# busselton au
# east london za
# mragowo pl
# sibolga id
# airai pw
# cape town za
# punta arenas cl
# kodiak us
# saint-denis re
# mizdah ly
# mandurah au
# udachnyy ru
# butaritari ki
# tasiilaq gl
# kaitangata nz
# picton ca
# mahebourg mu
# jimeta ng
# tsihombe mg
# busselton au
# atuona pf
# palabuhanratu id
# avarua ck
# punta arenas cl
# sumenep id
# hamilton bm
# salalah om
# sinegorye ru
# punta arenas cl
# gizo sb
# klaksvik fo
# avarua ck
# asau tv
# perth au
# basco ph
# kavaratti in
# coahuayana mx
# hobart au
# tilichiki ru
# jieshi cn
# louisbourg ca
# kruisfontein za
# walvis bay na
# cape town za
# saint-philippe re
# ushuaia ar
# new norfolk au
# punta arenas cl
# belushya guba ru
# bredasdorp za
# kapaa us
# kaitangata nz
# leshukonskoye ru
# college us
# punta arenas cl
# airai pw
# kuito ao
# port alfred za
# coahuayana mx
# thompson ca
# gogrial sd
# malwan in
# cape town za
# rize tr
# coihaique cl
# hilo us
# albany au
# hilo us
# ushuaia ar
# illoqqortoormiut gl
# barrow us
# bluff nz
# kodiak us
# avarua ck
# ust-maya ru
# marsabit ke
# busselton au
# hilo us
# rikitea pf
# punta arenas cl
# pevek ru
# inhambane mz
# rikitea pf
# aklavik ca
# klaksvik fo
# otradnoye ru
# bluff nz
# arraial do cabo br
# kodinsk ru
# ambilobe mg
# ushuaia ar
# sentyabrskiy ru
# dire dawa et
# mugur-aksy ru
# vaini to
# ziebice pl
# castro cl
# bam ir
# tuktoyaktuk ca
# roma au
# manavalakurichi in
# bambous virieux mu
# port elizabeth za
# bluff nz
# rio verde de mato grosso br
# mys shmidta ru
# bluff nz
# bandarbeyla so
# rikitea pf
# abu samrah qa
# north ogden us
# punta arenas cl
# jamestown sh
# tiksi ru
# punta arenas cl
# meulaboh id
# verkhoyansk ru
# bilma ne
# laizhou cn
# hambantota lk
# bengkulu id
# yumen cn
# ribeira grande pt
# la palma mx
# bluff nz
# ushuaia ar
# port macquarie au
# pudozh ru
# ushuaia ar
# barrow us
# tiarei pf
# bredasdorp za
# hermanus za
# te anau nz
# cape town za
# tunduru tz
# lesnoy ru
# hachinohe jp
# tuktoyaktuk ca
# vagamo no
# saldanha za
# sakakah sa
# busselton au
# kaitong cn
# poso id
# kaeo nz
# hobart au
# ponta do sol cv
# hithadhoo mv
# narsaq gl
# busselton au
# coihaique cl
# kapaa us
# padang id
# nisia floresta br
# talnakh ru
# mitsamiouli km
# kapaa us
# puerto ayora ec
# thompson ca
# ambon id
# hermanus za
# yellowknife ca
# pisco pe
# verkhoyansk ru
# jamestown sh
# lebu cl
# barrow us
# kiunga pg
# yerbogachen ru
# illoqqortoormiut gl
# margate za
# plymouth gb
# fortuna us
# pevek ru
# rikitea pf
# dikson ru
# ushuaia ar
# goulburn au
# thompson ca
# smolenka ru
# taolanaro mg
# barentsburg sj
# constitucion mx
# saleaula ws
# ushuaia ar
# burica pa
# tiksi ru
# namatanai pg
# tilichiki ru
# faanui pf
# ushuaia ar
# osmena ph
# cidreira br
# warqla dz
# bonga et
# punta arenas cl
# rio grande br
# busselton au
# orange au
# ushuaia ar
# ushuaia ar
# rikitea pf
# malwan in
# tchibanga ga
# limbang my
# santa marta de tormes es
# ushuaia ar
# kavieng pg
# camapua br
# rikitea pf
# mahebourg mu
# loa janan id
# avarua ck
# jamestown sh
# airai pw
# vila velha br
# santa maria do suacui br
# ushuaia ar
# mys shmidta ru
# paraiso mx
# acapulco mx
# hobart au
# saskylakh ru
# ushuaia ar
# grand river south east mu
# tortoli it
# severo-kurilsk ru
# illoqqortoormiut gl
# tinskoy ru
# hofn is
# puerto ayora ec
# bredasdorp za
# barentsburg sj
# haines junction ca
# coahuayana mx
# mizpe ramon il
# yellowknife ca
# adrar dz
# ushuaia ar
# puerto ayora ec
# xining cn
# rikitea pf
# katsuura jp
# busselton au
# constitucion mx
# laguna br
# kodiak us
# carnarvon au
# saleaula ws
# atuona pf
# bogovarovo ru
# provideniya ru
# lagoa vermelha br
# atuona pf
# powell river ca
# alta gracia ar
# morrope pe
# flinders au
# caravelas br
# lebu cl
# birao cf
# sisimiut gl
# zabol ir
# souillac mu
# busselton au
# beidao cn
# ushuaia ar
# hobart au
# flin flon ca
# kapaa us
# tura ru

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 607

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2a9169035ea6eb8c1b16a9de7e444748

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2a9169035ea6eb8c1b16a9de7e444748&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# call the response code with the get() method using the status_code
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"base":"stations","main":{"temp":70.32,"feels_like":71.04,"temp_min":67.01,"temp_max":72.79,"pressure":1014,"humidity":85},"visibility":10000,"wind":{"speed":1.99,"deg":221,"gust":5.01},"rain":{"1h":0.25},"clouds":{"all":100},"dt":1653278405,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1653297349,"sunset":1653350789},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10n'}],
#  'base': 'stations',
#  'main': {'temp': 70.32,
#   'feels_like': 71.04,
#   'temp_min': 67.01,
#   'temp_max': 72.79,
#   'pressure': 1014,
#   'humidity': 85},
#  'visibility': 10000,
#  'wind': {'speed': 1.99, 'deg': 221, 'gust': 5.01},
#  'rain': {'1h': 0.25},
#  'clouds': {'all': 100},
#  'dt': 1653278405,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1653297349,
#   'sunset': 1653350789},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Import the dependencies.
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
# Personal Practice
# new_city="Nairobi"

# %%
# Create an endpoint URL for a city.
# city_url = url + "&q=" + "Nairobi"
# city_weather = requests.get(city_url)
# city_weather

# %%
# Get the JSON text of the 'Get' request.
# city_weather.json()

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
 print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2a9169035ea6eb8c1b16a9de7e444748&q=Bston

# %%
# For each city in our lats_lngs list, we need to retrieve the following data and add it to a DataFrame:

# City, country, and date

# Latitude and longitude

# Maximum temperature

# Humidity

# Cloudiness

# Wind speed

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

city_weather = requests.get(city_url)

city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10n'}],
#  'base': 'stations',
#  'main': {'temp': 70.32,
#   'feels_like': 71.04,
#   'temp_min': 67.01,
#   'temp_max': 72.79,
#   'pressure': 1014,
#   'humidity': 85},
#  'visibility': 10000,
#  'wind': {'speed': 1.99, 'deg': 221, 'gust': 5.01},
#  'rain': {'1h': 0.25},
#  'clouds': {'all': 100},
#  'dt': 1653278405,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1653297349,
#   'sunset': 1653350789},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']["country"]
# Out:
# 'US'

# %%
boston_data['coord']['lat']
# Out:
# 42.3584

# %%
lat = boston_data["coord"]["lat"]

lng = boston_data["coord"]["lon"]

max_temp = boston_data["main"]["temp_max"]

humidity = boston_data["main"]["humidity"]

clouds = boston_data["clouds"]["all"]

wind = boston_data["wind"]["speed"]

print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 72.79 85 100 1.99

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Get the date from the JSON file.
date = boston_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 5, 23, 4, 0, 5)

# %%
# We can convert this datetime format to 2019-10-21 17:24:35 using the Python string format method strftime()
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-05-23 04:00:05'

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")

print("-----------------------------")

# Create counters.
record_count = 1

set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        record_count = 1
        
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | hamilton
# Processing Record 2 of Set 13 | kloulklubed
# Processing Record 3 of Set 13 | rikitea
# Processing Record 4 of Set 13 | severo-kurilsk
# Processing Record 5 of Set 13 | chuy
# Processing Record 6 of Set 13 | saint-augustin
# Processing Record 7 of Set 13 | bathsheba
# Processing Record 8 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 13 | yellowknife
# Processing Record 10 of Set 13 | saint-francois
# Processing Record 11 of Set 13 | hithadhoo
# Processing Record 12 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 13 | ornskoldsvik
# Processing Record 14 of Set 13 | killybegs
# Processing Record 15 of Set 13 | cherskiy
# Processing Record 16 of Set 13 | saint-philippe
# Processing Record 17 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 13 | new norfolk
# Processing Record 19 of Set 13 | menongue
# Processing Record 20 of Set 13 | tupik
# Processing Record 21 of Set 13 | salalah
# Processing Record 22 of Set 13 | prata
# Processing Record 23 of Set 13 | ribeira grande
# Processing Record 24 of Set 13 | adelaide
# Processing Record 25 of Set 13 | kodiak
# Processing Record 26 of Set 13 | busselton
# Processing Record 27 of Set 13 | punta arenas
# Processing Record 28 of Set 13 | mataura
# Processing Record 29 of Set 13 | marienburg
# Processing Record 30 of Set 13 | belgrade
# Processing Record 31 of Set 13 | necochea
# Processing Record 32 of Set 13 | atuona
# Processing Record 33 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 13 | campoverde
# Processing Record 35 of Set 13 | hobart
# Processing Record 36 of Set 13 | husavik
# Processing Record 37 of Set 13 | ushuaia
# Processing Record 38 of Set 13 | santa maria
# Processing Record 39 of Set 13 | vila velha
# Processing Record 40 of Set 13 | vaini
# Processing Record 41 of Set 13 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 13 | ostrovnoy
# Processing Record 43 of Set 13 | mitrofanovka
# Processing Record 44 of Set 13 | kapaa
# Processing Record 45 of Set 13 | kapoeta
# Processing Record 46 of Set 13 | monrovia
# Processing Record 47 of Set 13 | wagar
# Processing Record 48 of Set 13 | butaritari
# Processing Record 49 of Set 13 | carbondale
# Processing Record 50 of Set 13 | cascavel
# Processing Record 1 of Set 14 | jamestown
# Processing Record 2 of Set 14 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 14 | bambous virieux
# Processing Record 4 of Set 14 | tsogni
# Processing Record 5 of Set 14 | tuktoyaktuk
# Processing Record 6 of Set 14 | aklavik
# Processing Record 7 of Set 14 | hermanus
# Processing Record 8 of Set 14 | cidreira
# Processing Record 9 of Set 14 | yabelo
# Processing Record 10 of Set 14 | mount gambier
# Processing Record 11 of Set 14 | avarua
# Processing Record 12 of Set 14 | torbay
# Processing Record 13 of Set 14 | faanui
# Processing Record 14 of Set 14 | neiafu
# Processing Record 15 of Set 14 | flin flon
# Processing Record 16 of Set 14 | pisco
# Processing Record 17 of Set 14 | longyearbyen
# Processing Record 18 of Set 14 | moyale
# Processing Record 19 of Set 14 | padang
# Processing Record 20 of Set 14 | saint george
# Processing Record 21 of Set 14 | diego de almagro
# Processing Record 22 of Set 14 | fairbanks
# Processing Record 23 of Set 14 | port keats
# Processing Record 24 of Set 14 | geraldton
# Processing Record 25 of Set 14 | bluff
# Processing Record 26 of Set 14 | hilo
# Processing Record 27 of Set 14 | pevek
# Processing Record 28 of Set 14 | nikolskoye
# Processing Record 29 of Set 14 | namibe
# Processing Record 30 of Set 14 | dikson
# Processing Record 31 of Set 14 | taylor
# Processing Record 32 of Set 14 | shunyi
# Processing Record 33 of Set 14 | fiditi
# Processing Record 34 of Set 14 | opochka
# Processing Record 35 of Set 14 | san rafael
# Processing Record 36 of Set 14 | port alfred
# Processing Record 37 of Set 14 | bredasdorp
# Processing Record 38 of Set 14 | barrow
# Processing Record 39 of Set 14 | tura
# Processing Record 40 of Set 14 | moree
# Processing Record 41 of Set 14 | vanavara
# Processing Record 42 of Set 14 | prado
# Processing Record 43 of Set 14 | east london
# Processing Record 44 of Set 14 | poum
# Processing Record 45 of Set 14 | guerrero negro
# Processing Record 46 of Set 14 | saint-jerome
# Processing Record 47 of Set 14 | cocorit
# Processing Record 48 of Set 14 | hasaki
# Processing Record 49 of Set 14 | castro
# Processing Record 50 of Set 14 | ormara
# Processing Record 1 of Set 15 | general roca
# Processing Record 2 of Set 15 | kruisfontein
# Processing Record 3 of Set 15 | yambio
# Processing Record 4 of Set 15 | port elizabeth
# Processing Record 5 of Set 15 | mar del plata
# Processing Record 6 of Set 15 | kahului
# Processing Record 7 of Set 15 | madingou
# Processing Record 8 of Set 15 | myaundzha
# Processing Record 9 of Set 15 | gat
# Processing Record 10 of Set 15 | lagoa
# Processing Record 11 of Set 15 | albany
# Processing Record 12 of Set 15 | buraydah
# Processing Record 13 of Set 15 | lompoc
# Processing Record 14 of Set 15 | egvekinot
# Processing Record 15 of Set 15 | shingu
# Processing Record 16 of Set 15 | mgandu
# Processing Record 17 of Set 15 | bauska
# Processing Record 18 of Set 15 | kavieng
# Processing Record 19 of Set 15 | mlimba
# Processing Record 20 of Set 15 | sal rei
# Processing Record 21 of Set 15 | clyde river
# Processing Record 22 of Set 15 | nemuro
# Processing Record 23 of Set 15 | mahebourg
# Processing Record 24 of Set 15 | funtua
# Processing Record 25 of Set 15 | dogondoutchi
# Processing Record 26 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 15 | male
# Processing Record 28 of Set 15 | wenatchee
# Processing Record 29 of Set 15 | saint-georges
# Processing Record 30 of Set 15 | grindavik
# Processing Record 31 of Set 15 | emerald
# Processing Record 32 of Set 15 | along
# Processing Record 33 of Set 15 | rocky mountain house
# Processing Record 34 of Set 15 | arraial do cabo
# Processing Record 35 of Set 15 | nizwa
# Processing Record 36 of Set 15 | beringovskiy
# Processing Record 37 of Set 15 | kumluca
# Processing Record 38 of Set 15 | coquimbo
# Processing Record 39 of Set 15 | katsuura
# Processing Record 40 of Set 15 | cape town
# Processing Record 41 of Set 15 | haines junction
# Processing Record 42 of Set 15 | huarmey
# Processing Record 43 of Set 15 | mamakan
# Processing Record 44 of Set 15 | dorogobuzh
# Processing Record 45 of Set 15 | hobyo
# Processing Record 46 of Set 15 | usinsk
# Processing Record 47 of Set 15 | derzhavinsk
# Processing Record 48 of Set 15 | miles city
# Processing Record 49 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 15 | amapa
# Processing Record 1 of Set 16 | nichinan
# Processing Record 2 of Set 16 | kavaratti
# Processing Record 3 of Set 16 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 16 | puerto ayora
# Processing Record 5 of Set 16 | monteagudo
# Processing Record 6 of Set 16 | vilhena
# Processing Record 7 of Set 16 | awjilah
# Processing Record 8 of Set 16 | caravelas
# Processing Record 9 of Set 16 | shimoda
# Processing Record 10 of Set 16 | port blair
# Processing Record 11 of Set 16 | mehamn
# Processing Record 12 of Set 16 | abu kamal
# Processing Record 13 of Set 16 | los llanos de aridane
# Processing Record 14 of Set 16 | noyabrsk
# Processing Record 15 of Set 16 | kodinsk
# Processing Record 16 of Set 16 | port macquarie
# Processing Record 17 of Set 16 | alotau
# City not found. Skipping...
# Processing Record 18 of Set 16 | matay
# Processing Record 19 of Set 16 | bara
# Processing Record 20 of Set 16 | carnarvon
# Processing Record 21 of Set 16 | portland
# Processing Record 22 of Set 16 | beian
# Processing Record 23 of Set 16 | sangueya
# Processing Record 24 of Set 16 | port hardy
# Processing Record 25 of Set 16 | marrakesh
# Processing Record 26 of Set 16 | maniitsoq
# Processing Record 27 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 16 | airai
# Processing Record 29 of Set 16 | vostok
# Processing Record 30 of Set 16 | akyab
# Processing Record 31 of Set 16 | jasper
# Processing Record 32 of Set 16 | tessalit
# Processing Record 33 of Set 16 | barra patuca
# Processing Record 34 of Set 16 | souillac
# Processing Record 35 of Set 16 | puerto madero
# Processing Record 36 of Set 16 | margate
# Processing Record 37 of Set 16 | mayo
# Processing Record 38 of Set 16 | kinablangan
# Processing Record 39 of Set 16 | diu
# Processing Record 40 of Set 16 | rengo
# Processing Record 41 of Set 16 | pendleton
# Processing Record 42 of Set 16 | anadyr
# Processing Record 43 of Set 16 | chokurdakh
# Processing Record 44 of Set 16 | kishi
# Processing Record 45 of Set 16 | alofi
# Processing Record 46 of Set 16 | trenggalek
# Processing Record 47 of Set 16 | wangkui
# Processing Record 48 of Set 16 | diffa
# Processing Record 49 of Set 16 | khatanga
# Processing Record 50 of Set 16 | hami
# Processing Record 1 of Set 17 | fortuna
# Processing Record 2 of Set 17 | prince rupert
# Processing Record 3 of Set 17 | sumbawa
# City not found. Skipping...
# Processing Record 4 of Set 17 | nenjiang
# Processing Record 5 of Set 17 | sitka
# Processing Record 6 of Set 17 | grand gaube
# Processing Record 7 of Set 17 | umba
# Processing Record 8 of Set 17 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 17 | nioro
# Processing Record 10 of Set 17 | ilulissat
# Processing Record 11 of Set 17 | bilma
# Processing Record 12 of Set 17 | hammerfest
# Processing Record 13 of Set 17 | pokhara
# Processing Record 14 of Set 17 | naze
# Processing Record 15 of Set 17 | saint-pierre
# Processing Record 16 of Set 17 | muika
# City not found. Skipping...
# Processing Record 17 of Set 17 | port-gentil
# Processing Record 18 of Set 17 | heze
# Processing Record 19 of Set 17 | kutum
# Processing Record 20 of Set 17 | qaanaaq
# Processing Record 21 of Set 17 | san cristobal
# Processing Record 22 of Set 17 | tiksi
# Processing Record 23 of Set 17 | primore
# City not found. Skipping...
# Processing Record 24 of Set 17 | kaitangata
# Processing Record 25 of Set 17 | magadan
# Processing Record 26 of Set 17 | katobu
# Processing Record 27 of Set 17 | nouadhibou
# Processing Record 28 of Set 17 | khasan
# Processing Record 29 of Set 17 | rocha
# Processing Record 30 of Set 17 | dinsor
# City not found. Skipping...
# Processing Record 31 of Set 17 | manuk mangkaw
# Processing Record 32 of Set 17 | havre-saint-pierre
# Processing Record 33 of Set 17 | carrollton
# Processing Record 34 of Set 17 | sur
# Processing Record 35 of Set 17 | kalmunai
# Processing Record 36 of Set 17 | dryden
# Processing Record 37 of Set 17 | unai
# Processing Record 38 of Set 17 | gidole
# Processing Record 39 of Set 17 | tuatapere
# Processing Record 40 of Set 17 | touros
# Processing Record 41 of Set 17 | southampton
# Processing Record 42 of Set 17 | san matias
# Processing Record 43 of Set 17 | norman wells
# Processing Record 44 of Set 17 | broken hill
# Processing Record 45 of Set 17 | kiama
# Processing Record 46 of Set 17 | san julian
# Processing Record 47 of Set 17 | severnoye
# Processing Record 48 of Set 17 | strezhevoy
# Processing Record 49 of Set 17 | severnyy
# Processing Record 50 of Set 17 | manta
# Processing Record 1 of Set 18 | tete
# Processing Record 2 of Set 18 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 18 | kirovskiy
# Processing Record 4 of Set 18 | jizan
# Processing Record 5 of Set 18 | ixtapa
# Processing Record 6 of Set 18 | kirksville
# Processing Record 7 of Set 18 | santa cruz
# Processing Record 8 of Set 18 | thompson
# Processing Record 9 of Set 18 | yola
# Processing Record 10 of Set 18 | saskylakh
# Processing Record 11 of Set 18 | laguna
# Processing Record 12 of Set 18 | mbandaka
# Processing Record 13 of Set 18 | karratha
# Processing Record 14 of Set 18 | tasiilaq
# Processing Record 15 of Set 18 | okha
# Processing Record 16 of Set 18 | lasa
# Processing Record 17 of Set 18 | agrado
# Processing Record 18 of Set 18 | kerema
# Processing Record 19 of Set 18 | cayenne
# Processing Record 20 of Set 18 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 18 | mount isa
# Processing Record 22 of Set 18 | larsnes
# Processing Record 23 of Set 18 | kenai
# Processing Record 24 of Set 18 | riyadh
# Processing Record 25 of Set 18 | kletnya
# Processing Record 26 of Set 18 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 18 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 18 | iskateley
# Processing Record 29 of Set 18 | placido de castro
# Processing Record 30 of Set 18 | hlotse
# Processing Record 31 of Set 18 | petauke
# Processing Record 32 of Set 18 | mildura
# Processing Record 33 of Set 18 | korla
# Processing Record 34 of Set 18 | vila franca do campo
# Processing Record 35 of Set 18 | lorengau
# Processing Record 36 of Set 18 | anchorage
# Processing Record 37 of Set 18 | lyuban
# Processing Record 38 of Set 18 | kargasok
# Processing Record 39 of Set 18 | iranshahr
# Processing Record 40 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 18 | enshi
# Processing Record 42 of Set 18 | asau
# Processing Record 43 of Set 18 | te anau
# Processing Record 44 of Set 18 | phan thiet
# Processing Record 45 of Set 18 | porbandar
# Processing Record 46 of Set 18 | quelimane
# Processing Record 47 of Set 18 | corinto
# Processing Record 48 of Set 18 | evansville
# Processing Record 49 of Set 18 | upernavik
# Processing Record 50 of Set 18 | ottumwa
# Processing Record 1 of Set 19 | klaksvik
# Processing Record 2 of Set 19 | narrabri
# Processing Record 3 of Set 19 | longyan
# Processing Record 4 of Set 19 | codrington
# Processing Record 5 of Set 19 | boende
# Processing Record 6 of Set 19 | maraa
# Processing Record 7 of Set 19 | senanga
# Processing Record 8 of Set 19 | albox
# Processing Record 9 of Set 19 | camaqua
# Processing Record 10 of Set 19 | ancud
# Processing Record 11 of Set 19 | araguatins
# City not found. Skipping...
# Processing Record 12 of Set 19 | mahibadhoo
# Processing Record 13 of Set 19 | constitucion
# Processing Record 14 of Set 19 | jumla
# Processing Record 15 of Set 19 | sarangani
# Processing Record 16 of Set 19 | tezu
# Processing Record 17 of Set 19 | port augusta
# Processing Record 18 of Set 19 | kisangani
# Processing Record 19 of Set 19 | orocue
# Processing Record 20 of Set 19 | rio gallegos
# Processing Record 21 of Set 19 | gamba
# Processing Record 22 of Set 19 | noumea
# Processing Record 23 of Set 19 | nome
# Processing Record 24 of Set 19 | blagoyevo
# Processing Record 25 of Set 19 | yar-sale
# Processing Record 26 of Set 19 | oda
# Processing Record 27 of Set 19 | san carlos de bariloche
# Processing Record 28 of Set 19 | bengkulu
# Processing Record 29 of Set 19 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 19 | vao
# Processing Record 31 of Set 19 | falealupo
# City not found. Skipping...
# Processing Record 32 of Set 19 | roebourne
# Processing Record 33 of Set 19 | pangnirtung
# Processing Record 34 of Set 19 | bharuch
# Processing Record 35 of Set 19 | skjervoy
# Processing Record 36 of Set 19 | victoria
# Processing Record 37 of Set 19 | saldanha
# Processing Record 38 of Set 19 | sambava
# Processing Record 39 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 19 | vardo
# Processing Record 41 of Set 19 | lebu
# Processing Record 42 of Set 19 | veraval
# Processing Record 43 of Set 19 | camacupa
# Processing Record 44 of Set 19 | harper
# Processing Record 45 of Set 19 | port hedland
# Processing Record 46 of Set 19 | xadani
# City not found. Skipping...
# Processing Record 47 of Set 19 | anloga
# Processing Record 48 of Set 19 | antalaha
# Processing Record 49 of Set 19 | talnakh
# Processing Record 50 of Set 19 | yuzhno-kurilsk
# Processing Record 1 of Set 20 | progreso
# Processing Record 2 of Set 20 | wangaratta
# Processing Record 3 of Set 20 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 20 | bahir dar
# Processing Record 5 of Set 20 | pacific grove
# Processing Record 6 of Set 20 | puerto suarez
# Processing Record 7 of Set 20 | kamaishi
# Processing Record 8 of Set 20 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 20 | alyangula
# Processing Record 10 of Set 20 | tateyama
# Processing Record 11 of Set 20 | kununurra
# Processing Record 12 of Set 20 | ponta do sol
# Processing Record 13 of Set 20 | maiduguri
# Processing Record 14 of Set 20 | bairiki
# Processing Record 15 of Set 20 | yulara
# Processing Record 16 of Set 20 | bogomila
# Processing Record 17 of Set 20 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 20 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 20 | tabou
# Processing Record 20 of Set 20 | iqaluit
# Processing Record 21 of Set 20 | gurupi
# Processing Record 22 of Set 20 | champerico
# Processing Record 23 of Set 20 | cabo san lucas
# Processing Record 24 of Set 20 | aloleng
# Processing Record 25 of Set 20 | georgetown
# Processing Record 26 of Set 20 | hualmay
# Processing Record 27 of Set 20 | virtsu
# Processing Record 28 of Set 20 | lunino
# Processing Record 29 of Set 20 | patnos
# Processing Record 30 of Set 20 | dodola
# Processing Record 31 of Set 20 | candawaga
# City not found. Skipping...
# Processing Record 32 of Set 20 | bokspits
# City not found. Skipping...
# Processing Record 33 of Set 20 | provideniya
# Processing Record 34 of Set 20 | leshukonskoye
# Processing Record 35 of Set 20 | acarau
# Processing Record 36 of Set 20 | centenario do sul
# Processing Record 37 of Set 20 | kargil
# Processing Record 38 of Set 20 | mtwara
# Processing Record 39 of Set 20 | nioki
# Processing Record 40 of Set 20 | dolores
# Processing Record 41 of Set 20 | tigil
# Processing Record 42 of Set 20 | san patricio
# Processing Record 43 of Set 20 | quthing
# Processing Record 44 of Set 20 | phalodi
# Processing Record 45 of Set 20 | tucuman
# Processing Record 46 of Set 20 | miri
# Processing Record 47 of Set 20 | tiarei
# Processing Record 48 of Set 20 | alihe
# Processing Record 49 of Set 20 | awbari
# Processing Record 50 of Set 20 | skrunda
# Processing Record 1 of Set 21 | zhigalovo
# Processing Record 2 of Set 21 | borlange
# City not found. Skipping...
# Processing Record 3 of Set 21 | whitehorse
# Processing Record 4 of Set 21 | scottsburgh
# City not found. Skipping...
# Processing Record 5 of Set 21 | baiao
# Processing Record 6 of Set 21 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 21 | marzuq
# Processing Record 8 of Set 21 | vitry-le-francois
# Processing Record 9 of Set 21 | semporna
# Processing Record 10 of Set 21 | hambantota
# Processing Record 11 of Set 21 | qui nhon
# Processing Record 12 of Set 21 | saint marys
# Processing Record 13 of Set 21 | warmbad
# Processing Record 14 of Set 21 | esperance
# Processing Record 15 of Set 21 | alice springs
# Processing Record 16 of Set 21 | jacqueville
# Processing Record 17 of Set 21 | buchanan
# Processing Record 18 of Set 21 | denpasar
# Processing Record 19 of Set 21 | alta floresta
# Processing Record 20 of Set 21 | nayudupeta
# Processing Record 21 of Set 21 | morondava
# Processing Record 22 of Set 21 | kungurtug
# Processing Record 23 of Set 21 | stornoway
# Processing Record 24 of Set 21 | yuksekova
# Processing Record 25 of Set 21 | zhigansk
# Processing Record 26 of Set 21 | bandarbeyla
# Processing Record 27 of Set 21 | pombia
# Processing Record 28 of Set 21 | waingapu
# Processing Record 29 of Set 21 | agadir
# Processing Record 30 of Set 21 | sterling
# Processing Record 31 of Set 21 | kresttsy
# Processing Record 32 of Set 21 | mercedes
# Processing Record 33 of Set 21 | hun
# Processing Record 34 of Set 21 | dalmatovo
# Processing Record 35 of Set 21 | blackfoot
# Processing Record 36 of Set 21 | spornoye
# Processing Record 37 of Set 21 | ulaangom
# Processing Record 38 of Set 21 | mana
# Processing Record 39 of Set 21 | yertarskiy
# Processing Record 40 of Set 21 | tomigusuku
# Processing Record 41 of Set 21 | gimli
# Processing Record 42 of Set 21 | kesan
# Processing Record 43 of Set 21 | raychikhinsk
# Processing Record 44 of Set 21 | bethel
# Processing Record 45 of Set 21 | abu zabad
# Processing Record 46 of Set 21 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 21 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 21 | hailey
# Processing Record 49 of Set 21 | tautira
# Processing Record 50 of Set 21 | waling
# Processing Record 1 of Set 22 | miramar
# Processing Record 2 of Set 22 | coos bay
# Processing Record 3 of Set 22 | athabasca
# Processing Record 4 of Set 22 | pryazha
# Processing Record 5 of Set 22 | pullman
# Processing Record 6 of Set 22 | avera
# Processing Record 7 of Set 22 | bajo baudo
# City not found. Skipping...
# Processing Record 8 of Set 22 | sao filipe
# Processing Record 9 of Set 22 | saint-leu
# Processing Record 10 of Set 22 | lithakia
# Processing Record 11 of Set 22 | kofele
# Processing Record 12 of Set 22 | point pedro
# Processing Record 13 of Set 22 | isangel
# Processing Record 14 of Set 22 | port pirie
# Processing Record 15 of Set 22 | nanortalik
# Processing Record 16 of Set 22 | payo
# Processing Record 17 of Set 22 | naantali
# Processing Record 18 of Set 22 | kautokeino
# Processing Record 19 of Set 22 | narsaq
# Processing Record 20 of Set 22 | rafai
# Processing Record 21 of Set 22 | coihaique
# Processing Record 22 of Set 22 | oksfjord
# Processing Record 23 of Set 22 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 22 | alexandria
# Processing Record 25 of Set 22 | sept-iles
# Processing Record 26 of Set 22 | nantucket
# Processing Record 27 of Set 22 | ajdabiya
# Processing Record 28 of Set 22 | sabha
# Processing Record 29 of Set 22 | jiexiu
# Processing Record 30 of Set 22 | warrnambool
# Processing Record 31 of Set 22 | batagay-alyta
# Processing Record 32 of Set 22 | mopipi
# Processing Record 33 of Set 22 | sao sebastiao
# Processing Record 34 of Set 22 | mareeba
# Processing Record 35 of Set 22 | lourdes
# Processing Record 36 of Set 22 | gambela
# Processing Record 37 of Set 22 | sao jose da coroa grande
# Processing Record 38 of Set 22 | tazovskiy
# Processing Record 39 of Set 22 | sampit
# Processing Record 40 of Set 22 | kouango
# Processing Record 41 of Set 22 | soyo
# Processing Record 42 of Set 22 | tromso
# Processing Record 43 of Set 22 | guarapari
# Processing Record 44 of Set 22 | leningradskiy
# Processing Record 45 of Set 22 | ust-maya
# Processing Record 46 of Set 22 | arrifes
# Processing Record 47 of Set 22 | newark
# Processing Record 48 of Set 22 | leh
# Processing Record 49 of Set 22 | keita
# Processing Record 50 of Set 22 | kadykchan
# City not found. Skipping...
# Processing Record 1 of Set 23 | nizhniy baskunchak
# Processing Record 2 of Set 23 | nabire
# Processing Record 3 of Set 23 | salyan
# Processing Record 4 of Set 23 | erechim
# Processing Record 5 of Set 23 | daru
# Processing Record 6 of Set 23 | kastamonu
# Processing Record 7 of Set 23 | asmar
# Processing Record 8 of Set 23 | innisfail
# Processing Record 9 of Set 23 | katha
# City not found. Skipping...
# Processing Record 10 of Set 23 | inhambane
# Processing Record 11 of Set 23 | kushmurun
# Processing Record 12 of Set 23 | la rioja
# Processing Record 13 of Set 23 | obigarm
# Processing Record 14 of Set 23 | paita
# Processing Record 15 of Set 23 | babanusah
# City not found. Skipping...
# Processing Record 16 of Set 23 | lishui
# Processing Record 17 of Set 23 | hendek
# Processing Record 18 of Set 23 | puerto palomas
# Processing Record 19 of Set 23 | torres
# Processing Record 20 of Set 23 | ambulu
# Processing Record 21 of Set 23 | mragowo
# Processing Record 22 of Set 23 | sibolga
# Processing Record 23 of Set 23 | saint-denis
# Processing Record 24 of Set 23 | mizdah
# Processing Record 25 of Set 23 | mandurah
# Processing Record 26 of Set 23 | udachnyy
# Processing Record 27 of Set 23 | picton
# Processing Record 28 of Set 23 | jimeta
# Processing Record 29 of Set 23 | sumenep
# Processing Record 30 of Set 23 | sinegorye
# Processing Record 31 of Set 23 | gizo
# Processing Record 32 of Set 23 | perth
# Processing Record 33 of Set 23 | basco
# Processing Record 34 of Set 23 | coahuayana
# Processing Record 35 of Set 23 | tilichiki
# Processing Record 36 of Set 23 | jieshi
# Processing Record 37 of Set 23 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 23 | walvis bay
# Processing Record 39 of Set 23 | college
# Processing Record 40 of Set 23 | kuito
# Processing Record 41 of Set 23 | gogrial
# Processing Record 42 of Set 23 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 23 | rize
# Processing Record 44 of Set 23 | marsabit
# Processing Record 45 of Set 23 | otradnoye
# Processing Record 46 of Set 23 | ambilobe
# Processing Record 47 of Set 23 | dire dawa
# Processing Record 48 of Set 23 | mugur-aksy
# Processing Record 49 of Set 23 | ziebice
# Processing Record 50 of Set 23 | bam
# Processing Record 1 of Set 24 | roma
# Processing Record 2 of Set 24 | manavalakurichi
# Processing Record 3 of Set 24 | rio verde de mato grosso
# Processing Record 4 of Set 24 | abu samrah
# Processing Record 5 of Set 24 | north ogden
# Processing Record 6 of Set 24 | meulaboh
# Processing Record 7 of Set 24 | verkhoyansk
# Processing Record 8 of Set 24 | laizhou
# Processing Record 9 of Set 24 | yumen
# Processing Record 10 of Set 24 | la palma
# Processing Record 11 of Set 24 | pudozh
# Processing Record 12 of Set 24 | tunduru
# City not found. Skipping...
# Processing Record 13 of Set 24 | lesnoy
# Processing Record 14 of Set 24 | hachinohe
# Processing Record 15 of Set 24 | vagamo
# Processing Record 16 of Set 24 | sakakah
# Processing Record 17 of Set 24 | kaitong
# Processing Record 18 of Set 24 | poso
# Processing Record 19 of Set 24 | kaeo
# Processing Record 20 of Set 24 | nisia floresta
# Processing Record 21 of Set 24 | mitsamiouli
# Processing Record 22 of Set 24 | ambon
# Processing Record 23 of Set 24 | kiunga
# Processing Record 24 of Set 24 | yerbogachen
# Processing Record 25 of Set 24 | plymouth
# Processing Record 26 of Set 24 | goulburn
# Processing Record 27 of Set 24 | smolenka
# Processing Record 28 of Set 24 | burica
# City not found. Skipping...
# Processing Record 29 of Set 24 | namatanai
# Processing Record 30 of Set 24 | osmena
# Processing Record 31 of Set 24 | bonga
# Processing Record 32 of Set 24 | rio grande
# Processing Record 33 of Set 24 | orange
# Processing Record 34 of Set 24 | tchibanga
# Processing Record 35 of Set 24 | limbang
# Processing Record 36 of Set 24 | santa marta de tormes
# Processing Record 37 of Set 24 | camapua
# Processing Record 38 of Set 24 | loa janan
# Processing Record 39 of Set 24 | santa maria do suacui
# Processing Record 40 of Set 24 | paraiso
# Processing Record 41 of Set 24 | acapulco
# Processing Record 42 of Set 24 | tortoli
# Processing Record 43 of Set 24 | tinskoy
# Processing Record 44 of Set 24 | hofn
# Processing Record 45 of Set 24 | mizpe ramon
# City not found. Skipping...
# Processing Record 46 of Set 24 | adrar
# Processing Record 47 of Set 24 | xining
# Processing Record 48 of Set 24 | bogovarovo
# Processing Record 49 of Set 24 | lagoa vermelha
# Processing Record 50 of Set 24 | powell river
# Processing Record 1 of Set 25 | alta gracia
# Processing Record 2 of Set 25 | morrope
# Processing Record 3 of Set 25 | flinders
# Processing Record 4 of Set 25 | birao
# Processing Record 5 of Set 25 | sisimiut
# Processing Record 6 of Set 25 | zabol
# Processing Record 7 of Set 25 | beidao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hamilton  39.1834  -84.5333     60.91        67         100
# 1     Kloulklubed   7.0419  134.2556     84.70        70         100
# 2         Rikitea -23.1203 -134.9692     76.23        76          55
# 3  Severo-Kurilsk  50.6789  156.1250     41.79        96         100
# 4            Chuy -33.6971  -53.4616     51.03        85          34
# 5  Saint-Augustin  51.2260  -58.6502     44.74        97         100
# 6       Bathsheba  13.2167  -59.5167     81.21        78          20
# 7     Yellowknife  62.4560 -114.3525     35.56        64          99
# 8  Saint-Francois  46.4154    3.9054     62.67        88           0
# 9       Hithadhoo  -0.6000   73.0833     83.32        74         100
#
#    Wind Speed Country                 Date
# 0        3.00      US  2022-05-23 03:58:44
# 1       10.20      PW  2022-05-23 04:03:36
# 2       16.46      PF  2022-05-23 04:03:36
# 3       14.27      RU  2022-05-23 04:03:37
# 4        6.08      UY  2022-05-23 04:03:37
# 5        7.76      CA  2022-05-23 04:03:37
# 6       12.66      BB  2022-05-23 04:03:38
# 7        8.01      CA  2022-05-23 04:00:27
# 8        2.30      FR  2022-05-23 04:03:38
# 9       10.47      MV  2022-05-23 04:03:39

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1653279546.477439

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig4.png")
# Show plot.
plt.show()

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.45x + 92.94
# The p-value is: 0.011

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt
# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")


# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")


plt.xlabel('Latitude')
plt.ylabel('Temp')

plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
  
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
 index13 = city_data_df.loc[13]

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hamilton  39.1834  -84.5333     60.91        67         100
# 1       Kloulklubed   7.0419  134.2556     84.70        70         100
# 3    Severo-Kurilsk  50.6789  156.1250     41.79        96         100
# 5    Saint-Augustin  51.2260  -58.6502     44.74        97         100
# 6         Bathsheba  13.2167  -59.5167     81.21        78          20
# ..              ...      ...       ...       ...       ...         ...
# 553    Powell River  49.8496 -124.5361     60.33        64         100
# 557           Birao  10.2849   22.7882     81.45        46          98
# 558        Sisimiut  66.9395  -53.6735     32.99        84         100
# 559           Zabol  32.2500   67.2500     66.24        12           0
# 560          Beidao  34.5686  105.8933     76.82        48          29
#
#      Wind Speed Country                 Date
# 0          3.00      US  2022-05-23 03:58:44
# 1         10.20      PW  2022-05-23 04:03:36
# 3         14.27      RU  2022-05-23 04:03:37
# 5          7.76      CA  2022-05-23 04:03:37
# 6         12.66      BB  2022-05-23 04:03:38
# ..          ...     ...                  ...
# 553        4.09      CA  2022-05-23 04:13:46
# 557        0.54      CF  2022-05-23 04:19:05
# 558        7.54      GL  2022-05-23 04:19:05
# 559        8.46      AF  2022-05-23 04:19:05
# 560        2.44      CN  2022-05-23 04:19:06
#
# [374 rows x 9 columns]

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hamilton  39.1834  -84.5333     60.91        67         100
# 1     Kloulklubed   7.0419  134.2556     84.70        70         100
# 3  Severo-Kurilsk  50.6789  156.1250     41.79        96         100
# 5  Saint-Augustin  51.2260  -58.6502     44.74        97         100
# 6       Bathsheba  13.2167  -59.5167     81.21        78          20
#
#    Wind Speed Country                 Date
# 0        3.00      US  2022-05-23 03:58:44
# 1       10.20      PW  2022-05-23 04:03:36
# 3       14.27      RU  2022-05-23 04:03:37
# 5        7.76      CA  2022-05-23 04:03:37
# 6       12.66      BB  2022-05-23 04:03:38

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature','Max Temp',(10,40))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity','% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression for %cloudinesss on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness','% Cloudiness',(10,55))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
     # Linear regression on the Northern Hemisphere
    x_values = northern_hemi_df["Lat"]
    y_values = northern_hemi_df["Wind Speed"]
     # Call the function.
    plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))

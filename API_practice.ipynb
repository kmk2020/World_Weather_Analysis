# %%
# Import the dependencies.
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)

lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
   # print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
         # citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
pip freeze
# Out:
# alabaster @ file:///home/ktietz/src/ci/alabaster_1611921544520/work
# anaconda-client @ file:///C:/ci/anaconda-client_1635342725944/work
# anaconda-navigator==2.1.4
# anaconda-project @ file:///tmp/build/80754af9/anaconda-project_1626085644852/work
# anyio @ file:///C:/ci/anyio_1620153135622/work/dist
# appdirs==1.4.4
# argh==0.26.2
# argon2-cffi @ file:///C:/ci/argon2-cffi_1613037869401/work
# arrow @ file:///C:/ci/arrow_1617738834352/work
# asn1crypto @ file:///tmp/build/80754af9/asn1crypto_1596577642040/work
# astroid @ file:///C:/ci/astroid_1628063282661/work
# astropy @ file:///C:/ci/astropy_1629829318700/work
# async-generator @ file:///home/ktietz/src/ci/async_generator_1611927993394/work
# atomicwrites==1.4.0
# attrs @ file:///tmp/build/80754af9/attrs_1620827162558/work
# autopep8 @ file:///tmp/build/80754af9/autopep8_1620866417880/work
# Babel @ file:///tmp/build/80754af9/babel_1620871417480/work
# backcall @ file:///home/ktietz/src/ci/backcall_1611930011877/work
# backports.functools-lru-cache @ file:///tmp/build/80754af9/backports.functools_lru_cache_1618170165463/work
# backports.shutil-get-terminal-size @ file:///tmp/build/80754af9/backports.shutil_get_terminal_size_1608222128777/work
# backports.tempfile @ file:///home/linux1/recipes/ci/backports.tempfile_1610991236607/work
# backports.weakref==1.0.post1
# bcrypt @ file:///C:/ci/bcrypt_1607022693089/work
# beautifulsoup4 @ file:///tmp/build/80754af9/beautifulsoup4_1631874778482/work
# binaryornot @ file:///tmp/build/80754af9/binaryornot_1617751525010/work
# bitarray @ file:///C:/ci/bitarray_1629133068652/work
# bkcharts==0.2
# black==19.10b0
# bleach @ file:///tmp/build/80754af9/bleach_1628110601003/work
# bokeh @ file:///C:/ci/bokeh_1635306491714/work
# boto==2.49.0
# Bottleneck @ file:///C:/ci/bottleneck_1607557040328/work
# brotlipy==0.7.0
# cached-property @ file:///tmp/build/80754af9/cached-property_1600785575025/work
# certifi==2021.10.8
# cffi @ file:///C:/ci/cffi_1625831756778/work
# chardet @ file:///C:/ci/chardet_1607706937985/work
# charset-normalizer @ file:///tmp/build/80754af9/charset-normalizer_1630003229654/work
# citipy==0.0.5
# click==8.0.3
# cloudpickle @ file:///tmp/build/80754af9/cloudpickle_1632508026186/work
# clyent==1.2.2
# colorama @ file:///tmp/build/80754af9/colorama_1607707115595/work
# comtypes==1.1.10
# conda==4.12.0
# conda-build==3.21.6
# conda-content-trust @ file:///tmp/build/80754af9/conda-content-trust_1617045594566/work
# conda-pack @ file:///tmp/build/80754af9/conda-pack_1611163042455/work
# conda-package-handling @ file:///C:/ci/conda-package-handling_1618262410900/work
# conda-repo-cli @ file:///tmp/build/80754af9/conda-repo-cli_1620168426516/work
# conda-token @ file:///tmp/build/80754af9/conda-token_1620076980546/work
# conda-verify==3.4.2
# contextlib2 @ file:///Users/ktietz/demo/mc3/conda-bld/contextlib2_1630668244042/work
# cookiecutter @ file:///tmp/build/80754af9/cookiecutter_1617748928239/work
# cryptography @ file:///C:/ci/cryptography_1633520531101/work
# cycler==0.10.0
# Cython @ file:///C:/ci/cython_1636018292912/work
# cytoolz==0.11.0
# daal4py==2021.3.0
# dask==2021.10.0
# debugpy @ file:///C:/ci/debugpy_1629222819322/work
# decorator @ file:///tmp/build/80754af9/decorator_1632776554403/work
# defusedxml @ file:///tmp/build/80754af9/defusedxml_1615228127516/work
# diff-match-patch @ file:///Users/ktietz/demo/mc3/conda-bld/diff-match-patch_1630511840874/work
# distributed @ file:///C:/ci/distributed_1635968318313/work
# docutils @ file:///C:/ci/docutils_1620828264669/work
# entrypoints==0.3
# et-xmlfile==1.1.0
# fastcache @ file:///C:/ci/fastcache_1607571310570/work
# filelock @ file:///tmp/build/80754af9/filelock_1635402558181/work
# flake8 @ file:///tmp/build/80754af9/flake8_1620776156532/work
# Flask @ file:///home/ktietz/src/ci/flask_1611932660458/work
# Note: you may need to restart the kernel to use updated packages.
# fonttools==4.25.0
# fsspec @ file:///tmp/build/80754af9/fsspec_1636116461911/work
# future @ file:///C:/ci/future_1607568713721/work
# geojson==2.5.0
# gevent @ file:///C:/ci/gevent_1628273776273/work
# glob2 @ file:///home/linux1/recipes/ci/glob2_1610991677669/work
# gmaps==0.9.0
# greenlet @ file:///C:/ci/greenlet_1628888275363/work
# h5py @ file:///C:/ci/h5py_1622088609188/work
# HeapDict @ file:///Users/ktietz/demo/mc3/conda-bld/heapdict_1630598515714/work
# html5lib @ file:///Users/ktietz/demo/mc3/conda-bld/html5lib_1629144453894/work
# idna @ file:///tmp/build/80754af9/idna_1622654382723/work
# imagecodecs @ file:///C:/ci/imagecodecs_1635511087451/work
# imageio @ file:///tmp/build/80754af9/imageio_1617700267927/work
# imagesize @ file:///Users/ktietz/demo/mc3/conda-bld/imagesize_1628863108022/work
# importlib-metadata @ file:///C:/ci/importlib-metadata_1631916826748/work
# inflection==0.5.1
# iniconfig @ file:///home/linux1/recipes/ci/iniconfig_1610983019677/work
# intervaltree @ file:///Users/ktietz/demo/mc3/conda-bld/intervaltree_1630511889664/work
# ipykernel @ file:///C:/ci/ipykernel_1633545585502/work/dist/ipykernel-6.4.1-py3-none-any.whl
# ipython @ file:///C:/ci/ipython_1635944283918/work
# ipython-genutils @ file:///tmp/build/80754af9/ipython_genutils_1606773439826/work
# ipywidgets @ file:///tmp/build/80754af9/ipywidgets_1634143127070/work
# isort @ file:///tmp/build/80754af9/isort_1628603791788/work
# itsdangerous @ file:///tmp/build/80754af9/itsdangerous_1621432558163/work
# jdcal @ file:///Users/ktietz/demo/mc3/conda-bld/jdcal_1630584345063/work
# jedi @ file:///C:/ci/jedi_1611341083684/work
# Jinja2 @ file:///tmp/build/80754af9/jinja2_1612213139570/work
# jinja2-time @ file:///tmp/build/80754af9/jinja2-time_1617751524098/work
# joblib @ file:///tmp/build/80754af9/joblib_1635411271373/work
# json5 @ file:///tmp/build/80754af9/json5_1624432770122/work
# jsonschema @ file:///Users/ktietz/demo/mc3/conda-bld/jsonschema_1630511932244/work
# jupyter @ file:///C:/ci/jupyter_1607685287094/work
# jupyter-client @ file:///tmp/build/80754af9/jupyter_client_1616770841739/work
# jupyter-console @ file:///tmp/build/80754af9/jupyter_console_1616615302928/work
# jupyter-core @ file:///C:/ci/jupyter_core_1633420716440/work
# jupyter-server @ file:///C:/ci/jupyter_server_1616084298419/work
# jupyterlab @ file:///tmp/build/80754af9/jupyterlab_1635799997693/work
# jupyterlab-pygments @ file:///tmp/build/80754af9/jupyterlab_pygments_1601490720602/work
# jupyterlab-server @ file:///tmp/build/80754af9/jupyterlab_server_1633419203660/work
# jupyterlab-widgets @ file:///tmp/build/80754af9/jupyterlab_widgets_1609884341231/work
# kdtree==0.16
# keyring @ file:///C:/ci/keyring_1629321702436/work
# kiwisolver @ file:///C:/ci/kiwisolver_1612282555033/work
# lazy-object-proxy @ file:///C:/ci/lazy-object-proxy_1616529288960/work
# libarchive-c @ file:///tmp/build/80754af9/python-libarchive-c_1617780486945/work
# llvmlite==0.37.0
# locket==0.2.1
# lxml @ file:///C:/ci/lxml_1616443418777/work
# MarkupSafe @ file:///C:/ci/markupsafe_1607027406824/work
# matplotlib @ file:///C:/ci/matplotlib-suite_1634667159685/work
# matplotlib-inline @ file:///tmp/build/80754af9/matplotlib-inline_1628242447089/work
# mccabe==0.6.1
# menuinst @ file:///C:/ci/menuinst_1631733438520/work
# mistune @ file:///C:/ci/mistune_1607359457024/work
# mkl-fft==1.3.1
# mkl-random @ file:///C:/ci/mkl_random_1626186184308/work
# mkl-service==2.4.0
# mock @ file:///tmp/build/80754af9/mock_1607622725907/work
# more-itertools @ file:///tmp/build/80754af9/more-itertools_1635423142362/work
# mpmath==1.2.1
# msgpack @ file:///C:/ci/msgpack-python_1612287350784/work
# multipledispatch @ file:///C:/ci/multipledispatch_1607574329826/work
# munkres==1.1.4
# mypy-extensions==0.4.3
# mysql-connector-python==8.0.27
# navigator-updater==0.2.1
# nbclassic @ file:///tmp/build/80754af9/nbclassic_1616085367084/work
# nbclient @ file:///tmp/build/80754af9/nbclient_1614364831625/work
# nbconvert @ file:///C:/ci/nbconvert_1624479160025/work
# nbformat @ file:///tmp/build/80754af9/nbformat_1617383369282/work
# nest-asyncio @ file:///tmp/build/80754af9/nest-asyncio_1613680548246/work
# networkx @ file:///tmp/build/80754af9/networkx_1633639043937/work
# nltk==3.6.5
# nose @ file:///tmp/build/80754af9/nose_1606773131901/work
# notebook @ file:///C:/ci/notebook_1635393701545/work
# numba @ file:///C:/ci/numba_1635186062888/work
# numexpr @ file:///C:/ci/numexpr_1618856728739/work
# numpy @ file:///C:/ci/numpy_and_numpy_base_1626271900803/work
# numpydoc @ file:///tmp/build/80754af9/numpydoc_1605117425582/work
# olefile @ file:///Users/ktietz/demo/mc3/conda-bld/olefile_1629805411829/work
# openpyxl @ file:///tmp/build/80754af9/openpyxl_1632777717936/work
# packaging @ file:///tmp/build/80754af9/packaging_1625611678980/work
# pandas @ file:///C:/ci/pandas_1635506685681/work
# pandocfilters @ file:///C:/ci/pandocfilters_1605114832805/work
# paramiko @ file:///tmp/build/80754af9/paramiko_1598886428689/work
# parso @ file:///tmp/build/80754af9/parso_1617223946239/work
# partd @ file:///tmp/build/80754af9/partd_1618000087440/work
# path @ file:///C:/ci/path_1624287837534/work
# pathlib2 @ file:///C:/ci/pathlib2_1625585796814/work
# pathspec==0.7.0
# patsy==0.5.2
# pep8==1.7.1
# pexpect @ file:///tmp/build/80754af9/pexpect_1605563209008/work
# pickleshare @ file:///tmp/build/80754af9/pickleshare_1606932040724/work
# Pillow==8.4.0
# pkginfo==1.7.1
# pluggy @ file:///C:/ci/pluggy_1615976440052/work
# ply==3.11
# poyo @ file:///tmp/build/80754af9/poyo_1617751526755/work
# prometheus-client @ file:///tmp/build/80754af9/prometheus_client_1623189609245/work
# prompt-toolkit @ file:///tmp/build/80754af9/prompt-toolkit_1633440160888/work
# psutil @ file:///C:/ci/psutil_1612298199233/work
# ptyprocess @ file:///tmp/build/80754af9/ptyprocess_1609355006118/work/dist/ptyprocess-0.7.0-py2.py3-none-any.whl
# py @ file:///tmp/build/80754af9/py_1607971587848/work
# pycodestyle @ file:///tmp/build/80754af9/pycodestyle_1615748559966/work
# pycosat==0.6.3
# pycparser @ file:///tmp/build/80754af9/pycparser_1594388511720/work
# pycurl==7.44.1
# pydocstyle @ file:///tmp/build/80754af9/pydocstyle_1621600989141/work
# pyerfa @ file:///C:/ci/pyerfa_1621560974055/work
# pyflakes @ file:///tmp/build/80754af9/pyflakes_1617200973297/work
# Pygments @ file:///tmp/build/80754af9/pygments_1629234116488/work
# PyJWT @ file:///C:/ci/pyjwt_1619682721924/work
# pylint @ file:///C:/ci/pylint_1627536884966/work
# pyls-spyder==0.4.0
# PyNaCl @ file:///C:/ci/pynacl_1607612759007/work
# pyodbc===4.0.0-unsupported
# pyOpenSSL @ file:///tmp/build/80754af9/pyopenssl_1635333100036/work
# pyparsing @ file:///tmp/build/80754af9/pyparsing_1635766073266/work
# pyreadline==2.1
# pyrsistent @ file:///C:/ci/pyrsistent_1636093225342/work
# PySocks @ file:///C:/ci/pysocks_1605307512533/work
# pytest==6.2.4
# python-dateutil @ file:///tmp/build/80754af9/python-dateutil_1626374649649/work
# python-lsp-black @ file:///tmp/build/80754af9/python-lsp-black_1634232156041/work
# python-lsp-jsonrpc==1.0.0
# python-lsp-server==1.2.4
# python-slugify @ file:///tmp/build/80754af9/python-slugify_1620405669636/work
# pytz==2021.3
# PyWavelets @ file:///C:/ci/pywavelets_1607645631519/work
# pywin32==228
# pywin32-ctypes @ file:///C:/ci/pywin32-ctypes_1607553594546/work
# pywinpty @ file:///C:/ci/pywinpty_1607419945780/work
# PyYAML==6.0
# pyzmq @ file:///C:/ci/pyzmq_1628276105793/work
# QDarkStyle @ file:///tmp/build/80754af9/qdarkstyle_1617386714626/work
# qstylizer @ file:///tmp/build/80754af9/qstylizer_1617713584600/work/dist/qstylizer-0.1.10-py2.py3-none-any.whl
# QtAwesome @ file:///tmp/build/80754af9/qtawesome_1615991616277/work
# qtconsole @ file:///tmp/build/80754af9/qtconsole_1632739723211/work
# QtPy @ file:///tmp/build/80754af9/qtpy_1629397026935/work
# regex @ file:///C:/ci/regex_1628063427816/work
# requests @ file:///tmp/build/80754af9/requests_1629994808627/work
# rope @ file:///tmp/build/80754af9/rope_1623703006312/work
# Rtree @ file:///C:/ci/rtree_1618421015405/work
# ruamel-yaml-conda @ file:///C:/ci/ruamel_yaml_1616016898638/work
# scikit-image==0.18.3
# scikit-learn @ file:///C:/ci/scikit-learn_1622739499047/work
# scikit-learn-intelex==2021.20210714.120553
# scipy @ file:///C:/ci/scipy_1630606917240/work
# seaborn @ file:///tmp/build/80754af9/seaborn_1629307859561/work
# Send2Trash @ file:///tmp/build/80754af9/send2trash_1632406701022/work
# simplegeneric==0.8.1
# singledispatch @ file:///tmp/build/80754af9/singledispatch_1629321204894/work
# sip==4.19.13
# six @ file:///tmp/build/80754af9/six_1623709665295/work
# sniffio @ file:///C:/ci/sniffio_1614030527509/work
# snowballstemmer @ file:///tmp/build/80754af9/snowballstemmer_1611258885636/work
# sortedcollections @ file:///tmp/build/80754af9/sortedcollections_1611172717284/work
# sortedcontainers @ file:///tmp/build/80754af9/sortedcontainers_1623949099177/work
# soupsieve @ file:///tmp/build/80754af9/soupsieve_1616183228191/work
# Sphinx==4.2.0
# sphinxcontrib-applehelp @ file:///home/ktietz/src/ci/sphinxcontrib-applehelp_1611920841464/work
# sphinxcontrib-devhelp @ file:///home/ktietz/src/ci/sphinxcontrib-devhelp_1611920923094/work
# sphinxcontrib-htmlhelp @ file:///tmp/build/80754af9/sphinxcontrib-htmlhelp_1623945626792/work
# sphinxcontrib-jsmath @ file:///home/ktietz/src/ci/sphinxcontrib-jsmath_1611920942228/work
# sphinxcontrib-qthelp @ file:///home/ktietz/src/ci/sphinxcontrib-qthelp_1611921055322/work
# sphinxcontrib-serializinghtml @ file:///tmp/build/80754af9/sphinxcontrib-serializinghtml_1624451540180/work
# sphinxcontrib-websupport @ file:///tmp/build/80754af9/sphinxcontrib-websupport_1597081412696/work
# spyder @ file:///C:/ci/spyder_1636480369575/work
# spyder-kernels @ file:///C:/ci/spyder-kernels_1634237096710/work
# SQLAlchemy @ file:///C:/ci/sqlalchemy_1626948551162/work
# statsmodels==0.12.2
# sympy @ file:///C:/ci/sympy_1635219088507/work
# tables==3.6.1
# TBB==0.2
# tblib @ file:///Users/ktietz/demo/mc3/conda-bld/tblib_1629402031467/work
# terminado==0.9.4
# testpath @ file:///tmp/build/80754af9/testpath_1624638946665/work
# text-unidecode @ file:///Users/ktietz/demo/mc3/conda-bld/text-unidecode_1629401354553/work
# textdistance @ file:///tmp/build/80754af9/textdistance_1612461398012/work
# threadpoolctl @ file:///Users/ktietz/demo/mc3/conda-bld/threadpoolctl_1629802263681/work
# three-merge @ file:///tmp/build/80754af9/three-merge_1607553261110/work
# tifffile @ file:///tmp/build/80754af9/tifffile_1627275862826/work
# tinycss @ file:///tmp/build/80754af9/tinycss_1617713798712/work
# toml @ file:///tmp/build/80754af9/toml_1616166611790/work
# toolz @ file:///home/linux1/recipes/ci/toolz_1610987900194/work
# tornado @ file:///C:/ci/tornado_1606924294691/work
# tqdm @ file:///tmp/build/80754af9/tqdm_1635330843403/work
# traitlets @ file:///tmp/build/80754af9/traitlets_1632522747050/work
# typed-ast @ file:///C:/ci/typed-ast_1624953797214/work
# typing-extensions @ file:///tmp/build/80754af9/typing_extensions_1631814937681/work
# ujson @ file:///C:/ci/ujson_1611259568517/work
# unicodecsv==0.14.1
# Unidecode @ file:///tmp/build/80754af9/unidecode_1614712377438/work
# urllib3==1.26.7
# watchdog @ file:///C:/ci/watchdog_1624955113064/work
# wcwidth @ file:///Users/ktietz/demo/mc3/conda-bld/wcwidth_1629357192024/work
# webencodings==0.5.1
# Werkzeug @ file:///tmp/build/80754af9/werkzeug_1635505089296/work
# whichcraft @ file:///tmp/build/80754af9/whichcraft_1617751293875/work
# widgetsnbextension @ file:///C:/ci/widgetsnbextension_1607531582688/work
# win-inet-pton @ file:///C:/ci/win_inet_pton_1605306162074/work
# win-unicode-console==0.5
# wincertstore==0.2
# wrapt @ file:///C:/ci/wrapt_1607574570428/work
# xlrd @ file:///tmp/build/80754af9/xlrd_1608072521494/work
# XlsxWriter @ file:///tmp/build/80754af9/xlsxwriter_1628603415431/work
# xlwings==0.24.9
# xlwt==1.3.0
# xmltodict @ file:///Users/ktietz/demo/mc3/conda-bld/xmltodict_1629301980723/work
# yapf @ file:///tmp/build/80754af9/yapf_1615749224965/work
# zict==2.0.0
# zipp @ file:///tmp/build/80754af9/zipp_1633618647012/work
# zope.event==4.5.0
# zope.interface @ file:///C:/ci/zope.interface_1625036252485/work

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\kelvi\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\kelvi\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
class City:
    '''
    City wraps up the info about a city, including its name, coordinates,
    and belonging country.
    '''
    def __init__(self, city_name, country_code):
        self.city_name = city_name
        
        
        self.country_code = country_code

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# nikolskoye ru
# kaya bf
# dikson ru
# samarai pg
# cerrito py
# hermanus za
# severo-kurilsk ru
# mar del plata ar
# hilo us
# butaritari ki
# hobart au
# otradnoye ru
# marabba sd
# yellowknife ca
# ushuaia ar
# attawapiskat ca
# saint-augustin ca
# busselton au
# tuktoyaktuk ca
# bluff nz
# busselton au
# taolanaro mg
# avarua ck
# albany au
# harlingen nl
# kodiak us
# rikitea pf
# saskylakh ru
# ahipara nz
# hobart au
# mahebourg mu
# inhambane mz
# mataura pf
# georgetown sh
# bontang id
# butaritari ki
# new norfolk au
# mahon es
# barentsburg sj
# tasiilaq gl
# sitamau in
# cabo san lucas mx
# rikitea pf
# busselton au
# saint anthony ca
# ushuaia ar
# poum nc
# kuche cn
# klaksvik fo
# iqaluit ca
# khonuu ru
# poum nc
# avarua ck
# labuhan id
# ushuaia ar
# tiksi ru
# kapaa us
# vaini to
# thompson ca
# norman wells ca
# pahrump us
# faya td
# sovetskiy ru
# atuona pf
# busselton au
# severo-yeniseyskiy ru
# douglas us
# mataura pf
# dikson ru
# atuona pf
# lorengau pg
# saskylakh ru
# albany au
# bredasdorp za
# labuan my
# narsaq gl
# taolanaro mg
# faanui pf
# albany au
# taruma br
# hobart au
# mount isa au
# ushuaia ar
# carman ca
# bredasdorp za
# cabo san lucas mx
# arraial do cabo br
# hilo us
# umzimvubu za
# hilo us
# bethel us
# san cristobal ec
# rikitea pf
# rio grande br
# khatanga ru
# tiksi ru
# hilo us
# ushuaia ar
# buchanan lr
# atuona pf
# cidreira br
# sumbawa id
# karratha au
# chokurdakh ru
# tiarei pf
# naberera tz
# talaya ru
# batagay ru
# sambava mg
# cape town za
# new norfolk au
# rikitea pf
# puerto cortes hn
# korla cn
# dongsheng cn
# srednekolymsk ru
# dourbali td
# jabiru au
# punta arenas cl
# victoria ar
# east london za
# vaini to
# hilo us
# mount gambier au
# hilo us
# darovskoy ru
# ushuaia ar
# ajaccio fr
# mahebourg mu
# svetlogorsk ru
# bethel us
# cape town za
# atuona pf
# charlottetown ca
# cap malheureux mu
# contamana pe
# kapaa us
# birobidzhan ru
# rikitea pf
# najran sa
# haines junction ca
# imbituba br
# yeppoon au
# kushiro jp
# hobart au
# alofi nu
# taolanaro mg
# hamilton bm
# amderma ru
# ushuaia ar
# mataura pf
# olafsvik is
# barra do bugres br
# kidal ml
# ushuaia ar
# victoria sc
# ushuaia ar
# punta arenas cl
# busselton au
# palabuhanratu id
# bredasdorp za
# waitati nz
# itarema br
# pavullo nel frignano it
# la ronge ca
# kruisfontein za
# chicama pe
# green valley us
# victoria sc
# mar del plata ar
# cape town za
# punta arenas cl
# valparaiso cl
# aykhal ru
# severo-kurilsk ru
# darnah ly
# bara sd
# puerto ayora ec
# bengkulu id
# udachnyy ru
# busselton au
# khani ru
# meulaboh id
# cape town za
# albany au
# namatanai pg
# abrau-dyurso ru
# geraldton au
# mataura pf
# lavrentiya ru
# hithadhoo mv
# sisian am
# faya td
# hilo us
# hofn is
# provideniya ru
# east london za
# butaritari ki
# barrow us
# bredasdorp za
# hibbing us
# teya ru
# iqaluit ca
# east london za
# new norfolk au
# fallon us
# iqaluit ca
# illoqqortoormiut gl
# yellowknife ca
# belushya guba ru
# busselton au
# mahajanga mg
# hilo us
# grand river south east mu
# killarney ca
# ushuaia ar
# louisbourg ca
# gravelbourg ca
# attawapiskat ca
# albany au
# port alfred za
# barrow us
# vostok ru
# praia da vitoria pt
# punta arenas cl
# kruisfontein za
# kalmunai lk
# san patricio mx
# mataura pf
# matagami ca
# lorengau pg
# yellowknife ca
# tuktoyaktuk ca
# barrow us
# klaksvik fo
# wagar sd
# abu dhabi ae
# tasiilaq gl
# leningradskiy ru
# ouango cf
# chokurdakh ru
# newcastle za
# albany au
# rocha uy
# avarua ck
# ushuaia ar
# provideniya ru
# freeport us
# sao filipe cv
# qaanaaq gl
# rikitea pf
# avarua ck
# cape town za
# yellowknife ca
# jacksonville us
# waddan ly
# cidreira br
# bluff nz
# ferrol es
# ushuaia ar
# ushuaia ar
# yellowknife ca
# saint-fabien ca
# nishihara jp
# port-gentil ga
# whitefish us
# montepuez mz
# rikitea pf
# castro cl
# richards bay za
# korla cn
# alexandria us
# butaritari ki
# auxerre fr
# butaritari ki
# nizhniy tsasuchey ru
# vaini to
# bambous virieux mu
# busselton au
# arlit ne
# kununurra au
# twin falls us
# butaritari ki
# tumannyy ru
# calvia es
# ushuaia ar
# east london za
# constitucion mx
# bluff nz
# atuona pf
# hermanus za
# san policarpo ph
# vaini to
# hobart au
# belushya guba ru
# vaini to
# garden city us
# geraldton au
# sao filipe cv
# airai pw
# saint-pierre pm
# ushuaia ar
# havoysund no
# rikitea pf
# tiznit ma
# andenes no
# butaritari ki
# atuona pf
# hermanus za
# sao filipe cv
# hermanus za
# cape town za
# jever de
# bluff nz
# mataura pf
# lagunillas ve
# sulangan ph
# talnakh ru
# meadow lake ca
# chornobay ua
# punta arenas cl
# klaksvik fo
# kapaa us
# bluff nz
# vardo no
# cherskiy ru
# bethel us
# east london za
# bredasdorp za
# ushuaia ar
# sitka us
# karkaralinsk kz
# cayenne gf
# busselton au
# nizhneyansk ru
# ushuaia ar
# kodiak us
# ushuaia ar
# chuy uy
# bengkulu id
# mto wa mbu tz
# albany au
# albany au
# tsihombe mg
# rikitea pf
# avarua ck
# ponta do sol pt
# hermanus za
# turinsk ru
# heinola fi
# castro cl
# vila franca do campo pt
# atuona pf
# mataura pf
# vaini to
# tuatapere nz
# rikitea pf
# maceio br
# tuktoyaktuk ca
# rio de janeiro br
# vaini to
# camopi gf
# qaanaaq gl
# new norfolk au
# cherskiy ru
# arraial do cabo br
# punta arenas cl
# east london za
# atuona pf
# tuktoyaktuk ca
# jever de
# busselton au
# klaksvik fo
# jamestown sh
# altamont us
# bredasdorp za
# albany au
# namibe ao
# albany au
# lompoc us
# bathsheba bb
# yellowknife ca
# lebu cl
# hilo us
# hamilton bm
# kruisfontein za
# barrow us
# laguna br
# cape town za
# saint simons us
# mataura pf
# atuona pf
# dikson ru
# yellowknife ca
# gummidipundi in
# kamenskoye ru
# punta arenas cl
# murmashi ru
# los llanos de aridane es
# rikitea pf
# hilo us
# litoral del san juan co
# provideniya ru
# qaanaaq gl
# belushya guba ru
# muroto jp
# kloulklubed pw
# bluff nz
# mahebourg mu
# norman wells ca
# taolanaro mg
# punta arenas cl
# nome us
# yerbogachen ru
# busselton au
# faridan ir
# vaini to
# kapaa us
# havelock us
# busselton au
# kapaa us
# mataura pf
# nizwa om
# tandlianwala pk
# lagoa pt
# kapaa us
# kapaa us
# vaini to
# ushuaia ar
# ushuaia ar
# ponta do sol cv
# puerto ayora ec
# san diego de la union mx
# pisco pe
# tasiilaq gl
# mar del plata ar
# winona us
# amapa br
# ushuaia ar
# mezen ru
# port elizabeth za
# puerto ayora ec
# montepuez mz
# tiksi ru
# manta ec
# saint-philippe re
# barentsburg sj
# tuktoyaktuk ca
# mataura pf
# lagoa pt
# dudinka ru
# kapaa us
# qaanaaq gl
# illoqqortoormiut gl
# ilulissat gl
# chokurdakh ru
# busselton au
# ushuaia ar
# ushuaia ar
# hobart au
# punta arenas cl
# athabasca ca
# puerto ayora ec
# butaritari ki
# hithadhoo mv
# rikitea pf
# atuona pf
# mayo ca
# jamestown sh
# ushuaia ar
# butaritari ki
# albany au
# hasaki jp
# piacabucu br
# ancud cl
# lebu cl
# severo-kurilsk ru
# punta arenas cl
# hilo us
# nikolskoye ru
# mar del plata ar
# nuevo imperial pe
# mar del plata ar
# jamestown sh
# flin flon ca
# tsihombe mg
# mount isa au
# taolanaro mg
# kefamenanu id
# ushuaia ar
# ongandjera na
# faya td
# yar-sale ru
# tiksi ru
# launceston au
# vaitupu wf
# nelson bay au
# tasiilaq gl
# torbay ca
# kavieng pg
# mrirt ma
# carnarvon au
# hobart au
# yumen cn
# meulaboh id
# punta arenas cl
# cape town za
# mys shmidta ru
# east london za
# chuy uy
# vaini to
# chokurdakh ru
# kuche cn
# rikitea pf
# laborie lc
# amderma ru
# rikitea pf
# rikitea pf
# hargeysa so
# prince rupert ca
# coquimbo cl
# illoqqortoormiut gl
# santa isabel do rio negro br
# illoqqortoormiut gl
# atuona pf
# senneterre ca
# upernavik gl
# port alfred za
# kingaroy au
# pacific grove us
# bulgan mn
# lagoa pt
# mataura pf
# bredasdorp za
# benjamin aceval py
# rikitea pf
# norman wells ca
# tolaga bay nz
# mount isa au
# rikitea pf
# victoria sc
# bluff nz
# nikolskoye ru
# tuktoyaktuk ca
# san andres co
# tsihombe mg
# hasaki jp
# nanortalik gl
# albany au
# east london za
# srandakan id
# grand river south east mu
# atuona pf
# bethel us
# faanui pf
# asau tv
# los negros bo
# cape town za
# nanortalik gl
# kavaratti in
# san cristobal ec
# clyde river ca
# avarua ck
# hermanus za
# gaeta it
# dikson ru
# saldanha za
# mataura pf
# bluff nz
# lorengau pg
# bell ville ar
# arraial do cabo br
# yellowknife ca
# new norfolk au
# port alfred za
# talnakh ru
# rikitea pf
# flores da cunha br
# cape town za
# aban ru
# renukut in
# east london za
# illoqqortoormiut gl
# saint george bm
# hithadhoo mv
# bubaque gw
# tuktoyaktuk ca
# thompson ca
# carnarvon au
# chokurdakh ru
# belushya guba ru
# nikolskoye ru
# punta arenas cl
# puerto leguizamo co
# saldanha za
# mys shmidta ru
# puerto ayora ec
# rawson ar
# pevek ru
# albany au
# ushuaia ar
# aldan ru
# petropavlovsk-kamchatskiy ru
# bambous virieux mu
# berbera so
# nouadhibou mr
# rocha uy
# sabibah tn
# punta arenas cl
# suoyarvi ru
# kaitangata nz
# rafraf tn
# hilo us
# jamestown sh
# hithadhoo mv
# ushuaia ar
# rikitea pf
# punta arenas cl
# hermanus za
# north bend us
# atuona pf
# miramar mx
# mataura pf
# airai pw
# comodoro rivadavia ar
# qui nhon vn
# rikitea pf
# faanui pf
# korla cn
# mataura pf
# hobart au
# rikitea pf
# lebanon us
# souillac mu
# kapaa us
# hobart au
# hithadhoo mv
# georgetown sh
# caravelas br
# tayga ru
# gazojak tm
# new norfolk au
# constitucion mx
# tasiilaq gl
# mahebourg mu
# kutum sd
# tiksi ru
# papetoai pf
# walvis bay na
# vostok ru
# butaritari ki
# punta arenas cl
# qaanaaq gl
# taolanaro mg
# tiarei pf
# kuryk kz
# busselton au
# cobija bo
# barentsburg sj
# hobart au
# port elizabeth za
# atuona pf
# hoquiam us
# kavieng pg
# upernavik gl
# bolshaya sosnova ru
# tiksi ru
# mancio lima br
# mataura pf
# saleaula ws
# lieksa fi
# castro cl
# taolanaro mg
# acajutla sv
# avarua ck
# shikohabad in
# east london za
# ushuaia ar
# mount gambier au
# tiksi ru
# tuktoyaktuk ca
# copiapo cl
# palabuhanratu id
# ponta do sol cv
# georgetown sh
# da nang vn
# bredasdorp za
# vaini to
# lavrentiya ru
# marcona pe
# bubaque gw
# rikitea pf
# charters towers au
# illoqqortoormiut gl
# avarua ck
# illoqqortoormiut gl
# rikitea pf
# praia da vitoria pt
# punta arenas cl
# saint-leu re
# taolanaro mg
# erzin ru
# plettenberg bay za
# hami cn
# barrow us
# shache cn
# tuktoyaktuk ca
# vaitupu wf
# saint-ambroise ca
# lebu cl
# mocambique mz
# albany au
# nizhneyansk ru
# georgetown sh
# ayan ru
# ucluelet ca
# rikitea pf
# shingu jp
# surt ly
# sao joao da barra br
# carnarvon au
# ushuaia ar
# umzimvubu za
# tungor ru
# cam pha vn
# busselton au
# lardos gr
# coihaique cl
# nargana pa
# esperance au
# georgetown sh
# olot es
# fengrun cn
# dwarka in
# soyo ao
# rikitea pf
# punta arenas cl
# jamestown sh
# ambulu id
# hithadhoo mv
# nenjiang cn
# masuguru tz
# faanui pf
# marcona pe
# arlit ne
# port elizabeth za
# ushuaia ar
# cape town za
# ushuaia ar
# belushya guba ru
# alofi nu
# rikitea pf
# atar mr
# poum nc
# vaini to
# nikolskoye ru
# katsuura jp
# qaanaaq gl
# pokrovka ru
# albany au
# kudahuvadhoo mv
# bengkulu id
# ilulissat gl
# mahebourg mu
# atuona pf
# sao filipe cv
# del rio us
# rio grande br
# ushuaia ar
# combita co
# kruisfontein za
# northam au
# calama cl
# illoqqortoormiut gl
# pevek ru
# punta arenas cl
# qaanaaq gl
# norman wells ca
# dikson ru
# bengkulu id
# mataura pf
# grand river south east mu
# kutum sd
# lugoba tz
# illoqqortoormiut gl
# punta arenas cl
# nanortalik gl
# kununurra au
# souillac mu
# ushuaia ar
# brigantine us
# hermanus za
# hasaki jp
# mount isa au
# upernavik gl
# calabozo ve
# coihaique cl
# jamestown us
# klaksvik fo
# hithadhoo mv
# cape town za
# port elizabeth za
# mataura pf
# lavrentiya ru
# grindavik is
# faanui pf
# pevek ru
# maniitsoq gl
# avarua ck
# qaanaaq gl
# vaini to
# ribeira grande pt
# punta arenas cl
# nicoya cr
# geraldton au
# mitsamiouli km
# longyearbyen sj
# jamestown sh
# saint-augustin ca
# sur om
# faya td
# sumbawa id
# palencia es
# rivne ua
# cape town za
# hermanus za
# puerto ayora ec
# tasiilaq gl
# saint-pierre pm
# hithadhoo mv
# christchurch nz
# shchelyayur ru
# sri aman my
# vaini to
# torbay ca
# carnarvon au
# ushuaia ar
# norman wells ca
# yulara au
# fort nelson ca
# jamestown sh
# sorong id
# mildura au
# ramnagar in
# mataura pf
# hilo us
# mataura pf
# bereda so
# chuy uy
# illoqqortoormiut gl
# vathi gr
# anadyr ru
# ushuaia ar
# carnarvon au
# tamiahua mx
# castro cl
# severo-kurilsk ru
# punta arenas cl
# port hardy ca
# mys shmidta ru
# mataura pf
# salamanca es
# bengkulu id
# busselton au
# mandera ke
# tiksi ru
# kodiak us
# algiers dz
# lebu cl
# torbay ca
# agirish ru
# tasiilaq gl
# carnarvon au
# talaya ru
# luziania br
# rikitea pf
# harper lr
# punta arenas cl
# ambilobe mg
# mrirt ma
# punta arenas cl
# busselton au
# purpe ru
# hambantota lk
# hermanus za
# ushuaia ar
# bredasdorp za
# busselton au
# taolanaro mg
# santa isabel do rio negro br
# arraial do cabo br
# hermanus za
# punta arenas cl
# busselton au
# kyra ru
# albany au
# aras no
# hasaki jp
# grand centre ca
# new norfolk au
# cap malheureux mu
# bredasdorp za
# nikolskoye ru
# hermanus za
# flinders au
# wynyard ca
# porto novo cv
# taguatinga br
# albany au
# kapaa us
# georgetown sh
# busselton au
# busselton au
# hami cn
# bengkulu id
# castro cl
# ushuaia ar
# cherskiy ru
# palmer us
# mataura pf
# butaritari ki
# narsaq gl
# greve strand dk
# klaksvik fo
# znamenskoye ru
# cockburn town bs
# lavrentiya ru
# rikitea pf
# geraldton au
# aljezur pt
# vestmannaeyjar is
# bethel us
# albany au
# chokurdakh ru
# north bend us
# ushuaia ar
# ngukurr au
# juliaca pe
# busselton au
# khatanga ru
# attawapiskat ca
# avarua ck
# namatanai pg
# belushya guba ru
# port lincoln au
# taolanaro mg
# tabou ci
# butaritari ki
# maningrida au
# barrow us
# mataura pf
# joao pinheiro br
# bowen au
# lahaina us
# svendborg dk
# bur gabo so
# san policarpo ph
# punta arenas cl
# busselton au
# nikolskoye ru
# khanpur pk
# rikitea pf
# wageningen sr
# bredasdorp za
# albany au
# lorengau pg
# belyy yar ru
# mataura pf
# walvis bay na
# ulaangom mn
# vaini to
# carnarvon au
# giresun tr
# busselton au
# bredasdorp za
# lompoc us
# nizhneyansk ru
# rabaul pg
# vila velha br
# svetlyy ru
# xiangxiang cn
# carnarvon au
# kidal ml
# itoman jp
# ribeira grande pt
# saint anthony ca
# port lincoln au
# ushuaia ar
# hithadhoo mv
# ushuaia ar
# illoqqortoormiut gl
# ilo pe
# ushuaia ar
# rio grande br
# rikitea pf
# cape town za
# airai pw
# urumqi cn
# acapulco mx
# atuona pf
# puerto ayora ec
# rikitea pf
# avarua ck
# inuvik ca
# albany au
# vaini to
# huilong cn
# natchitoches us
# albany au
# okhotsk ru
# vaitupu wf
# saint-leu re
# tiznit ma
# butaritari ki
# ushuaia ar
# jamestown sh
# samarai pg
# cape town za
# faya td
# namatanai pg
# port alfred za
# illoqqortoormiut gl
# leshukonskoye ru
# esmeraldas ec
# kawalu id
# ushuaia ar
# arauca co
# khatanga ru
# koundara gn
# camacha pt
# atuona pf
# taolanaro mg
# henties bay na
# poum nc
# saint george bm
# port blair in
# chokurdakh ru
# sarakhs ir
# iwanai jp
# puerto ayora ec
# rikitea pf
# victor harbor au
# caravelas br
# meulaboh id
# victoria sc
# busselton au
# hilo us
# rikitea pf
# belushya guba ru
# chumikan ru
# sovetskiy ru
# georgetown sh
# avarua ck
# esperance au
# palmer us
# cayenne gf
# santa maria cv
# port hedland au
# yazman pk
# college us
# albany au
# aksu kz
# severo-kurilsk ru
# jesus del monte mx
# sakaiminato jp
# bredasdorp za
# bambous virieux mu
# carnarvon au
# abiy adi et
# jamestown sh
# rikitea pf
# dese et
# puerto ayora ec
# albany au
# laguna br
# puerto santander co
# tavricheskoye ru
# el prat de llobregat es
# vidim ru
# ushuaia ar
# nikolskoye ru
# dingle ie
# albany au
# arraial do cabo br
# castro cl
# hermanus za
# bluff nz
# hobart au
# lagoa pt
# new norfolk au
# arraial do cabo br
# mataura pf
# hobyo so
# kushmurun kz
# caravelas br
# bredasdorp za
# dicabisagan ph
# georgetown sh
# rikitea pf
# rikitea pf
# butaritari ki
# belushya guba ru
# mayo ca
# noumea nc
# coquimbo cl
# cape town za
# rikitea pf
# port alfred za
# avarua ck
# fairbanks us
# airai pw
# cape town za
# san cristobal ec
# kapaa us
# bluff nz
# dikson ru
# yellowknife ca
# butaritari ki
# punta arenas cl
# bluff nz
# cape town za
# abu kamal sy
# esperance au
# tuktoyaktuk ca
# ushuaia ar
# kodiak us
# hobart au
# taolanaro mg
# severo-kurilsk ru
# new norfolk au
# cape town za
# talnakh ru
# rocha uy
# butaritari ki
# mataura pf
# severo-kurilsk ru
# hilo us
# rikitea pf
# zhangye cn
# mataura pf
# rikitea pf
# marcona pe
# busselton au
# nikolskoye ru
# touros br
# hermanus za
# friedland de
# saint anthony ca
# mahibadhoo mv
# banda aceh id
# kralendijk an
# hilo us
# vila franca do campo pt
# mataura pf
# daoukro ci
# laurel us
# porbandar in
# attawapiskat ca
# nikolskoye ru
# irtyshskiy ru
# almaznyy ru
# chabahar ir
# albany au
# chokurdakh ru
# chivilcoy ar
# moorhead us
# le port re
# jamestown sh
# kapaa us
# saint-philippe re
# kralendijk an
# punta arenas cl
# meulaboh id
# tsihombe mg
# nybro se
# ambulu id
# lagoa pt
# mataura pf
# quelimane mz
# castro cl
# hobart au
# port alfred za
# ternate id
# mys shmidta ru
# nikolskoye ru
# bluff nz
# vila franca do campo pt
# bamiantong cn
# vestmannaeyjar is
# east london za
# ilulissat gl
# halalo wf
# busselton au
# honiara sb
# bredasdorp za
# lompoc us
# albany au
# rikitea pf
# belushya guba ru
# hermanus za
# longyearbyen sj
# hilo us
# esperance au
# coihaique cl
# avarua ck
# rikitea pf
# balkhash kz
# cabo san lucas mx
# punta arenas cl
# caluquembe ao
# rikitea pf
# yellowknife ca
# pacifica us
# mehamn no
# new norfolk au
# bolungarvik is
# severo-yeniseyskiy ru
# dikson ru
# conakry gn
# butaritari ki
# busselton au
# luangwa zm
# cape town za
# saint george bm
# salalah om
# provideniya ru
# mataura pf
# tuktoyaktuk ca
# agogo gh
# sovetsk ru
# hithadhoo mv
# port alfred za
# amderma ru
# rikitea pf
# ushuaia ar
# rehoboth na
# umm bab qa
# fuyu cn
# kapaa us
# rikitea pf
# srednekolymsk ru
# rikitea pf
# kapaa us
# vaini to
# longyearbyen sj
# avera pf
# jamestown sh
# bambous virieux mu
# jamestown sh
# biak id
# sao gabriel da cachoeira br
# bethel us
# busselton au
# butaritari ki
# arraial do cabo br
# constitucion mx
# port hardy ca
# kuala terengganu my
# khonuu ru
# hithadhoo mv
# kruisfontein za
# srednekolymsk ru
# ponta do sol cv
# barentsburg sj
# ushuaia ar
# tuy hoa vn
# rikitea pf
# palana ru
# mar del plata ar
# ushuaia ar
# georgetown sh
# mwinilunga zm
# port macquarie au
# todos santos mx
# albany au
# srednekolymsk ru
# hobart au
# stephenville ca
# adrar dz
# fort wellington gy
# george za
# qorveh ir
# hermanus za
# longyearbyen sj
# alofi nu
# necochea ar
# yellowknife ca
# sao filipe cv
# aksay kz
# attawapiskat ca
# vaini to
# kodiak us
# saint-philippe re
# tiksi ru
# hithadhoo mv
# albany au
# mataura pf
# puerto ayora ec
# busselton au
# yellowknife ca
# upernavik gl
# nabire id
# maloshuyka ru
# hobart au
# oussouye sn
# singkang id
# stepnogorsk kz
# albany au
# vaini to
# basco ph
# chumikan ru
# san quintin mx
# victoria sc
# chapais ca
# kenai us
# port elizabeth za
# qaanaaq gl
# mandera ke
# maniitsoq gl
# beloha mg
# sorland no
# punta arenas cl
# barcelos br
# panlaitan ph
# new norfolk au
# jamestown sh
# qaanaaq gl
# east london za
# roald no
# bredasdorp za
# taolanaro mg
# mwense zm
# tahe cn
# rikitea pf
# belushya guba ru
# chuy uy
# faya td
# port lincoln au
# port elizabeth za
# shumskiy ru
# rikitea pf
# avera pf
# hofn is
# attawapiskat ca
# maputo mz
# cape town za
# yanan cn
# busselton au
# kaitangata nz
# georgetown sh
# ancud cl
# mataura pf
# punta arenas cl
# kutum sd
# dunedin nz
# kapaa us
# safford us
# cibitoke bi
# san patricio mx
# albany au
# ridgecrest us
# olive branch us
# rikitea pf
# qaanaaq gl
# bredasdorp za
# vaini to
# provideniya ru
# puerto ayora ec
# barrow us
# ketchikan us
# port elizabeth za
# namibe ao
# barrow us
# flinders au
# vaini to
# ponta do sol pt
# vagay ru
# calvinia za
# vao nc
# maniitsoq gl
# hilo us
# eenhana na
# punta arenas cl
# tasiilaq gl
# khatanga ru
# ilulissat gl
# altay cn
# surt ly
# luangwa zm
# isangel vu
# ushuaia ar
# mataura pf
# ribeira grande pt
# ushuaia ar
# hamilton bm
# ngukurr au
# port alfred za
# rikitea pf
# cleburne us
# dubenskiy ru
# rikitea pf
# cape town za
# saint george bm
# morros br
# sisimiut gl
# mount isa au
# geraldton au
# punta arenas cl
# yellowknife ca
# qaanaaq gl
# mys shmidta ru
# kapaa us
# lorengau pg
# ribeira grande pt
# sitka us
# ushuaia ar
# puerto ayora ec
# tasiilaq gl
# vaitupu wf
# busselton au
# vershino-shakhtaminskiy ru
# bengkulu id
# ushuaia ar
# airai pw
# flinders au
# barrow us
# ugoofaaru mv
# hermanus za
# puerto ayora ec
# busselton au
# japura br
# bara sd
# la ronge ca
# san jose bo
# olafsvik is
# estrella ph
# rikitea pf
# isangel vu
# marcona pe
# bandarbeyla so
# jamestown sh
# port-gentil ga
# mataura pf
# busselton au
# kapaa us
# palana ru
# asilah ma
# sentyabrskiy ru
# chakradharpur in
# georgetown sh
# isangel vu
# kupang id
# scottsbluff us
# esperance au
# bredasdorp za
# khorramabad ir
# lapua fi
# rocha uy
# taolanaro mg
# bengkulu id
# fos-sur-mer fr
# hobyo so
# mataura pf
# miles city us
# torbay ca
# tuktoyaktuk ca
# bethel us
# ust-nera ru
# dikson ru
# nuuk gl
# rikitea pf
# albany au
# tucurui br
# codrington ag
# rikitea pf
# bluff nz
# saldanha za
# yantai cn
# dingli mt
# cape town za
# yulara au
# torbay ca
# yulara au
# altar mx
# naze jp
# vaini to
# borovichi ru
# qaanaaq gl
# murray bridge au
# mataura pf
# victoria cl
# new norfolk au
# broome au
# rikitea pf
# yellowknife ca
# visavadar in
# whitehorse ca
# mataura pf
# rikitea pf
# bandarbeyla so

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 577

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2a9169035ea6eb8c1b16a9de7e444748

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2a9169035ea6eb8c1b16a9de7e444748&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# call the response code with the get() method using the status_code
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}],"base":"stations","main":{"temp":69.87,"feels_like":69.71,"temp_min":58.96,"temp_max":79.56,"pressure":1014,"humidity":67},"visibility":10000,"wind":{"speed":5.01,"deg":165,"gust":11.99},"clouds":{"all":34},"dt":1653070413,"sys":{"type":2,"id":2001997,"country":"US","sunrise":1653038295,"sunset":1653091414},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 69.87,
#   'feels_like': 69.71,
#   'temp_min': 58.96,
#   'temp_max': 79.56,
#   'pressure': 1014,
#   'humidity': 67},
#  'visibility': 10000,
#  'wind': {'speed': 5.01, 'deg': 165, 'gust': 11.99},
#  'clouds': {'all': 34},
#  'dt': 1653070413,
#  'sys': {'type': 2,
#   'id': 2001997,
#   'country': 'US',
#   'sunrise': 1653038295,
#   'sunset': 1653091414},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Import the dependencies.
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

# %%
# Personal Practice
# new_city="Nairobi"

# %%
# Create an endpoint URL for a city.
# city_url = url + "&q=" + "Nairobi"
# city_weather = requests.get(city_url)
# city_weather

# %%
# Get the JSON text of the 'Get' request.
# city_weather.json()

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
 print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2a9169035ea6eb8c1b16a9de7e444748&q=Bston

# %%
# For each city in our lats_lngs list, we need to retrieve the following data and add it to a DataFrame:

# City, country, and date

# Latitude and longitude

# Maximum temperature

# Humidity

# Cloudiness

# Wind speed

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

city_weather = requests.get(city_url)

city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 69.87,
#   'feels_like': 69.71,
#   'temp_min': 58.96,
#   'temp_max': 79.56,
#   'pressure': 1014,
#   'humidity': 67},
#  'visibility': 10000,
#  'wind': {'speed': 5.01, 'deg': 165, 'gust': 11.99},
#  'clouds': {'all': 34},
#  'dt': 1653070413,
#  'sys': {'type': 2,
#   'id': 2001997,
#   'country': 'US',
#   'sunrise': 1653038295,
#   'sunset': 1653091414},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']["country"]
# Out:
# 'US'

# %%
boston_data['coord']['lat']
# Out:
# 42.3584

# %%
lat = boston_data["coord"]["lat"]

lng = boston_data["coord"]["lon"]

max_temp = boston_data["main"]["temp_max"]

humidity = boston_data["main"]["humidity"]

clouds = boston_data["clouds"]["all"]

wind = boston_data["wind"]["speed"]

print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 79.56 67 34 5.01

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Get the date from the JSON file.
date = boston_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 5, 20, 18, 13, 33)

# %%
# We can convert this datetime format to 2019-10-21 17:24:35 using the Python string format method strftime()
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-05-20 18:13:33'

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")

print("-----------------------------")

# Create counters.
record_count = 1

set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        record_count = 1
        
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 12 | nikolskoye
# Processing Record 2 of Set 12 | kaya
# Processing Record 3 of Set 12 | dikson
# Processing Record 4 of Set 12 | samarai
# Processing Record 5 of Set 12 | cerrito
# Processing Record 6 of Set 12 | hermanus
# Processing Record 7 of Set 12 | severo-kurilsk
# Processing Record 8 of Set 12 | mar del plata
# Processing Record 9 of Set 12 | hilo
# Processing Record 10 of Set 12 | butaritari
# Processing Record 11 of Set 12 | hobart
# Processing Record 12 of Set 12 | otradnoye
# Processing Record 13 of Set 12 | marabba
# Processing Record 14 of Set 12 | yellowknife
# Processing Record 15 of Set 12 | ushuaia
# Processing Record 16 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 12 | saint-augustin
# Processing Record 18 of Set 12 | busselton
# Processing Record 19 of Set 12 | tuktoyaktuk
# Processing Record 20 of Set 12 | bluff
# Processing Record 21 of Set 12 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 12 | avarua
# Processing Record 23 of Set 12 | albany
# Processing Record 24 of Set 12 | harlingen
# Processing Record 25 of Set 12 | kodiak
# Processing Record 26 of Set 12 | rikitea
# Processing Record 27 of Set 12 | saskylakh
# Processing Record 28 of Set 12 | ahipara
# Processing Record 29 of Set 12 | mahebourg
# Processing Record 30 of Set 12 | inhambane
# Processing Record 31 of Set 12 | mataura
# Processing Record 32 of Set 12 | georgetown
# Processing Record 33 of Set 12 | bontang
# Processing Record 34 of Set 12 | new norfolk
# Processing Record 35 of Set 12 | mahon
# Processing Record 36 of Set 12 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 12 | tasiilaq
# Processing Record 38 of Set 12 | sitamau
# Processing Record 39 of Set 12 | cabo san lucas
# Processing Record 40 of Set 12 | saint anthony
# Processing Record 41 of Set 12 | poum
# Processing Record 42 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 12 | klaksvik
# Processing Record 44 of Set 12 | iqaluit
# Processing Record 45 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 12 | labuhan
# Processing Record 47 of Set 12 | tiksi
# Processing Record 48 of Set 12 | kapaa
# Processing Record 49 of Set 12 | vaini
# Processing Record 50 of Set 12 | thompson
# Processing Record 1 of Set 13 | norman wells
# Processing Record 2 of Set 13 | pahrump
# Processing Record 3 of Set 13 | faya
# Processing Record 4 of Set 13 | sovetskiy
# Processing Record 5 of Set 13 | atuona
# Processing Record 6 of Set 13 | severo-yeniseyskiy
# Processing Record 7 of Set 13 | douglas
# Processing Record 8 of Set 13 | lorengau
# Processing Record 9 of Set 13 | bredasdorp
# Processing Record 10 of Set 13 | labuan
# Processing Record 11 of Set 13 | narsaq
# Processing Record 12 of Set 13 | faanui
# Processing Record 13 of Set 13 | taruma
# Processing Record 14 of Set 13 | mount isa
# Processing Record 15 of Set 13 | carman
# Processing Record 16 of Set 13 | arraial do cabo
# Processing Record 17 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 13 | bethel
# Processing Record 19 of Set 13 | san cristobal
# Processing Record 20 of Set 13 | rio grande
# Processing Record 21 of Set 13 | khatanga
# Processing Record 22 of Set 13 | buchanan
# Processing Record 23 of Set 13 | cidreira
# Processing Record 24 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 25 of Set 13 | karratha
# Processing Record 26 of Set 13 | chokurdakh
# Processing Record 27 of Set 13 | tiarei
# Processing Record 28 of Set 13 | naberera
# Processing Record 29 of Set 13 | talaya
# Processing Record 30 of Set 13 | batagay
# Processing Record 31 of Set 13 | sambava
# Processing Record 32 of Set 13 | cape town
# Processing Record 33 of Set 13 | puerto cortes
# City not found. Skipping...
# Processing Record 34 of Set 13 | korla
# Processing Record 35 of Set 13 | dongsheng
# Processing Record 36 of Set 13 | srednekolymsk
# Processing Record 37 of Set 13 | dourbali
# Processing Record 38 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 39 of Set 13 | punta arenas
# Processing Record 40 of Set 13 | victoria
# Processing Record 41 of Set 13 | east london
# Processing Record 42 of Set 13 | mount gambier
# Processing Record 43 of Set 13 | darovskoy
# Processing Record 44 of Set 13 | ajaccio
# Processing Record 45 of Set 13 | svetlogorsk
# Processing Record 46 of Set 13 | charlottetown
# Processing Record 47 of Set 13 | cap malheureux
# Processing Record 48 of Set 13 | contamana
# Processing Record 49 of Set 13 | birobidzhan
# Processing Record 50 of Set 13 | najran
# Processing Record 1 of Set 14 | haines junction
# Processing Record 2 of Set 14 | imbituba
# Processing Record 3 of Set 14 | yeppoon
# Processing Record 4 of Set 14 | kushiro
# Processing Record 5 of Set 14 | alofi
# Processing Record 6 of Set 14 | hamilton
# Processing Record 7 of Set 14 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 14 | olafsvik
# Processing Record 9 of Set 14 | barra do bugres
# Processing Record 10 of Set 14 | kidal
# Processing Record 11 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 14 | waitati
# Processing Record 13 of Set 14 | itarema
# Processing Record 14 of Set 14 | pavullo nel frignano
# Processing Record 15 of Set 14 | la ronge
# Processing Record 16 of Set 14 | kruisfontein
# Processing Record 17 of Set 14 | chicama
# Processing Record 18 of Set 14 | green valley
# Processing Record 19 of Set 14 | valparaiso
# Processing Record 20 of Set 14 | aykhal
# Processing Record 21 of Set 14 | darnah
# Processing Record 22 of Set 14 | bara
# Processing Record 23 of Set 14 | puerto ayora
# Processing Record 24 of Set 14 | bengkulu
# Processing Record 25 of Set 14 | udachnyy
# Processing Record 26 of Set 14 | khani
# Processing Record 27 of Set 14 | meulaboh
# Processing Record 28 of Set 14 | namatanai
# Processing Record 29 of Set 14 | abrau-dyurso
# Processing Record 30 of Set 14 | geraldton
# Processing Record 31 of Set 14 | lavrentiya
# Processing Record 32 of Set 14 | hithadhoo
# Processing Record 33 of Set 14 | sisian
# Processing Record 34 of Set 14 | hofn
# Processing Record 35 of Set 14 | provideniya
# Processing Record 36 of Set 14 | barrow
# Processing Record 37 of Set 14 | hibbing
# Processing Record 38 of Set 14 | teya
# Processing Record 39 of Set 14 | fallon
# Processing Record 40 of Set 14 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 14 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 14 | mahajanga
# Processing Record 43 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 14 | killarney
# Processing Record 45 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 14 | gravelbourg
# Processing Record 47 of Set 14 | port alfred
# Processing Record 48 of Set 14 | vostok
# Processing Record 49 of Set 14 | praia da vitoria
# Processing Record 50 of Set 14 | kalmunai
# Processing Record 1 of Set 15 | san patricio
# Processing Record 2 of Set 15 | matagami
# Processing Record 3 of Set 15 | wagar
# Processing Record 4 of Set 15 | abu dhabi
# Processing Record 5 of Set 15 | leningradskiy
# Processing Record 6 of Set 15 | ouango
# Processing Record 7 of Set 15 | newcastle
# Processing Record 8 of Set 15 | rocha
# Processing Record 9 of Set 15 | freeport
# Processing Record 10 of Set 15 | sao filipe
# Processing Record 11 of Set 15 | qaanaaq
# Processing Record 12 of Set 15 | jacksonville
# Processing Record 13 of Set 15 | waddan
# Processing Record 14 of Set 15 | ferrol
# Processing Record 15 of Set 15 | saint-fabien
# City not found. Skipping...
# Processing Record 16 of Set 15 | nishihara
# Processing Record 17 of Set 15 | port-gentil
# Processing Record 18 of Set 15 | whitefish
# Processing Record 19 of Set 15 | montepuez
# Processing Record 20 of Set 15 | castro
# Processing Record 21 of Set 15 | richards bay
# Processing Record 22 of Set 15 | alexandria
# Processing Record 23 of Set 15 | auxerre
# Processing Record 24 of Set 15 | nizhniy tsasuchey
# Processing Record 25 of Set 15 | bambous virieux
# Processing Record 26 of Set 15 | arlit
# Processing Record 27 of Set 15 | kununurra
# Processing Record 28 of Set 15 | twin falls
# Processing Record 29 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 15 | calvia
# Processing Record 31 of Set 15 | constitucion
# Processing Record 32 of Set 15 | san policarpo
# Processing Record 33 of Set 15 | garden city
# Processing Record 34 of Set 15 | airai
# Processing Record 35 of Set 15 | saint-pierre
# Processing Record 36 of Set 15 | havoysund
# Processing Record 37 of Set 15 | tiznit
# Processing Record 38 of Set 15 | andenes
# Processing Record 39 of Set 15 | jever
# Processing Record 40 of Set 15 | lagunillas
# Processing Record 41 of Set 15 | sulangan
# Processing Record 42 of Set 15 | talnakh
# Processing Record 43 of Set 15 | meadow lake
# Processing Record 44 of Set 15 | chornobay
# Processing Record 45 of Set 15 | vardo
# Processing Record 46 of Set 15 | cherskiy
# Processing Record 47 of Set 15 | sitka
# Processing Record 48 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 15 | cayenne
# Processing Record 50 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 16 | chuy
# Processing Record 2 of Set 16 | mto wa mbu
# Processing Record 3 of Set 16 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 16 | ponta do sol
# Processing Record 5 of Set 16 | turinsk
# Processing Record 6 of Set 16 | heinola
# Processing Record 7 of Set 16 | vila franca do campo
# Processing Record 8 of Set 16 | tuatapere
# Processing Record 9 of Set 16 | maceio
# Processing Record 10 of Set 16 | rio de janeiro
# Processing Record 11 of Set 16 | camopi
# Processing Record 12 of Set 16 | jamestown
# Processing Record 13 of Set 16 | altamont
# Processing Record 14 of Set 16 | namibe
# Processing Record 15 of Set 16 | lompoc
# Processing Record 16 of Set 16 | bathsheba
# Processing Record 17 of Set 16 | lebu
# Processing Record 18 of Set 16 | laguna
# Processing Record 19 of Set 16 | saint simons
# Processing Record 20 of Set 16 | gummidipundi
# Processing Record 21 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 16 | murmashi
# Processing Record 23 of Set 16 | los llanos de aridane
# Processing Record 24 of Set 16 | litoral del san juan
# City not found. Skipping...
# Processing Record 25 of Set 16 | muroto
# Processing Record 26 of Set 16 | kloulklubed
# Processing Record 27 of Set 16 | nome
# Processing Record 28 of Set 16 | yerbogachen
# Processing Record 29 of Set 16 | faridan
# City not found. Skipping...
# Processing Record 30 of Set 16 | havelock
# Processing Record 31 of Set 16 | nizwa
# Processing Record 32 of Set 16 | tandlianwala
# Processing Record 33 of Set 16 | lagoa
# Processing Record 34 of Set 16 | san diego de la union
# Processing Record 35 of Set 16 | pisco
# Processing Record 36 of Set 16 | winona
# Processing Record 37 of Set 16 | amapa
# Processing Record 38 of Set 16 | mezen
# Processing Record 39 of Set 16 | port elizabeth
# Processing Record 40 of Set 16 | manta
# Processing Record 41 of Set 16 | saint-philippe
# Processing Record 42 of Set 16 | dudinka
# Processing Record 43 of Set 16 | ilulissat
# Processing Record 44 of Set 16 | athabasca
# Processing Record 45 of Set 16 | mayo
# Processing Record 46 of Set 16 | hasaki
# Processing Record 47 of Set 16 | piacabucu
# Processing Record 48 of Set 16 | ancud
# Processing Record 49 of Set 16 | nuevo imperial
# Processing Record 50 of Set 16 | flin flon
# Processing Record 1 of Set 17 | kefamenanu
# Processing Record 2 of Set 17 | ongandjera
# Processing Record 3 of Set 17 | yar-sale
# Processing Record 4 of Set 17 | launceston
# Processing Record 5 of Set 17 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 17 | nelson bay
# Processing Record 7 of Set 17 | torbay
# Processing Record 8 of Set 17 | kavieng
# Processing Record 9 of Set 17 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 17 | carnarvon
# Processing Record 11 of Set 17 | yumen
# Processing Record 12 of Set 17 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 17 | laborie
# Processing Record 14 of Set 17 | hargeysa
# Processing Record 15 of Set 17 | prince rupert
# Processing Record 16 of Set 17 | coquimbo
# Processing Record 17 of Set 17 | santa isabel do rio negro
# Processing Record 18 of Set 17 | senneterre
# Processing Record 19 of Set 17 | upernavik
# Processing Record 20 of Set 17 | kingaroy
# Processing Record 21 of Set 17 | pacific grove
# Processing Record 22 of Set 17 | bulgan
# Processing Record 23 of Set 17 | benjamin aceval
# Processing Record 24 of Set 17 | tolaga bay
# Processing Record 25 of Set 17 | san andres
# Processing Record 26 of Set 17 | nanortalik
# Processing Record 27 of Set 17 | srandakan
# Processing Record 28 of Set 17 | asau
# Processing Record 29 of Set 17 | los negros
# Processing Record 30 of Set 17 | kavaratti
# Processing Record 31 of Set 17 | clyde river
# Processing Record 32 of Set 17 | gaeta
# Processing Record 33 of Set 17 | saldanha
# Processing Record 34 of Set 17 | bell ville
# Processing Record 35 of Set 17 | flores da cunha
# Processing Record 36 of Set 17 | aban
# Processing Record 37 of Set 17 | renukut
# Processing Record 38 of Set 17 | saint george
# Processing Record 39 of Set 17 | bubaque
# Processing Record 40 of Set 17 | puerto leguizamo
# Processing Record 41 of Set 17 | rawson
# Processing Record 42 of Set 17 | pevek
# Processing Record 43 of Set 17 | aldan
# Processing Record 44 of Set 17 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 17 | berbera
# Processing Record 46 of Set 17 | nouadhibou
# Processing Record 47 of Set 17 | sabibah
# City not found. Skipping...
# Processing Record 48 of Set 17 | suoyarvi
# Processing Record 49 of Set 17 | kaitangata
# Processing Record 50 of Set 17 | rafraf
# Processing Record 1 of Set 18 | north bend
# Processing Record 2 of Set 18 | miramar
# Processing Record 3 of Set 18 | comodoro rivadavia
# Processing Record 4 of Set 18 | qui nhon
# Processing Record 5 of Set 18 | lebanon
# Processing Record 6 of Set 18 | souillac
# Processing Record 7 of Set 18 | caravelas
# Processing Record 8 of Set 18 | tayga
# Processing Record 9 of Set 18 | gazojak
# Processing Record 10 of Set 18 | kutum
# Processing Record 11 of Set 18 | papetoai
# Processing Record 12 of Set 18 | walvis bay
# Processing Record 13 of Set 18 | kuryk
# Processing Record 14 of Set 18 | cobija
# Processing Record 15 of Set 18 | hoquiam
# Processing Record 16 of Set 18 | bolshaya sosnova
# Processing Record 17 of Set 18 | mancio lima
# Processing Record 18 of Set 18 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 18 | lieksa
# Processing Record 20 of Set 18 | acajutla
# Processing Record 21 of Set 18 | shikohabad
# Processing Record 22 of Set 18 | copiapo
# Processing Record 23 of Set 18 | da nang
# Processing Record 24 of Set 18 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 18 | charters towers
# Processing Record 26 of Set 18 | saint-leu
# Processing Record 27 of Set 18 | erzin
# Processing Record 28 of Set 18 | plettenberg bay
# Processing Record 29 of Set 18 | hami
# Processing Record 30 of Set 18 | shache
# Processing Record 31 of Set 18 | saint-ambroise
# Processing Record 32 of Set 18 | mocambique
# City not found. Skipping...
# Processing Record 33 of Set 18 | ayan
# Processing Record 34 of Set 18 | ucluelet
# Processing Record 35 of Set 18 | shingu
# Processing Record 36 of Set 18 | surt
# Processing Record 37 of Set 18 | sao joao da barra
# Processing Record 38 of Set 18 | tungor
# Processing Record 39 of Set 18 | cam pha
# City not found. Skipping...
# Processing Record 40 of Set 18 | lardos
# Processing Record 41 of Set 18 | coihaique
# Processing Record 42 of Set 18 | nargana
# Processing Record 43 of Set 18 | esperance
# Processing Record 44 of Set 18 | olot
# Processing Record 45 of Set 18 | fengrun
# Processing Record 46 of Set 18 | dwarka
# Processing Record 47 of Set 18 | soyo
# Processing Record 48 of Set 18 | ambulu
# Processing Record 49 of Set 18 | nenjiang
# Processing Record 50 of Set 18 | masuguru
# Processing Record 1 of Set 19 | atar
# Processing Record 2 of Set 19 | katsuura
# Processing Record 3 of Set 19 | pokrovka
# Processing Record 4 of Set 19 | kudahuvadhoo
# Processing Record 5 of Set 19 | del rio
# Processing Record 6 of Set 19 | combita
# Processing Record 7 of Set 19 | northam
# Processing Record 8 of Set 19 | calama
# Processing Record 9 of Set 19 | lugoba
# Processing Record 10 of Set 19 | brigantine
# Processing Record 11 of Set 19 | calabozo
# Processing Record 12 of Set 19 | grindavik
# Processing Record 13 of Set 19 | maniitsoq
# Processing Record 14 of Set 19 | ribeira grande
# Processing Record 15 of Set 19 | nicoya
# Processing Record 16 of Set 19 | mitsamiouli
# Processing Record 17 of Set 19 | longyearbyen
# Processing Record 18 of Set 19 | sur
# Processing Record 19 of Set 19 | palencia
# Processing Record 20 of Set 19 | rivne
# Processing Record 21 of Set 19 | christchurch
# Processing Record 22 of Set 19 | shchelyayur
# City not found. Skipping...
# Processing Record 23 of Set 19 | sri aman
# Processing Record 24 of Set 19 | yulara
# Processing Record 25 of Set 19 | fort nelson
# Processing Record 26 of Set 19 | sorong
# Processing Record 27 of Set 19 | mildura
# Processing Record 28 of Set 19 | ramnagar
# Processing Record 29 of Set 19 | bereda
# Processing Record 30 of Set 19 | vathi
# Processing Record 31 of Set 19 | anadyr
# Processing Record 32 of Set 19 | tamiahua
# Processing Record 33 of Set 19 | port hardy
# Processing Record 34 of Set 19 | salamanca
# Processing Record 35 of Set 19 | mandera
# Processing Record 36 of Set 19 | algiers
# Processing Record 37 of Set 19 | agirish
# Processing Record 38 of Set 19 | luziania
# Processing Record 39 of Set 19 | harper
# Processing Record 40 of Set 19 | ambilobe
# Processing Record 41 of Set 19 | purpe
# Processing Record 42 of Set 19 | hambantota
# Processing Record 43 of Set 19 | kyra
# Processing Record 44 of Set 19 | aras
# Processing Record 45 of Set 19 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 19 | flinders
# Processing Record 47 of Set 19 | wynyard
# Processing Record 48 of Set 19 | porto novo
# Processing Record 49 of Set 19 | taguatinga
# Processing Record 50 of Set 19 | palmer
# Processing Record 1 of Set 20 | greve strand
# Processing Record 2 of Set 20 | znamenskoye
# Processing Record 3 of Set 20 | cockburn town
# Processing Record 4 of Set 20 | aljezur
# Processing Record 5 of Set 20 | vestmannaeyjar
# Processing Record 6 of Set 20 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 20 | juliaca
# Processing Record 8 of Set 20 | port lincoln
# Processing Record 9 of Set 20 | tabou
# Processing Record 10 of Set 20 | maningrida
# Processing Record 11 of Set 20 | joao pinheiro
# Processing Record 12 of Set 20 | bowen
# Processing Record 13 of Set 20 | lahaina
# Processing Record 14 of Set 20 | svendborg
# Processing Record 15 of Set 20 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 20 | khanpur
# Processing Record 17 of Set 20 | wageningen
# Processing Record 18 of Set 20 | belyy yar
# Processing Record 19 of Set 20 | ulaangom
# Processing Record 20 of Set 20 | giresun
# Processing Record 21 of Set 20 | rabaul
# Processing Record 22 of Set 20 | vila velha
# Processing Record 23 of Set 20 | svetlyy
# Processing Record 24 of Set 20 | xiangxiang
# Processing Record 25 of Set 20 | itoman
# Processing Record 26 of Set 20 | ilo
# Processing Record 27 of Set 20 | urumqi
# Processing Record 28 of Set 20 | acapulco
# Processing Record 29 of Set 20 | inuvik
# Processing Record 30 of Set 20 | huilong
# Processing Record 31 of Set 20 | natchitoches
# Processing Record 32 of Set 20 | okhotsk
# Processing Record 33 of Set 20 | leshukonskoye
# Processing Record 34 of Set 20 | esmeraldas
# Processing Record 35 of Set 20 | kawalu
# Processing Record 36 of Set 20 | arauca
# Processing Record 37 of Set 20 | koundara
# Processing Record 38 of Set 20 | camacha
# Processing Record 39 of Set 20 | henties bay
# Processing Record 40 of Set 20 | port blair
# Processing Record 41 of Set 20 | sarakhs
# Processing Record 42 of Set 20 | iwanai
# Processing Record 43 of Set 20 | victor harbor
# Processing Record 44 of Set 20 | chumikan
# Processing Record 45 of Set 20 | santa maria
# Processing Record 46 of Set 20 | port hedland
# Processing Record 47 of Set 20 | yazman
# Processing Record 48 of Set 20 | college
# Processing Record 49 of Set 20 | aksu
# Processing Record 50 of Set 20 | jesus del monte
# Processing Record 1 of Set 21 | sakaiminato
# Processing Record 2 of Set 21 | abiy adi
# City not found. Skipping...
# Processing Record 3 of Set 21 | dese
# Processing Record 4 of Set 21 | puerto santander
# Processing Record 5 of Set 21 | tavricheskoye
# Processing Record 6 of Set 21 | el prat de llobregat
# Processing Record 7 of Set 21 | vidim
# Processing Record 8 of Set 21 | dingle
# Processing Record 9 of Set 21 | hobyo
# Processing Record 10 of Set 21 | kushmurun
# Processing Record 11 of Set 21 | dicabisagan
# Processing Record 12 of Set 21 | noumea
# Processing Record 13 of Set 21 | fairbanks
# Processing Record 14 of Set 21 | abu kamal
# Processing Record 15 of Set 21 | zhangye
# Processing Record 16 of Set 21 | touros
# Processing Record 17 of Set 21 | friedland
# Processing Record 18 of Set 21 | mahibadhoo
# Processing Record 19 of Set 21 | banda aceh
# Processing Record 20 of Set 21 | kralendijk
# Processing Record 21 of Set 21 | daoukro
# Processing Record 22 of Set 21 | laurel
# Processing Record 23 of Set 21 | porbandar
# Processing Record 24 of Set 21 | irtyshskiy
# Processing Record 25 of Set 21 | almaznyy
# Processing Record 26 of Set 21 | chabahar
# Processing Record 27 of Set 21 | chivilcoy
# Processing Record 28 of Set 21 | moorhead
# Processing Record 29 of Set 21 | le port
# Processing Record 30 of Set 21 | nybro
# Processing Record 31 of Set 21 | quelimane
# Processing Record 32 of Set 21 | ternate
# Processing Record 33 of Set 21 | bamiantong
# Processing Record 34 of Set 21 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 21 | honiara
# Processing Record 36 of Set 21 | balkhash
# Processing Record 37 of Set 21 | caluquembe
# Processing Record 38 of Set 21 | pacifica
# Processing Record 39 of Set 21 | mehamn
# Processing Record 40 of Set 21 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 21 | conakry
# Processing Record 42 of Set 21 | luangwa
# Processing Record 43 of Set 21 | salalah
# Processing Record 44 of Set 21 | agogo
# Processing Record 45 of Set 21 | sovetsk
# Processing Record 46 of Set 21 | rehoboth
# Processing Record 47 of Set 21 | umm bab
# Processing Record 48 of Set 21 | fuyu
# Processing Record 49 of Set 21 | avera
# Processing Record 50 of Set 21 | biak
# Processing Record 1 of Set 22 | sao gabriel da cachoeira
# Processing Record 2 of Set 22 | kuala terengganu
# Processing Record 3 of Set 22 | tuy hoa
# Processing Record 4 of Set 22 | palana
# Processing Record 5 of Set 22 | mwinilunga
# Processing Record 6 of Set 22 | port macquarie
# Processing Record 7 of Set 22 | todos santos
# Processing Record 8 of Set 22 | stephenville
# Processing Record 9 of Set 22 | adrar
# Processing Record 10 of Set 22 | fort wellington
# Processing Record 11 of Set 22 | george
# Processing Record 12 of Set 22 | qorveh
# Processing Record 13 of Set 22 | necochea
# Processing Record 14 of Set 22 | aksay
# Processing Record 15 of Set 22 | nabire
# Processing Record 16 of Set 22 | maloshuyka
# City not found. Skipping...
# Processing Record 17 of Set 22 | oussouye
# Processing Record 18 of Set 22 | singkang
# Processing Record 19 of Set 22 | stepnogorsk
# Processing Record 20 of Set 22 | basco
# Processing Record 21 of Set 22 | san quintin
# Processing Record 22 of Set 22 | chapais
# Processing Record 23 of Set 22 | kenai
# Processing Record 24 of Set 22 | beloha
# Processing Record 25 of Set 22 | sorland
# Processing Record 26 of Set 22 | barcelos
# Processing Record 27 of Set 22 | panlaitan
# Processing Record 28 of Set 22 | roald
# Processing Record 29 of Set 22 | mwense
# Processing Record 30 of Set 22 | tahe
# Processing Record 31 of Set 22 | shumskiy
# Processing Record 32 of Set 22 | maputo
# Processing Record 33 of Set 22 | yanan
# City not found. Skipping...
# Processing Record 34 of Set 22 | dunedin
# Processing Record 35 of Set 22 | safford
# Processing Record 36 of Set 22 | cibitoke
# Processing Record 37 of Set 22 | ridgecrest
# Processing Record 38 of Set 22 | olive branch
# Processing Record 39 of Set 22 | ketchikan
# Processing Record 40 of Set 22 | vagay
# Processing Record 41 of Set 22 | calvinia
# Processing Record 42 of Set 22 | vao
# Processing Record 43 of Set 22 | eenhana
# Processing Record 44 of Set 22 | altay
# Processing Record 45 of Set 22 | isangel
# Processing Record 46 of Set 22 | cleburne
# Processing Record 47 of Set 22 | dubenskiy
# City not found. Skipping...
# Processing Record 48 of Set 22 | morros
# Processing Record 49 of Set 22 | sisimiut
# Processing Record 50 of Set 22 | vershino-shakhtaminskiy
# Processing Record 1 of Set 23 | ugoofaaru
# Processing Record 2 of Set 23 | japura
# Processing Record 3 of Set 23 | san jose
# Processing Record 4 of Set 23 | estrella
# Processing Record 5 of Set 23 | bandarbeyla
# Processing Record 6 of Set 23 | asilah
# Processing Record 7 of Set 23 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 23 | chakradharpur
# Processing Record 9 of Set 23 | kupang
# Processing Record 10 of Set 23 | scottsbluff
# Processing Record 11 of Set 23 | khorramabad
# Processing Record 12 of Set 23 | lapua
# Processing Record 13 of Set 23 | fos-sur-mer
# Processing Record 14 of Set 23 | miles city
# Processing Record 15 of Set 23 | ust-nera
# Processing Record 16 of Set 23 | nuuk
# Processing Record 17 of Set 23 | tucurui
# Processing Record 18 of Set 23 | codrington
# Processing Record 19 of Set 23 | yantai
# Processing Record 20 of Set 23 | dingli
# Processing Record 21 of Set 23 | altar
# Processing Record 22 of Set 23 | naze
# Processing Record 23 of Set 23 | borovichi
# Processing Record 24 of Set 23 | murray bridge
# Processing Record 25 of Set 23 | broome
# Processing Record 26 of Set 23 | visavadar
# Processing Record 27 of Set 23 | whitehorse
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Nikolskoye  59.7035   30.7861     49.89        64          83
# 1            Kaya  13.0917   -1.0844     97.48        24          73
# 2          Dikson  73.5069   80.5464     28.69        75          99
# 3         Samarai -10.6167  150.6667     81.43        76          26
# 4         Cerrito   6.8432  -72.6940     62.42        69          85
# 5        Hermanus -34.4187   19.2345     51.80        67          37
# 6  Severo-Kurilsk  50.6789  156.1250     42.57        90          99
# 7   Mar Del Plata -38.0023  -57.5575     63.95        60           0
# 8            Hilo  19.7297 -155.0900     87.28        79          20
# 9      Butaritari   3.0707  172.7902     81.16        76          68
#
#    Wind Speed Country                 Date
# 0        6.80      RU  2022-05-20 18:14:40
# 1        5.35      BF  2022-05-20 18:14:41
# 2        4.79      RU  2022-05-20 18:14:41
# 3        7.85      PG  2022-05-20 18:14:42
# 4        2.33      CO  2022-05-20 18:14:42
# 5        1.23      ZA  2022-05-20 18:14:42
# 6        7.49      RU  2022-05-20 18:14:43
# 7       18.41      AR  2022-05-20 18:14:37
# 8        5.99      US  2022-05-20 18:12:58
# 9       14.88      KI  2022-05-20 18:14:43

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1653071343.6794908

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig4.png")
# Show plot.
plt.show()

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.45x + 92.94
# The p-value is: 0.011

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt
# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")


# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")


plt.xlabel('Latitude')
plt.ylabel('Temp')

plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
  
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
 index13 = city_data_df.loc[13]

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Nikolskoye  59.7035   30.7861     49.89        64          83
# 1              Kaya  13.0917   -1.0844     97.48        24          73
# 2            Dikson  73.5069   80.5464     28.69        75          99
# 4           Cerrito   6.8432  -72.6940     62.42        69          85
# 6    Severo-Kurilsk  50.6789  156.1250     42.57        90          99
# ..              ...      ...       ...       ...       ...         ...
# 529            Naze  28.3667  129.4833     72.52        93         100
# 530       Borovichi  58.3878   33.9155     43.65        59         100
# 532          Broome  42.2506  -75.8330     81.46        58          20
# 533       Visavadar  21.3833   70.6833     81.66        75           2
# 534      Whitehorse  60.7161 -135.0538     56.10        45          40
#
#      Wind Speed Country                 Date
# 0          6.80      RU  2022-05-20 18:14:40
# 1          5.35      BF  2022-05-20 18:14:41
# 2          4.79      RU  2022-05-20 18:14:41
# 4          2.33      CO  2022-05-20 18:14:42
# 6          7.49      RU  2022-05-20 18:14:43
# ..          ...     ...                  ...
# 529       18.21      JP  2022-05-20 18:29:01
# 530        5.37      RU  2022-05-20 18:29:02
# 532       13.80      US  2022-05-20 18:29:02
# 533       12.86      IN  2022-05-20 18:29:03
# 534        5.75      CA  2022-05-20 18:29:03
#
# [365 rows x 9 columns]

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Nikolskoye  59.7035   30.7861     49.89        64          83
# 1            Kaya  13.0917   -1.0844     97.48        24          73
# 2          Dikson  73.5069   80.5464     28.69        75          99
# 4         Cerrito   6.8432  -72.6940     62.42        69          85
# 6  Severo-Kurilsk  50.6789  156.1250     42.57        90          99
#
#    Wind Speed Country                 Date
# 0        6.80      RU  2022-05-20 18:14:40
# 1        5.35      BF  2022-05-20 18:14:41
# 2        4.79      RU  2022-05-20 18:14:41
# 4        2.33      CO  2022-05-20 18:14:42
# 6        7.49      RU  2022-05-20 18:14:43

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature','Max Temp',(10,40))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity','% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression for %cloudinesss on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness','% Cloudiness',(10,55))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
     # Linear regression on the Northern Hemisphere
    x_values = northern_hemi_df["Lat"]
    y_values = northern_hemi_df["Wind Speed"]
     # Call the function.
    plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))
